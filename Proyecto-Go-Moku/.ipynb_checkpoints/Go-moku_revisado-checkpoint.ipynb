# %% [markdown]
# <table><tr>
#     <td><img src="img/Macc.png"/></td>
#     <td><p style="font-size:22px;">Lógica para ciencias de la computación</p></td>
# </tr></table>

# %% [markdown]
# ## Problema: Go-moku
#
# Go-moku es un juego de mesa para dos personas. Se juega con piedras blancas y negras en un tablero de Go de intersección de 15x15 o 19x19.
#
# Las negras juegan primero y los jugadores se alternan para colocar una piedra de su color en una intersección vacía. No hay restricción de dónde colocar, los jugadores colocan sus piedras alternativamente hasta que se recolectan una fila ininterrumpida de cinco piedras, ya sea horizontal, vertical o diagonalmente.
#
# <img src="img/hh.jpeg" alt="drawing" width="250"/>

# %% [markdown]
# ## Objetivo del proyecto
#
# El objetivo es que el computador genere un tablero en el que un jugador gana.
#
# ## Representación de las letras proposicionales.
#
# $N(x,y,t)$ es verdadero sii en el turno $t$ hay una piedra negra en la intersección $x$, $y$
# $B(x,y,t)$ es verdadero sii en el turno $t$ hay una piedra blanca en la intersección $x$, $y$.
#
#
# $x$ son las filas y $y$ son las columnas del tablero.

# %% [markdown]
# ## Etapa de la codificación de las letras proposicionales
#
# (Basado en el taller de clase de Codificación)

# %%
class objetoCodificacionNegras:
    
    def __init__ (self,Nf,Nc,Nn,chrInit) :
        self.Nf = Nf
        self.Nc = Nc
        self.Nn = Nn
        self.chrInit = chrInit

    def codifica(self,f,c,n) :
        v1 = self.Nc * f + c
        return self.Nn * v1 + n

    def decodifica(self,codigo):
        n = codigo % self.Nn
        v1 = int(codigo / self.Nn)
        c = v1 % self.Nc
        f = int(v1 / self.Nc)
        return f, c, n
    
    def N(self,f,c,n):
        codigo = self.codifica(f,c,n)
        return chr(self.chrInit + codigo)
    
    def Ninv(self,codigo) :
        v = ord(codigo)-self.chrInit
        return self.decodifica(v)

# %%
class objetoCodificacionBlancas:
    
    def __init__ (self,Nf,Nc,Nn,chrInit) :
        self.Nf = Nf
        self.Nc = Nc
        self.Nn = Nn
        self.chrInit = chrInit

    def codifica(self,f,c,n) :
        v1 = self.Nc * f + c
        return self.Nn * v1 + n

    def decodifica(self,codigo):
        n = codigo % self.Nn
        v1 = int(codigo / self.Nn)
        c = v1 % self.Nc
        f = int(v1 / self.Nc)
        return f, c, n
    
    def B(self,f,c,n):
        codigo = self.codifica(f,c,n)
        return chr(self.chrInit + codigo)
    
    def Binv(self,codigo) :
        v = ord(codigo)-self.chrInit
        return self.decodifica(v)

# %% [markdown]
# #### Dimensiones de la información para la visualización de las Negras

# %%
# Se define el rango de opciones para cada dimensión de información
Nfilas = 5
Ncolumnas = 5
Nnumeros = 7

# %%
# Se crea el objeto de codificación
cods_negras = objetoCodificacionNegras(Nfilas,Ncolumnas,Nnumeros,256)

# Se recorren todas las opciones de las dimensiones de información para visualizar su codificación
letras_negras = []
for n in range(Nnumeros):
    print("Turno: "+str(n))
    print("filas x columnas")
    for f in range(Nfilas):
        for c in range(Ncolumnas):
            cod = cods_negras.N(f,c,n)
            print(cod,end=" ")
            letras_negras.append(cod)
        print("")
    print('\n')
# Out:
# Turno: 0
# filas x columnas
# Ā ć Ď ĕ Ĝ
# ģ Ī ı ĸ Ŀ
# ņ ō Ŕ ś Ţ
# ũ Ű ŷ ž ƅ
# ƌ Ɠ ƚ ơ ƨ
#
#
# Turno: 1
# filas x columnas
# ā Ĉ ď Ė ĝ
# Ĥ ī Ĳ Ĺ ŀ
# Ň Ŏ ŕ Ŝ ţ
# Ū ű Ÿ ſ Ɔ
# ƍ Ɣ ƛ Ƣ Ʃ
#
#
# Turno: 2
# filas x columnas
# Ă ĉ Đ ė Ğ
# ĥ Ĭ ĳ ĺ Ł
# ň ŏ Ŗ ŝ Ť
# ū Ų Ź ƀ Ƈ
# Ǝ ƕ Ɯ ƣ ƪ
#
#
# Turno: 3
# filas x columnas
# ă Ċ đ Ę ğ
# Ħ ĭ Ĵ Ļ ł
# ŉ Ő ŗ Ş ť
# Ŭ ų ź Ɓ ƈ
# Ə Ɩ Ɲ Ƥ ƫ
#
#
# Turno: 4
# filas x columnas
# Ą ċ Ē ę Ġ
# ħ Į ĵ ļ Ń
# Ŋ ő Ř ş Ŧ
# ŭ Ŵ Ż Ƃ Ɖ
# Ɛ Ɨ ƞ ƥ Ƭ
#
#
# Turno: 5
# filas x columnas
# ą Č ē Ě ġ
# Ĩ į Ķ Ľ ń
# ŋ Œ ř Š ŧ
# Ů ŵ ż ƃ Ɗ
# Ƒ Ƙ Ɵ Ʀ ƭ
#
#
# Turno: 6
# filas x columnas
# Ć č Ĕ ě Ģ
# ĩ İ ķ ľ Ņ
# Ō œ Ś š Ũ
# ů Ŷ Ž Ƅ Ƌ
# ƒ ƙ Ơ Ƨ Ʈ

# %% [markdown]
# #### Dimensiones de la información para la visualización de las Blancas

# %%
# Se crea el objeto de codificación
cods_blancas = objetoCodificacionBlancas(Nfilas,Ncolumnas,Nnumeros,2001)

# Se recorren todas las opciones de las dimensiones de información para visualizar su codificación
letras_blancas = []
for n in range(Nnumeros):
    print("Turno: "+str(n))
    print("filas x columnas")
    for f in range(Nfilas):
        for c in range(Ncolumnas):
            cod = cods_blancas.B(f,c,n)
            print(cod,end=" ")
            letras_blancas.append( cod)
        print("")
    print('\n')
# Out:
# Turno: 0
# filas x columnas
# ߑ ߘ ߟ ߦ ߭
# ߴ ߻ ࠂ ࠉ ࠐ
# ࠗ ࠞ ࠥ ࠬ ࠳
# ࠺ ࡁ ࡈ ࡏ ࡖ
# ࡝ ࡤ ࡫ ࡲ ࡹ
#
#
# Turno: 1
# filas x columnas
# ߒ ߙ ߠ ߧ ߮
# ߵ ߼ ࠃ ࠊ ࠑ
# ࠘ ࠟ ࠦ ࠭ ࠴
# ࠻ ࡂ ࡉ ࡐ ࡗ
# ࡞ ࡥ ࡬ ࡳ ࡺ
#
#
# Turno: 2
# filas x columnas
# ߓ ߚ ߡ ߨ ߯
# ߶ ߽ ࠄ ࠋ ࠒ
# ࠙ ࠠ ࠧ ࠮ ࠵
# ࠼ ࡃ ࡊ ࡑ ࡘ
# ࡟ ࡦ ࡭ ࡴ ࡻ
#
#
# Turno: 3
# filas x columnas
# ߔ ߛ ߢ ߩ ߰
# ߷ ߾ ࠅ ࠌ ࠓ
# ࠚ ࠡ ࠨ ࠯ ࠶
# ࠽ ࡄ ࡋ ࡒ ࡙
# ࡠ ࡧ ࡮ ࡵ ࡼ
#
#
# Turno: 4
# filas x columnas
# ߕ ߜ ߣ ߪ ߱
# ߸ ߿ ࠆ ࠍ ࠔ
# ࠛ ࠢ ࠩ ࠰ ࠷
# ࠾ ࡅ ࡌ ࡓ ࡚
# ࡡ ࡨ ࡯ ࡶ ࡽ
#
#
# Turno: 5
# filas x columnas
# ߖ ߝ ߤ ߫ ߲
# ߹ ࠀ ࠇ ࠎ ࠕ
# ࠜ ࠣ ࠪ ࠱ ࠸
# ࠿ ࡆ ࡍ ࡔ ࡛
# ࡢ ࡩ ࡰ ࡷ ࡾ
#
#
# Turno: 6
# filas x columnas
# ߗ ߞ ߥ ߬ ߳
# ߺ ࠁ ࠈ ࠏ ࠖ
# ࠝ ࠤ ࠫ ࠲ ࠹
# ࡀ ࡇ ࡎ ࡕ ࡜
# ࡣ ࡪ ࡱ ࡸ ࡿ

# %%
for cod in letras_negras:
    print('n: ' + cod, end = ',')
    f,c,o = cods_negras.Ninv(cod)
    print ('Numero: ' +str(o), end = ',')
    print ('Fila: '+ str(f), end = ',')
    print ('Columnas: ' + str(c))
# Out:
# n: Ā,Numero: 0,Fila: 0,Columnas: 0
# n: ć,Numero: 0,Fila: 0,Columnas: 1
# n: Ď,Numero: 0,Fila: 0,Columnas: 2
# n: ĕ,Numero: 0,Fila: 0,Columnas: 3
# n: Ĝ,Numero: 0,Fila: 0,Columnas: 4
# n: ģ,Numero: 0,Fila: 1,Columnas: 0
# n: Ī,Numero: 0,Fila: 1,Columnas: 1
# n: ı,Numero: 0,Fila: 1,Columnas: 2
# n: ĸ,Numero: 0,Fila: 1,Columnas: 3
# n: Ŀ,Numero: 0,Fila: 1,Columnas: 4
# n: ņ,Numero: 0,Fila: 2,Columnas: 0
# n: ō,Numero: 0,Fila: 2,Columnas: 1
# n: Ŕ,Numero: 0,Fila: 2,Columnas: 2
# n: ś,Numero: 0,Fila: 2,Columnas: 3
# n: Ţ,Numero: 0,Fila: 2,Columnas: 4
# n: ũ,Numero: 0,Fila: 3,Columnas: 0
# n: Ű,Numero: 0,Fila: 3,Columnas: 1
# n: ŷ,Numero: 0,Fila: 3,Columnas: 2
# n: ž,Numero: 0,Fila: 3,Columnas: 3
# n: ƅ,Numero: 0,Fila: 3,Columnas: 4
# n: ƌ,Numero: 0,Fila: 4,Columnas: 0
# n: Ɠ,Numero: 0,Fila: 4,Columnas: 1
# n: ƚ,Numero: 0,Fila: 4,Columnas: 2
# n: ơ,Numero: 0,Fila: 4,Columnas: 3
# n: ƨ,Numero: 0,Fila: 4,Columnas: 4
# n: ā,Numero: 1,Fila: 0,Columnas: 0
# n: Ĉ,Numero: 1,Fila: 0,Columnas: 1
# n: ď,Numero: 1,Fila: 0,Columnas: 2
# n: Ė,Numero: 1,Fila: 0,Columnas: 3
# n: ĝ,Numero: 1,Fila: 0,Columnas: 4
# n: Ĥ,Numero: 1,Fila: 1,Columnas: 0
# n: ī,Numero: 1,Fila: 1,Columnas: 1
# n: Ĳ,Numero: 1,Fila: 1,Columnas: 2
# n: Ĺ,Numero: 1,Fila: 1,Columnas: 3
# n: ŀ,Numero: 1,Fila: 1,Columnas: 4
# n: Ň,Numero: 1,Fila: 2,Columnas: 0
# n: Ŏ,Numero: 1,Fila: 2,Columnas: 1
# n: ŕ,Numero: 1,Fila: 2,Columnas: 2
# n: Ŝ,Numero: 1,Fila: 2,Columnas: 3
# n: ţ,Numero: 1,Fila: 2,Columnas: 4
# n: Ū,Numero: 1,Fila: 3,Columnas: 0
# n: ű,Numero: 1,Fila: 3,Columnas: 1
# n: Ÿ,Numero: 1,Fila: 3,Columnas: 2
# n: ſ,Numero: 1,Fila: 3,Columnas: 3
# n: Ɔ,Numero: 1,Fila: 3,Columnas: 4
# n: ƍ,Numero: 1,Fila: 4,Columnas: 0
# n: Ɣ,Numero: 1,Fila: 4,Columnas: 1
# n: ƛ,Numero: 1,Fila: 4,Columnas: 2
# n: Ƣ,Numero: 1,Fila: 4,Columnas: 3
# n: Ʃ,Numero: 1,Fila: 4,Columnas: 4
# n: Ă,Numero: 2,Fila: 0,Columnas: 0
# n: ĉ,Numero: 2,Fila: 0,Columnas: 1
# n: Đ,Numero: 2,Fila: 0,Columnas: 2
# n: ė,Numero: 2,Fila: 0,Columnas: 3
# n: Ğ,Numero: 2,Fila: 0,Columnas: 4
# n: ĥ,Numero: 2,Fila: 1,Columnas: 0
# n: Ĭ,Numero: 2,Fila: 1,Columnas: 1
# n: ĳ,Numero: 2,Fila: 1,Columnas: 2
# n: ĺ,Numero: 2,Fila: 1,Columnas: 3
# n: Ł,Numero: 2,Fila: 1,Columnas: 4
# n: ň,Numero: 2,Fila: 2,Columnas: 0
# n: ŏ,Numero: 2,Fila: 2,Columnas: 1
# n: Ŗ,Numero: 2,Fila: 2,Columnas: 2
# n: ŝ,Numero: 2,Fila: 2,Columnas: 3
# n: Ť,Numero: 2,Fila: 2,Columnas: 4
# n: ū,Numero: 2,Fila: 3,Columnas: 0
# n: Ų,Numero: 2,Fila: 3,Columnas: 1
# n: Ź,Numero: 2,Fila: 3,Columnas: 2
# n: ƀ,Numero: 2,Fila: 3,Columnas: 3
# n: Ƈ,Numero: 2,Fila: 3,Columnas: 4
# n: Ǝ,Numero: 2,Fila: 4,Columnas: 0
# n: ƕ,Numero: 2,Fila: 4,Columnas: 1
# n: Ɯ,Numero: 2,Fila: 4,Columnas: 2
# n: ƣ,Numero: 2,Fila: 4,Columnas: 3
# n: ƪ,Numero: 2,Fila: 4,Columnas: 4
# n: ă,Numero: 3,Fila: 0,Columnas: 0
# n: Ċ,Numero: 3,Fila: 0,Columnas: 1
# n: đ,Numero: 3,Fila: 0,Columnas: 2
# n: Ę,Numero: 3,Fila: 0,Columnas: 3
# n: ğ,Numero: 3,Fila: 0,Columnas: 4
# n: Ħ,Numero: 3,Fila: 1,Columnas: 0
# n: ĭ,Numero: 3,Fila: 1,Columnas: 1
# n: Ĵ,Numero: 3,Fila: 1,Columnas: 2
# n: Ļ,Numero: 3,Fila: 1,Columnas: 3
# n: ł,Numero: 3,Fila: 1,Columnas: 4
# n: ŉ,Numero: 3,Fila: 2,Columnas: 0
# n: Ő,Numero: 3,Fila: 2,Columnas: 1
# n: ŗ,Numero: 3,Fila: 2,Columnas: 2
# n: Ş,Numero: 3,Fila: 2,Columnas: 3
# n: ť,Numero: 3,Fila: 2,Columnas: 4
# n: Ŭ,Numero: 3,Fila: 3,Columnas: 0
# n: ų,Numero: 3,Fila: 3,Columnas: 1
# n: ź,Numero: 3,Fila: 3,Columnas: 2
# n: Ɓ,Numero: 3,Fila: 3,Columnas: 3
# n: ƈ,Numero: 3,Fila: 3,Columnas: 4
# n: Ə,Numero: 3,Fila: 4,Columnas: 0
# n: Ɩ,Numero: 3,Fila: 4,Columnas: 1
# n: Ɲ,Numero: 3,Fila: 4,Columnas: 2
# n: Ƥ,Numero: 3,Fila: 4,Columnas: 3
# n: ƫ,Numero: 3,Fila: 4,Columnas: 4
# n: Ą,Numero: 4,Fila: 0,Columnas: 0
# n: ċ,Numero: 4,Fila: 0,Columnas: 1
# n: Ē,Numero: 4,Fila: 0,Columnas: 2
# n: ę,Numero: 4,Fila: 0,Columnas: 3
# n: Ġ,Numero: 4,Fila: 0,Columnas: 4
# n: ħ,Numero: 4,Fila: 1,Columnas: 0
# n: Į,Numero: 4,Fila: 1,Columnas: 1
# n: ĵ,Numero: 4,Fila: 1,Columnas: 2
# n: ļ,Numero: 4,Fila: 1,Columnas: 3
# n: Ń,Numero: 4,Fila: 1,Columnas: 4
# n: Ŋ,Numero: 4,Fila: 2,Columnas: 0
# n: ő,Numero: 4,Fila: 2,Columnas: 1
# n: Ř,Numero: 4,Fila: 2,Columnas: 2
# n: ş,Numero: 4,Fila: 2,Columnas: 3
# n: Ŧ,Numero: 4,Fila: 2,Columnas: 4
# n: ŭ,Numero: 4,Fila: 3,Columnas: 0
# n: Ŵ,Numero: 4,Fila: 3,Columnas: 1
# n: Ż,Numero: 4,Fila: 3,Columnas: 2
# n: Ƃ,Numero: 4,Fila: 3,Columnas: 3
# n: Ɖ,Numero: 4,Fila: 3,Columnas: 4
# n: Ɛ,Numero: 4,Fila: 4,Columnas: 0
# n: Ɨ,Numero: 4,Fila: 4,Columnas: 1
# n: ƞ,Numero: 4,Fila: 4,Columnas: 2
# n: ƥ,Numero: 4,Fila: 4,Columnas: 3
# n: Ƭ,Numero: 4,Fila: 4,Columnas: 4
# n: ą,Numero: 5,Fila: 0,Columnas: 0
# n: Č,Numero: 5,Fila: 0,Columnas: 1
# n: ē,Numero: 5,Fila: 0,Columnas: 2
# n: Ě,Numero: 5,Fila: 0,Columnas: 3
# n: ġ,Numero: 5,Fila: 0,Columnas: 4
# n: Ĩ,Numero: 5,Fila: 1,Columnas: 0
# n: į,Numero: 5,Fila: 1,Columnas: 1
# n: Ķ,Numero: 5,Fila: 1,Columnas: 2
# n: Ľ,Numero: 5,Fila: 1,Columnas: 3
# n: ń,Numero: 5,Fila: 1,Columnas: 4
# n: ŋ,Numero: 5,Fila: 2,Columnas: 0
# n: Œ,Numero: 5,Fila: 2,Columnas: 1
# n: ř,Numero: 5,Fila: 2,Columnas: 2
# n: Š,Numero: 5,Fila: 2,Columnas: 3
# n: ŧ,Numero: 5,Fila: 2,Columnas: 4
# n: Ů,Numero: 5,Fila: 3,Columnas: 0
# n: ŵ,Numero: 5,Fila: 3,Columnas: 1
# n: ż,Numero: 5,Fila: 3,Columnas: 2
# n: ƃ,Numero: 5,Fila: 3,Columnas: 3
# n: Ɗ,Numero: 5,Fila: 3,Columnas: 4
# n: Ƒ,Numero: 5,Fila: 4,Columnas: 0
# n: Ƙ,Numero: 5,Fila: 4,Columnas: 1
# n: Ɵ,Numero: 5,Fila: 4,Columnas: 2
# n: Ʀ,Numero: 5,Fila: 4,Columnas: 3
# n: ƭ,Numero: 5,Fila: 4,Columnas: 4
# n: Ć,Numero: 6,Fila: 0,Columnas: 0
# n: č,Numero: 6,Fila: 0,Columnas: 1
# n: Ĕ,Numero: 6,Fila: 0,Columnas: 2
# n: ě,Numero: 6,Fila: 0,Columnas: 3
# n: Ģ,Numero: 6,Fila: 0,Columnas: 4
# n: ĩ,Numero: 6,Fila: 1,Columnas: 0
# n: İ,Numero: 6,Fila: 1,Columnas: 1
# n: ķ,Numero: 6,Fila: 1,Columnas: 2
# n: ľ,Numero: 6,Fila: 1,Columnas: 3
# n: Ņ,Numero: 6,Fila: 1,Columnas: 4
# n: Ō,Numero: 6,Fila: 2,Columnas: 0
# n: œ,Numero: 6,Fila: 2,Columnas: 1
# n: Ś,Numero: 6,Fila: 2,Columnas: 2
# n: š,Numero: 6,Fila: 2,Columnas: 3
# n: Ũ,Numero: 6,Fila: 2,Columnas: 4
# n: ů,Numero: 6,Fila: 3,Columnas: 0
# n: Ŷ,Numero: 6,Fila: 3,Columnas: 1
# n: Ž,Numero: 6,Fila: 3,Columnas: 2
# n: Ƅ,Numero: 6,Fila: 3,Columnas: 3
# n: Ƌ,Numero: 6,Fila: 3,Columnas: 4
# n: ƒ,Numero: 6,Fila: 4,Columnas: 0
# n: ƙ,Numero: 6,Fila: 4,Columnas: 1
# n: Ơ,Numero: 6,Fila: 4,Columnas: 2
# n: Ƨ,Numero: 6,Fila: 4,Columnas: 3
# n: Ʈ,Numero: 6,Fila: 4,Columnas: 4

# %%
for cod in letras_blancas:
    print('n: ' + cod, end = ',')
    f,c,o = cods_blancas.Binv(cod)
    print ('Numero: ' +str(o), end = ',')
    print ('Fila: '+ str(f), end = ',')
    print ('Columnas: ' + str(c))
# Out:
# n: ߑ,Numero: 0,Fila: 0,Columnas: 0
# n: ߘ,Numero: 0,Fila: 0,Columnas: 1
# n: ߟ,Numero: 0,Fila: 0,Columnas: 2
# n: ߦ,Numero: 0,Fila: 0,Columnas: 3
# n: ߭,Numero: 0,Fila: 0,Columnas: 4
# n: ߴ,Numero: 0,Fila: 1,Columnas: 0
# n: ߻,Numero: 0,Fila: 1,Columnas: 1
# n: ࠂ,Numero: 0,Fila: 1,Columnas: 2
# n: ࠉ,Numero: 0,Fila: 1,Columnas: 3
# n: ࠐ,Numero: 0,Fila: 1,Columnas: 4
# n: ࠗ,Numero: 0,Fila: 2,Columnas: 0
# n: ࠞ,Numero: 0,Fila: 2,Columnas: 1
# n: ࠥ,Numero: 0,Fila: 2,Columnas: 2
# n: ࠬ,Numero: 0,Fila: 2,Columnas: 3
# n: ࠳,Numero: 0,Fila: 2,Columnas: 4
# n: ࠺,Numero: 0,Fila: 3,Columnas: 0
# n: ࡁ,Numero: 0,Fila: 3,Columnas: 1
# n: ࡈ,Numero: 0,Fila: 3,Columnas: 2
# n: ࡏ,Numero: 0,Fila: 3,Columnas: 3
# n: ࡖ,Numero: 0,Fila: 3,Columnas: 4
# n: ࡝,Numero: 0,Fila: 4,Columnas: 0
# n: ࡤ,Numero: 0,Fila: 4,Columnas: 1
# n: ࡫,Numero: 0,Fila: 4,Columnas: 2
# n: ࡲ,Numero: 0,Fila: 4,Columnas: 3
# n: ࡹ,Numero: 0,Fila: 4,Columnas: 4
# n: ߒ,Numero: 1,Fila: 0,Columnas: 0
# n: ߙ,Numero: 1,Fila: 0,Columnas: 1
# n: ߠ,Numero: 1,Fila: 0,Columnas: 2
# n: ߧ,Numero: 1,Fila: 0,Columnas: 3
# n: ߮,Numero: 1,Fila: 0,Columnas: 4
# n: ߵ,Numero: 1,Fila: 1,Columnas: 0
# n: ߼,Numero: 1,Fila: 1,Columnas: 1
# n: ࠃ,Numero: 1,Fila: 1,Columnas: 2
# n: ࠊ,Numero: 1,Fila: 1,Columnas: 3
# n: ࠑ,Numero: 1,Fila: 1,Columnas: 4
# n: ࠘,Numero: 1,Fila: 2,Columnas: 0
# n: ࠟ,Numero: 1,Fila: 2,Columnas: 1
# n: ࠦ,Numero: 1,Fila: 2,Columnas: 2
# n: ࠭,Numero: 1,Fila: 2,Columnas: 3
# n: ࠴,Numero: 1,Fila: 2,Columnas: 4
# n: ࠻,Numero: 1,Fila: 3,Columnas: 0
# n: ࡂ,Numero: 1,Fila: 3,Columnas: 1
# n: ࡉ,Numero: 1,Fila: 3,Columnas: 2
# n: ࡐ,Numero: 1,Fila: 3,Columnas: 3
# n: ࡗ,Numero: 1,Fila: 3,Columnas: 4
# n: ࡞,Numero: 1,Fila: 4,Columnas: 0
# n: ࡥ,Numero: 1,Fila: 4,Columnas: 1
# n: ࡬,Numero: 1,Fila: 4,Columnas: 2
# n: ࡳ,Numero: 1,Fila: 4,Columnas: 3
# n: ࡺ,Numero: 1,Fila: 4,Columnas: 4
# n: ߓ,Numero: 2,Fila: 0,Columnas: 0
# n: ߚ,Numero: 2,Fila: 0,Columnas: 1
# n: ߡ,Numero: 2,Fila: 0,Columnas: 2
# n: ߨ,Numero: 2,Fila: 0,Columnas: 3
# n: ߯,Numero: 2,Fila: 0,Columnas: 4
# n: ߶,Numero: 2,Fila: 1,Columnas: 0
# n: ߽,Numero: 2,Fila: 1,Columnas: 1
# n: ࠄ,Numero: 2,Fila: 1,Columnas: 2
# n: ࠋ,Numero: 2,Fila: 1,Columnas: 3
# n: ࠒ,Numero: 2,Fila: 1,Columnas: 4
# n: ࠙,Numero: 2,Fila: 2,Columnas: 0
# n: ࠠ,Numero: 2,Fila: 2,Columnas: 1
# n: ࠧ,Numero: 2,Fila: 2,Columnas: 2
# n: ࠮,Numero: 2,Fila: 2,Columnas: 3
# n: ࠵,Numero: 2,Fila: 2,Columnas: 4
# n: ࠼,Numero: 2,Fila: 3,Columnas: 0
# n: ࡃ,Numero: 2,Fila: 3,Columnas: 1
# n: ࡊ,Numero: 2,Fila: 3,Columnas: 2
# n: ࡑ,Numero: 2,Fila: 3,Columnas: 3
# n: ࡘ,Numero: 2,Fila: 3,Columnas: 4
# n: ࡟,Numero: 2,Fila: 4,Columnas: 0
# n: ࡦ,Numero: 2,Fila: 4,Columnas: 1
# n: ࡭,Numero: 2,Fila: 4,Columnas: 2
# n: ࡴ,Numero: 2,Fila: 4,Columnas: 3
# n: ࡻ,Numero: 2,Fila: 4,Columnas: 4
# n: ߔ,Numero: 3,Fila: 0,Columnas: 0
# n: ߛ,Numero: 3,Fila: 0,Columnas: 1
# n: ߢ,Numero: 3,Fila: 0,Columnas: 2
# n: ߩ,Numero: 3,Fila: 0,Columnas: 3
# n: ߰,Numero: 3,Fila: 0,Columnas: 4
# n: ߷,Numero: 3,Fila: 1,Columnas: 0
# n: ߾,Numero: 3,Fila: 1,Columnas: 1
# n: ࠅ,Numero: 3,Fila: 1,Columnas: 2
# n: ࠌ,Numero: 3,Fila: 1,Columnas: 3
# n: ࠓ,Numero: 3,Fila: 1,Columnas: 4
# n: ࠚ,Numero: 3,Fila: 2,Columnas: 0
# n: ࠡ,Numero: 3,Fila: 2,Columnas: 1
# n: ࠨ,Numero: 3,Fila: 2,Columnas: 2
# n: ࠯,Numero: 3,Fila: 2,Columnas: 3
# n: ࠶,Numero: 3,Fila: 2,Columnas: 4
# n: ࠽,Numero: 3,Fila: 3,Columnas: 0
# n: ࡄ,Numero: 3,Fila: 3,Columnas: 1
# n: ࡋ,Numero: 3,Fila: 3,Columnas: 2
# n: ࡒ,Numero: 3,Fila: 3,Columnas: 3
# n: ࡙,Numero: 3,Fila: 3,Columnas: 4
# n: ࡠ,Numero: 3,Fila: 4,Columnas: 0
# n: ࡧ,Numero: 3,Fila: 4,Columnas: 1
# n: ࡮,Numero: 3,Fila: 4,Columnas: 2
# n: ࡵ,Numero: 3,Fila: 4,Columnas: 3
# n: ࡼ,Numero: 3,Fila: 4,Columnas: 4
# n: ߕ,Numero: 4,Fila: 0,Columnas: 0
# n: ߜ,Numero: 4,Fila: 0,Columnas: 1
# n: ߣ,Numero: 4,Fila: 0,Columnas: 2
# n: ߪ,Numero: 4,Fila: 0,Columnas: 3
# n: ߱,Numero: 4,Fila: 0,Columnas: 4
# n: ߸,Numero: 4,Fila: 1,Columnas: 0
# n: ߿,Numero: 4,Fila: 1,Columnas: 1
# n: ࠆ,Numero: 4,Fila: 1,Columnas: 2
# n: ࠍ,Numero: 4,Fila: 1,Columnas: 3
# n: ࠔ,Numero: 4,Fila: 1,Columnas: 4
# n: ࠛ,Numero: 4,Fila: 2,Columnas: 0
# n: ࠢ,Numero: 4,Fila: 2,Columnas: 1
# n: ࠩ,Numero: 4,Fila: 2,Columnas: 2
# n: ࠰,Numero: 4,Fila: 2,Columnas: 3
# n: ࠷,Numero: 4,Fila: 2,Columnas: 4
# n: ࠾,Numero: 4,Fila: 3,Columnas: 0
# n: ࡅ,Numero: 4,Fila: 3,Columnas: 1
# n: ࡌ,Numero: 4,Fila: 3,Columnas: 2
# n: ࡓ,Numero: 4,Fila: 3,Columnas: 3
# n: ࡚,Numero: 4,Fila: 3,Columnas: 4
# n: ࡡ,Numero: 4,Fila: 4,Columnas: 0
# n: ࡨ,Numero: 4,Fila: 4,Columnas: 1
# n: ࡯,Numero: 4,Fila: 4,Columnas: 2
# n: ࡶ,Numero: 4,Fila: 4,Columnas: 3
# n: ࡽ,Numero: 4,Fila: 4,Columnas: 4
# n: ߖ,Numero: 5,Fila: 0,Columnas: 0
# n: ߝ,Numero: 5,Fila: 0,Columnas: 1
# n: ߤ,Numero: 5,Fila: 0,Columnas: 2
# n: ߫,Numero: 5,Fila: 0,Columnas: 3
# n: ߲,Numero: 5,Fila: 0,Columnas: 4
# n: ߹,Numero: 5,Fila: 1,Columnas: 0
# n: ࠀ,Numero: 5,Fila: 1,Columnas: 1
# n: ࠇ,Numero: 5,Fila: 1,Columnas: 2
# n: ࠎ,Numero: 5,Fila: 1,Columnas: 3
# n: ࠕ,Numero: 5,Fila: 1,Columnas: 4
# n: ࠜ,Numero: 5,Fila: 2,Columnas: 0
# n: ࠣ,Numero: 5,Fila: 2,Columnas: 1
# n: ࠪ,Numero: 5,Fila: 2,Columnas: 2
# n: ࠱,Numero: 5,Fila: 2,Columnas: 3
# n: ࠸,Numero: 5,Fila: 2,Columnas: 4
# n: ࠿,Numero: 5,Fila: 3,Columnas: 0
# n: ࡆ,Numero: 5,Fila: 3,Columnas: 1
# n: ࡍ,Numero: 5,Fila: 3,Columnas: 2
# n: ࡔ,Numero: 5,Fila: 3,Columnas: 3
# n: ࡛,Numero: 5,Fila: 3,Columnas: 4
# n: ࡢ,Numero: 5,Fila: 4,Columnas: 0
# n: ࡩ,Numero: 5,Fila: 4,Columnas: 1
# n: ࡰ,Numero: 5,Fila: 4,Columnas: 2
# n: ࡷ,Numero: 5,Fila: 4,Columnas: 3
# n: ࡾ,Numero: 5,Fila: 4,Columnas: 4
# n: ߗ,Numero: 6,Fila: 0,Columnas: 0
# n: ߞ,Numero: 6,Fila: 0,Columnas: 1
# n: ߥ,Numero: 6,Fila: 0,Columnas: 2
# n: ߬,Numero: 6,Fila: 0,Columnas: 3
# n: ߳,Numero: 6,Fila: 0,Columnas: 4
# n: ߺ,Numero: 6,Fila: 1,Columnas: 0
# n: ࠁ,Numero: 6,Fila: 1,Columnas: 1
# n: ࠈ,Numero: 6,Fila: 1,Columnas: 2
# n: ࠏ,Numero: 6,Fila: 1,Columnas: 3
# n: ࠖ,Numero: 6,Fila: 1,Columnas: 4
# n: ࠝ,Numero: 6,Fila: 2,Columnas: 0
# n: ࠤ,Numero: 6,Fila: 2,Columnas: 1
# n: ࠫ,Numero: 6,Fila: 2,Columnas: 2
# n: ࠲,Numero: 6,Fila: 2,Columnas: 3
# n: ࠹,Numero: 6,Fila: 2,Columnas: 4
# n: ࡀ,Numero: 6,Fila: 3,Columnas: 0
# n: ࡇ,Numero: 6,Fila: 3,Columnas: 1
# n: ࡎ,Numero: 6,Fila: 3,Columnas: 2
# n: ࡕ,Numero: 6,Fila: 3,Columnas: 3
# n: ࡜,Numero: 6,Fila: 3,Columnas: 4
# n: ࡣ,Numero: 6,Fila: 4,Columnas: 0
# n: ࡪ,Numero: 6,Fila: 4,Columnas: 1
# n: ࡱ,Numero: 6,Fila: 4,Columnas: 2
# n: ࡸ,Numero: 6,Fila: 4,Columnas: 3
# n: ࡿ,Numero: 6,Fila: 4,Columnas: 4

# %% [markdown]
# ## Restricciones del problema
#
# #### Reglas:
#
# 1. La primera piedra en ser colocada en el tablero, debe ser una piedra negra, no hay restricción en cual intersección puede ser colocada.
#
# 2. No puede haber más de una piedra en cada intersección, sin importar el color que está.
#
# 3. Se gana con cinco piedras del mismo color seguidas en línea vertical, horizontal o diagonal.
#
# 4. Si hay una piedra en una posición del tablero, esta se queda ahí para todos los turnos siguientes.
#
# 5. (Por evaluar) Se coloca una piedra a la vez en cada ronda.

# %%
letrasProposicionalesNegras = [chr(x) for x in range(256, 1744)]
letrasProposicionalesBlancas = [chr(x) for x in range(2001,3745)]

letrasProposicionales = letrasProposicionalesNegras + letrasProposicionalesBlancas
conectivos = ["Y", "O", ">", "="]

# %%
class Tree(object):
    def __init__(self, label, left, right):
        self.left = left
        self.right = right
        self.label = label
        
def String2Tree(A):
    # Crea una formula como tree dada una formula como cadena escrita en notacion polaca inversa
    # Input: - A, lista de caracteres con una formula escrita en notacion polaca inversa
    #        - letrasProposicionales, lista de letras proposicionales
    #        - conectivos, lista de conectivos
    # Output: formula como tree
    pila = []
    for c in A:
        # print("Examinando " + str(c))
        if c in letrasProposicionales:
            # print(u"El símbolo es letra proposicional")
            pila.append(Tree(c, None, None))
        elif c == '-':
            # print("Negamos")
            formulaAux = Tree(c, None, pila[-1])
            del pila[-1]
            pila.append(formulaAux)
        elif c in conectivos:
        # print("Unimos mediante conectivo")
            formulaAux = Tree(c, pila[-1], pila[-2])
            del pila[-1]
            del pila[-1]
            pila.append(formulaAux)
        else:
            print(u"Hay un problema: el símbolo " + str(c) + " no se reconoce")
    return pila[-1]

def Inorderp(f):
    # Imprime una formula como cadena dada una formula como arbol
    # de manera que las letras proposicionales sean legibles.
    # Input: tree, que es una formula de logica proposicional
    # Output: string de la formula

    if f.right == None:
        if f.label in letrasProposicionalesNegras:
            f,c,n = cods_negras.Ninv(f.label)
            return f"N({f},{c},{n})"
        elif f.label in letrasProposicionalesBlancas:
            f,c,n = cods_blancas.Binv(f.label)
            return f"B({f},{c},{n})"
        
    elif f.label == '-':
        return f.label + Inorderp(f.right)
    else:
        return "(" + Inorderp(f.left) + f.label + " " + Inorderp(f.right) + ")"
    
def Inorder(f):
    # Imprime una formula como cadena dada una formula como arbol
    # de manera que las letras proposicionales sean legibles.
    # Input: tree, que es una formula de logica proposicional
    # Output: string de la formula

    if f.right == None:
        return f.label
    
    elif f.label == '-':
        return f.label + Inorder(f.right)
    else:
        return "(" + Inorder(f.left) + f.label + Inorder(f.right) + ")"

# %% [markdown]
# ### Pasos para la regla 1:
#
# 1.1 Hay una negra en alguna coordenada ... \begin{align}
# \left( \bigvee_{x = b}^{f} \bigvee_{y = 2}^{6} N(x,y,1) \right)
# \end{align}

# %%
inicial = True
def negras_comienza():
    inicial = True
    Nf = Nfilas
    Nc = Ncolumnas
    
    for f in range(Nf):
        for c in range(Nc):
            if inicial:
                formula = cods_negras.N(f,c,0)
                inicial = False
            else:
                formula = cods_negras.N(f,c,0) + formula + "O"
    return formula

formula = negras_comienza()
A = String2Tree(formula)
print(Inorderp(A))
# Out:
# ((((((((((((((((((((((((N(0,0,0)O N(0,1,0))O N(0,2,0))O N(0,3,0))O N(0,4,0))O N(1,0,0))O N(1,1,0))O N(1,2,0))O N(1,3,0))O N(1,4,0))O N(2,0,0))O N(2,1,0))O N(2,2,0))O N(2,3,0))O N(2,4,0))O N(3,0,0))O N(3,1,0))O N(3,2,0))O N(3,3,0))O N(3,4,0))O N(4,0,0))O N(4,1,0))O N(4,2,0))O N(4,3,0))O N(4,4,0))

# %% [markdown]
# 1.2 No puede haber una blanca en el primer turno ...
#
# \begin{align}
# \left( \bigwedge_{x = b}^{f} \bigwedge_{y = 2}^{6} \neg B(x,y,1) \right)
# \end{align}

# %%
inicial = True
def no_blancas_comienza():
    inicial = True
    Nf = Nfilas
    Nc = Ncolumnas
    
    for f in range(Nf):
        for c in range(Nc):
            if inicial:
                formula = cods_blancas.B(f,c,0) + "-"
                inicial = False
            else:
                formula = cods_blancas.B(f,c,0) + "-" + formula + "Y"
    return formula

formula = no_blancas_comienza()
A = String2Tree(formula)
print(Inorderp(A))
# Out:
# ((((((((((((((((((((((((-B(0,0,0)Y -B(0,1,0))Y -B(0,2,0))Y -B(0,3,0))Y -B(0,4,0))Y -B(1,0,0))Y -B(1,1,0))Y -B(1,2,0))Y -B(1,3,0))Y -B(1,4,0))Y -B(2,0,0))Y -B(2,1,0))Y -B(2,2,0))Y -B(2,3,0))Y -B(2,4,0))Y -B(3,0,0))Y -B(3,1,0))Y -B(3,2,0))Y -B(3,3,0))Y -B(3,4,0))Y -B(4,0,0))Y -B(4,1,0))Y -B(4,2,0))Y -B(4,3,0))Y -B(4,4,0))

# %% [markdown]
# 1.3 Si hay una negra en una coordenada, no puede haber otra negra en otra coordenada...
#
# \begin{align}
# N(x,y,1) \rightarrow \left(\bigwedge_{(u,v) \neq (x,y)} \neg N(u,v,1)\right)
# \end{align}

# %%
inicial = True
def no_dif_negras(x,y):
    inicial = True
    Nf = Nfilas
    Nc = Ncolumnas
    rango = [(u,v) for u in range(cods_negras.Nf) for v in range(cods_negras.Nc)]
    rango = [casilla for casilla in rango if casilla != (x,y)]
    for (u,v) in rango:
        if inicial:
            formula = cods_negras.N(u,v,0) + '-'
            inicial = False
        else:
            formula = cods_negras.N(u,v,0) + '-' + formula + "Y"
    
    formula = formula + cods_negras.N(x,y,0) + '>'
    return formula

formula = no_dif_negras(0,0)
A = String2Tree(formula)
print(Inorderp(A))
# Out:
# (N(0,0,0)> (((((((((((((((((((((((-N(0,1,0)Y -N(0,2,0))Y -N(0,3,0))Y -N(0,4,0))Y -N(1,0,0))Y -N(1,1,0))Y -N(1,2,0))Y -N(1,3,0))Y -N(1,4,0))Y -N(2,0,0))Y -N(2,1,0))Y -N(2,2,0))Y -N(2,3,0))Y -N(2,4,0))Y -N(3,0,0))Y -N(3,1,0))Y -N(3,2,0))Y -N(3,3,0))Y -N(3,4,0))Y -N(4,0,0))Y -N(4,1,0))Y -N(4,2,0))Y -N(4,3,0))Y -N(4,4,0)))

# %% [markdown]
# 1.4  Para todas las posibilidades del paso 1.3
#
# \begin{align*}
# \left( \bigwedge_{x = b}^{f} \bigwedge_{y = 2}^{6} \left( N(x,y,1) \rightarrow \left(\bigwedge_{(u,v) \neq (x,y)} \neg N(u,v,1)\right) \right) \right)
# \end{align*}

# %%
def no_dif_negras_():
    inicial = True
    for f in range(cods_negras.Nf):
        for c in range(cods_negras.Nc): 
            if inicial:
                formula = no_dif_negras(f,c)
                inicial = False
            else:
                formula = no_dif_negras(f,c) + formula + "Y"
    return formula

# %%
formula = no_dif_negras_()
A = String2Tree(formula)
print(Inorderp(A))
# Out:
# (((((((((((((((((((((((((N(0,0,0)> (((((((((((((((((((((((-N(0,1,0)Y -N(0,2,0))Y -N(0,3,0))Y -N(0,4,0))Y -N(1,0,0))Y -N(1,1,0))Y -N(1,2,0))Y -N(1,3,0))Y -N(1,4,0))Y -N(2,0,0))Y -N(2,1,0))Y -N(2,2,0))Y -N(2,3,0))Y -N(2,4,0))Y -N(3,0,0))Y -N(3,1,0))Y -N(3,2,0))Y -N(3,3,0))Y -N(3,4,0))Y -N(4,0,0))Y -N(4,1,0))Y -N(4,2,0))Y -N(4,3,0))Y -N(4,4,0)))Y (N(0,1,0)> (((((((((((((((((((((((-N(0,0,0)Y -N(0,2,0))Y -N(0,3,0))Y -N(0,4,0))Y -N(1,0,0))Y -N(1,1,0))Y -N(1,2,0))Y -N(1,3,0))Y -N(1,4,0))Y -N(2,0,0))Y -N(2,1,0))Y -N(2,2,0))Y -N(2,3,0))Y -N(2,4,0))Y -N(3,0,0))Y -N(3,1,0))Y -N(3,2,0))Y -N(3,3,0))Y -N(3,4,0))Y -N(4,0,0))Y -N(4,1,0))Y -N(4,2,0))Y -N(4,3,0))Y -N(4,4,0))))Y (N(0,2,0)> (((((((((((((((((((((((-N(0,0,0)Y -N(0,1,0))Y -N(0,3,0))Y -N(0,4,0))Y -N(1,0,0))Y -N(
0))Y -N(3,1,0))Y -N(3,2,0))Y -N(3,3,0))Y -N(3,4,0))Y -N(4,0,0))Y -N(4,1,0))Y -N(4,2,0))Y -N(4,3,0))Y -N(4,4,0))))Y (N(1,3,0)> (((((((((((((((((((((((-N(0,0,0)Y -N(0,1,0))Y -N(0,2,0))Y -N(0,3,0))Y -N(0,4,0))Y -N(1,0,0))Y -N(1,1,0))Y -N(1,2,0))Y -N(1,4,0))Y -N(2,0,0))Y -N(2,1,0))Y -N(2,2,0))Y -N(2,3,0))Y -N(2,4,0))Y -N(3,0,0))Y -N(3,1,0))Y -N(3,2,0))Y -N(3,3,0))Y -N(3,4,0))Y -N(4,0,0))Y -N(4,1,0))Y -N(4,2,0))Y -N(4,3,0))Y -N(4,4,0))))Y (N(1,4,0)> (((((((((((((((((((((((-N(0,0,0)Y -N(0,1,0))Y -N(0,2,0))Y -N(0,3,0))Y -N(0,4,0))Y -N(1,0,0))Y -N(1,1,0))Y -N(1,2,0))Y -N(1,3,0))Y -N(2,0,0))Y -N(2,1,0))Y -N(2,2,0))Y -N(2,3,0))Y -N(2,4,0))Y -N(3,0,0))Y -N(3,1,0))Y -N(3,2,0))Y -N(3,3,0))Y -N(3,4,0))Y -N(4,0,0))Y -N(4,1,0))Y -N(4,2,0))Y -N(4,3,0))Y -N(4,4,0))))Y (N(2,0,0)> (((((((((((((((((((((((-N(0,0,0)Y -N(0,1,0))Y -N(0,2,0))Y -N(0,3,0))Y -N(0,4,0))Y -N(1,0,0))Y -N(1,1,0))Y -N(1,2,0))Y -N(1,3,0))Y -N(1,4,0))Y -N(2,1,0))Y -N(2,2,0))Y -N(2,3,0))Y -N(2,4,0))Y -N(3,0,0))Y -N(3,1,0))Y -N(3,2,0))Y -N(3,3,0))Y -N(3,4,0))Y -N(4,0,0))Y -N(4,1,0))Y -N(4,2,0))Y -N(4,3,0))Y -N(4,4,0))))Y (N(2,1,0)> (((((((((((((((((((((((-N(0,0,0)Y -N(0,1,0))Y -N(0,2,0))Y -N(0,3,0))Y -N(0,4,0))Y -N(1,0,0))Y -N(1,1,0))Y -N(1,2,0))Y -N(1,3,0))Y -N(1,4,0))Y -N(2,0,0))Y -N(2,2,0))Y -N(2,3,0))Y -N(2,4,0))Y -N(3,0,0))Y -N(3,1,0))Y -N(3,2,0))Y -N(3,3,0))Y -N(3,4,0))Y -N(4,0,0))Y -N(4,1,0))Y -N(4,2,0))Y -N(4,3,0))Y -N(4,4,0))))Y (N(2,2,0)> (((((((((((((((((((((((-N(0,0,0)Y -N(0,1,0))Y -N(0,2,0))Y -N(0,3,0))Y -N(0,4,0))Y -N(1,0,0 ...

# %% [markdown]
# 1.5 Finalmente, uniendo las funciones anteriores, obtenemos la **regla 1**:
#
# \begin{align*}
#     \left( \bigvee_{x = b}^{f} \bigvee_{y = 2}^{6} N(x,y,1) \right) \wedge \left( \bigwedge_{x = b}^{f} \bigwedge_{y = 2}^{6} \neg B(x,y,1) \right)  \wedge \left( \bigwedge_{x = b}^{f} \bigwedge_{y = 2}^{6} \left( N(x,y,1) \rightarrow \left(\bigwedge_{(u,v) \neq (x,y)} \neg N(u,v,1)\right) \right) \right)
# \end{align*}
#
# La primera piedra en ser colocada en el tablero, debe ser una piedra negra, no hay restricción en cual intersección puede ser colocada.

# %%
def regla1():
    formula1 = negras_comienza()
    formula2 = no_blancas_comienza()
    formula3 = no_dif_negras_()
    formula = formula3 + formula2 + 'Y' + formula1 + 'Y'
    return formula

# %%
formula = regla1()
A = String2Tree(formula)
print(Inorderp(A))
# Out:
# (((((((((((((((((((((((((N(0,0,0)O N(0,1,0))O N(0,2,0))O N(0,3,0))O N(0,4,0))O N(1,0,0))O N(1,1,0))O N(1,2,0))O N(1,3,0))O N(1,4,0))O N(2,0,0))O N(2,1,0))O N(2,2,0))O N(2,3,0))O N(2,4,0))O N(3,0,0))O N(3,1,0))O N(3,2,0))O N(3,3,0))O N(3,4,0))O N(4,0,0))O N(4,1,0))O N(4,2,0))O N(4,3,0))O N(4,4,0))Y (((((((((((((((((((((((((-B(0,0,0)Y -B(0,1,0))Y -B(0,2,0))Y -B(0,3,0))Y -B(0,4,0))Y -B(1,0,0))Y -B(1,1,0))Y -B(1,2,0))Y -B(1,3,0))Y -B(1,4,0))Y -B(2,0,0))Y -B(2,1,0))Y -B(2,2,0))Y -B(2,3,0))Y -B(2,4,0))Y -B(3,0,0))Y -B(3,1,0))Y -B(3,2,0))Y -B(3,3,0))Y -B(3,4,0))Y -B(4,0,0))Y -B(4,1,0))Y -B(4,2,0))Y -B(4,3,0))Y -B(4,4,0))Y (((((((((((((((((((((((((N(0,0,0)> (((((((((((((((((((((((-N(0,1,0)Y -N(0,2,0))Y -N(0,3,0))Y -N(0,4,0))Y -N(1,0,0))Y -N(1,1,0))Y -N(1,2,0))Y -N(1,3,0))Y -N(1,4,0))Y -N(2,0,0))Y -N(2,1,0))Y -N(2,2,0))Y -N(2,3,0))Y -N(2,4,0))Y -N(3,0,0))Y -N(3,1,0))Y -N(3,2,0))Y -N(3,3,0))Y -N(3,4,0))Y -N(4,0,0))Y -N(4,1,0))Y -N(4,2,0))Y -N(4,3,0))Y -N(4,4,0)))Y (N(0,1,0)> (((((((((((((((((((((((-N(0,0,0)Y -N(0,2,0))Y -N(0,3,0))Y -N(0,4,0))Y -N(1,0,0))Y -N(1,1,0))Y -N(1,2,0))Y -N(1,3,0))Y -N(1,4,0))Y -N(2,0,0))Y -N(2,1,0))Y -N(2,2,0))Y -N(2,3,0))Y -N(2,4,0))Y -N(3,0,0))Y -N(3,1,0))Y -N(3,2,0))Y -N(3,3,0))Y -N(3,4,0))Y -N(4,0,0))Y -N(4,1,0))Y -N(4,2,0))Y -N(4,3,0))Y -N(4,4,0))))Y (N(0,2,0)> (((((((((((((((((((((((-N(0,0,0)Y -N(0,1,0))Y -N(0,3,0))Y -N(0,4,0))Y -N(1,0,0))Y -N(1,1,0))Y -N(1,2,0))Y -N(1,3,0))Y -N(1,4,0))Y -N(2,0,0))Y -N(2,1,0))Y -N(2,2,0))Y -N(2,3,0
N(4,3,0))Y -N(4,4,0))))Y (N(1,3,0)> (((((((((((((((((((((((-N(0,0,0)Y -N(0,1,0))Y -N(0,2,0))Y -N(0,3,0))Y -N(0,4,0))Y -N(1,0,0))Y -N(1,1,0))Y -N(1,2,0))Y -N(1,4,0))Y -N(2,0,0))Y -N(2,1,0))Y -N(2,2,0))Y -N(2,3,0))Y -N(2,4,0))Y -N(3,0,0))Y -N(3,1,0))Y -N(3,2,0))Y -N(3,3,0))Y -N(3,4,0))Y -N(4,0,0))Y -N(4,1,0))Y -N(4,2,0))Y -N(4,3,0))Y -N(4,4,0))))Y (N(1,4,0)> (((((((((((((((((((((((-N(0,0,0)Y -N(0,1,0))Y -N(0,2,0))Y -N(0,3,0))Y -N(0,4,0))Y -N(1,0,0))Y -N(1,1,0))Y -N(1,2,0))Y -N(1,3,0))Y -N(2,0,0))Y -N(2,1,0))Y -N(2,2,0))Y -N(2,3,0))Y -N(2,4,0))Y -N(3,0,0))Y -N(3,1,0))Y -N(3,2,0))Y -N(3,3,0))Y -N(3,4,0))Y -N(4,0,0))Y -N(4,1,0))Y -N(4,2,0))Y -N(4,3,0))Y -N(4,4,0))))Y (N(2,0,0)> (((((((((((((((((((((((-N(0,0,0)Y -N(0,1,0))Y -N(0,2,0))Y -N(0,3,0))Y -N(0,4,0))Y -N(1,0,0))Y -N(1,1,0))Y -N(1,2, ...

# %% [markdown]
# ### Pasos para la regla 2:
#
# 2.1 No puede haber una misma piedra en una intersección escogida.
#
# \begin{align*}
# \left( N(x,y,t) \rightarrow \neg B(x,y,t) \right) \wedge \left( B(x,y,t) \rightarrow \neg N(x,y,t) \right)
# \end{align*}

# %%
def no_piedras_misma_interseccion(x,y,t):
    formula1 = cods_blancas.B(x,y,t) + "-" + cods_negras.N(x,y,t) + ">"
    formula2 = cods_negras.N(x,y,t) + "-" + cods_blancas.B(x,y,t) + ">"
    formula = formula2 + formula1 + "Y"
    return formula

formula = no_piedras_misma_interseccion(1,1,2)
A = String2Tree(formula)
print(Inorderp(A))
# Out:
# ((N(1,1,2)> -B(1,1,2))Y (B(1,1,2)> -N(1,1,2)))

# %% [markdown]
# 2.2. Para todas las posibilidades del paso 2.1. Obtenemos la **regla 2**:
#
# \begin{align*}
#   \bigwedge_{t = 1}^{25} \bigwedge_{x = b}^{f} \bigwedge_{y = 2}^{6} \left( N(x,y,t) \rightarrow \neg B(x,y,t) \right) \wedge \left( B(x,y,t) \rightarrow \neg N(x,y,t) \right)
# \end{align*}
#
# No puede haber más de una piedra en cada intersección, sin importar el color que está.

# %%
def regla2():
    inicial = True
    Nf = Nfilas
    Nc = Ncolumnas
    Nt = Nnumeros
    for f in range(Nf):
        for c in range(Nc): 
            for t in range(Nt):
                if inicial:
                    formula = no_piedras_misma_interseccion(f,c,t)
                    inicial = False
                else:
                    formula = no_piedras_misma_interseccion(f,c,t) + formula + 'Y'
    return formula

# %%
formula = regla2()
A = String2Tree(formula)
print(Inorderp(A))
# Out:
# ((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((N(0,0,0)> -B(0,0,0))Y (B(0,0,0)> -N(0,0,0)))Y ((N(0,0,1)> -B(0,0,1))Y (B(0,0,1)> -N(0,0,1))))Y ((N(0,0,2)> -B(0,0,2))Y (B(0,0,2)> -N(0,0,2))))Y ((N(0,0,3)> -B(0,0,3))Y (B(0,0,3)> -N(0,0,3))))Y ((N(0,0,4)> -B(0,0,4))Y (B(0,0,4)> -N(0,0,4))))Y ((N(0,0,5)> -B(0,0,5))Y (B(0,0,5)> -N(0,0,5))))Y ((N(0,0,6)> -B(0,0,6))Y (B(0,0,6)> -N(0,0,6))))Y ((N(0,1,0)> -B(0,1,0))Y (B(0,1,0)> -N(0,1,0))))Y ((N(0,1,1)> -B(0,1,1))Y (B(0,1,1)> -N(0,1,1))))Y ((N(0,1,2)> -B(0,1,2))Y (B(0,1,2)> -N(0,1,2))))Y ((N(0,1,3)> -B(0,1,3))Y (B(0,1,3)> -N(0,1,3))))Y ((N(0,1,4)> -B(0,1,4))Y (B(0,1,4)> -N(0,1,4))))Y ((N(0,1,5)> -B(0,1,5))Y (B(0,1,5)> -N(0,1,5))))Y ((N(0,1,6)> -B(0,1,6))Y (B(0,1,6)> -N(0,1,6))))Y ((N(0,2,0)> -B(0,2,0))Y (B(0,2,0)> -N(0,2,0))))Y ((N(0,2,1)> -B(0,2,1))Y (B(0,2,1)> -N(0,2,1))))Y ((N(0,2,2)> -B(0,2,2))Y (B(0,2,2)> -N(0,2,2))))Y ((N(0,2,3)> -B(0,2,3))Y (B(0,2,3)> -N(0,2,3))))Y ((N(0,2,4)> -B(0,2,4))Y (B(0,2,4)> -N(0,2,4))))Y ((N(0,2,5)> -B(0,2,5))Y (B(0,2,5)> -N(0,2,5))))Y ((N(0,2,6)> -B(0,2,6))Y (B(0,2,6)> -N(0,2,6))))Y ((N(0,3,0)> -B(0,3,0))Y (B(0,3,0)> -N(0,3,0))))Y ((N(0,3,1)> -B(0,3,1))Y (B(0,3,1)> -N(0,3,1))))Y ((N(0,3,2)> -B(0,3,2))Y (B(0,3,2)> -N(0,3,2))))Y ((N(0,3,3)> -B(0,3,3))Y (B(0,3,3)> -N(0,3,3))))Y ((N(0,3,4)> -B(0,3,4))Y (B(0,3,4)> -N(0,3,4))))Y ((N(0,3,5)> -B(0,3,5))Y (B(0,3,5)> -N(0,3,5))))Y ((N(0,3,6)> -B(0,3,6))Y (B(0,3,6)> -N(0,3,6))))Y ((N(0,4,0)> -B(0,4,0))Y (B(0,4,0)> -N(0,4,0))))Y ((N(0,4,1)> -B(0,4,1))Y (B(0,4,1)> -N(0,4,1))))Y ((N(0,4,2)> -B(0,4,2))Y (B(0,4,2)> -N(0,4,2))))Y ((N(0,4,3)> -B(0,4,3))Y (B(0,4,3)> -N(0,4,3))))Y ((N(0,4,4)> -B(0,4,4))Y (B(0,4,4)> -N(0,4,4))))Y ((N(0,4,5)> -B(0,4,5))Y (B(0,4,5)> -N(0,4,5))))Y ((N(0,4,6)> -B(0,4,6))Y (B(0,4,6)> -N(0,4,6))))Y ((N(1,0,0)> -B(1,0,0))Y (B(1,0,0)> -N(1,0,0))))Y ((N(1,0,1)> -B(1,0,1))Y (B(1,0,1)> -N(1,0,1))))Y ((N(1,0,2)> -B(1,0,2))Y (B(1,0,2)> -N(1,0,2))))Y ((N(1,0,3)> -B(1,0,3))Y (B(1,0,3)> -N(1,0,3))))Y ((N(1,0,4)> -B(1,0,4))Y (B(1,0,4)> -N(1,0,4))))Y ((N(1,0,5)> -B(1,0,5))Y (B(1,0,5)> -N(1,0,5))))Y ((N(1,0,6)> -B(1,0,6))Y (B(1,0,6)> -N(1,0,6))))Y ((N(1,1,0)> -B(1,1,0))Y (B(1,1,0)> -N(1,1,0))))Y ((N(1,1,1)> -B(1,1,1))Y (B(1,1,1)> -N(1,1,1))))Y ((N(1,1,2)> -B(1,1,2))Y (B(1,1,2)> -N(1,1,2))))Y ((N(1,1,3)> -B(1,1,3))Y (B(1,1,3)> -N(1,1,3))))Y ((N(1,1,4)> -B(1,1,4))Y (B(1,1,4)> -N(1,1,4))))Y ((N(1,1,5)> -B(1,1,5))Y (B(1,1,5)> -N(1,1,5))))Y ((N(1,1,6)> -B(1,1,6))Y (B(1,1,6)> -N(1,1,6))))Y ((N(1,2,0)> -B(1,2,0))Y (B(1,2,0)> -N(1,2,0))))Y ((N(1,2,1)> -B(1,2,1))Y (B(1,2,1)> -N(1,2,1))))Y ((N(1,2,2)> -B(1,2,2))Y (B(1,2,2)> -N(1,2,2))))Y ((N(1,2,3)> -B(1,2,3))Y (B(1,2,3)> -N(1,2,3))))Y ((N(1,2,4)> -B(1,2,4))Y (B(1,2,4)> -N(1,2,4))))Y ((N(1,2,5)> -B(1,2,5))Y (B(1,2,5)> -N(1,2,5))))Y ((N(1,2,6)> -B(1,2,6))Y (B(1,2,6)> -N(1,2,6))))Y ((N(1,3,0)> -B(1,3,0))Y (B(1,3,0)> -N(1,3,0))))Y ((N(1,3,1)> -B(1,3,1))Y (B(1,3,1)> -N(1,3,1))))Y ((N(1,3,2)> -B(1,3,2))Y (B(1,3,2)> -N(1,3,2))))Y ((N(1,3,3)> -B(1,3,3))Y (B(1,3,3)> -N(1,3,3))))Y ((N(1,3,4)> -B(1,3,4))Y (B(1,3,4)> -N(1,3,4))))Y ((N(1,3,5)> -B(1,3,5))Y (B(1,3,5)> -N(1,3,5))))Y ((N(1,3,6)> -B(1,3,6))Y (B(1,3,6)> -N(1,3,6))))Y ((N(1,4,0)> -B(1,4,0))Y (B(1,4,0)> -N(1,4,0))))Y ((N(1,4,1)> -B(1,4,1))Y (B(1,4,1)> -N(1,4,1))))Y ((N(1,4,2)> -B(1,4,2))Y (B(1,4,2)> -N(1,4,2))))Y ((N(1,4,3)> -B(1,4,3))Y (B(1,4,3)> -N(1,4,3))))Y ((N(1,4,4)> -B(1,4,4))Y (B(1,4,4)> -N(1,4,4))))Y ((N(1,4,5)> -B(1,4,5))Y (B(1,4,5)> -N(1,4,5))))Y ((N(1,4,6)> -B(1,4,6))Y (B(1,4,6)> -N(1,4,6))))Y ((N(2,0,0)> -B(2,0,0))Y (B(2,0,0)> -N(2,0,0))))Y ((N(2,0,1)> -B(2,0,1))Y (B(2,0,1)> -N(2,0,1))))Y ((N(2,0,2)> -B(2,0,2))Y (B(2,0,2)> -N(2,0,2))))Y ((N(2,0,3)> -B(2,0,3))Y (B(2,0,3)> -N(2,0,3))))Y ((N(2,0,4)> -B(2,0,4))Y (B(2,0,4)> -N(2,0,4))))Y ((N(2,0,5)> -B(2,0,5))Y (B(2,0,5)> -N(2,0,5))))Y ((N(2,0,6)> -B(2,0,6))Y (B(2,0,6)> -N(2,0,6))))Y ((N(2,1,0)> -B(2,1,0))Y (B(2,1,0)> -N(2,1,0))))Y ((N(2 ...

# %% [markdown]
# ### Pasos para la regla 3:
#
# #### Victoria diagonal 1
#
# \begin{align*}
#     (\bigwedge^{4}_{i = 0} N(b + i,2 + i, 10))
# \end{align*}
# \begin{align*}
#     \vee
# \end{align*}
#
# \begin{align*}
#     (\bigwedge^{4}_{i = 0} B(b + i,2 + i, 10))
# \end{align*}

# %%
def victoria_negras_diagonal_1():
    inicial = True
    for i in range(5):
        if inicial:
            formula = cods_negras.N(1 + i, 1 + i, Nnumeros -1)
            inicial = False
        else:
            formula = cods_negras.N(1 + i, 1 + i, Nnumeros -1) + formula + 'Y'
    return formula

def victoria_blancas_diagonal_1():
    inicial = True
    for i in range(5):
        if inicial:
            formula = cods_blancas.B(1 + i, 1 + i, Nnumeros -1)
            inicial = False
        else:
            formula = cods_blancas.B(1 + i, 1 + i, Nnumeros -1) + formula + 'Y'
    return formula

def victoria_diagonal_1():
    formula1 = victoria_negras_diagonal_1()
    formula2 = victoria_blancas_diagonal_1()
    formula = formula2 + formula1 + 'O'
    return formula

formula = victoria_diagonal_1()
A = String2Tree(formula)
print(Inorderp(A))
# Out:
# (((((N(1,1,6)Y N(2,2,6))Y N(3,3,6))Y N(4,4,6))Y N(6,0,6))O ((((B(1,1,6)Y B(2,2,6))Y B(3,3,6))Y B(4,4,6))Y B(6,0,6)))

# %% [markdown]
# #### Victoria diagonal 2
#
# \begin{align*}
#     (\bigwedge^{4}_{i = 0} N(b + 1, 6 - i, 10))
# \end{align*}
# \begin{align*}
#     \vee
# \end{align*}
# \begin{align*}
#     (\bigwedge^{4}_{i = 0} B(b + 1, 6 - i, 10))
# \end{align*}

# %%
def victoria_negras_diagonal_2():
    inicial = True
    for i in range(5):
        if inicial:
            formula = cods_negras.N(1 + i, 5 - i, Nnumeros -1)
            inicial = False
        else:
            formula = cods_negras.N(1 + i, 5 - i, Nnumeros -1) + formula + 'Y'
    return formula

def victoria_blancas_diagonal_2():
    inicial = True
    for i in range(5):
        if inicial:
            formula = cods_blancas.B(1 + i, 5 - i, Nnumeros -1)
            inicial = False
        else:
            formula = cods_blancas.B(1 + i, 5 - i, Nnumeros -1) + formula + 'Y'
    return formula

def victoria_diagonal_2():
    formula1 = victoria_negras_diagonal_2()
    formula2 = victoria_blancas_diagonal_2()
    formula = formula2 + formula1 + 'O'
    return formula

formula = victoria_diagonal_2()
A = String2Tree(formula)
print(Inorderp(A))
# Out:
# (((((N(2,0,6)Y N(2,4,6))Y N(3,3,6))Y N(4,2,6))Y N(5,1,6))O ((((B(2,0,6)Y B(2,4,6))Y B(3,3,6))Y B(4,2,6))Y B(5,1,6)))

# %% [markdown]
# #### Victoria vertical
#
# \begin{align*}
#     \bigvee^{6}_{y = 2}(\bigwedge^{f}_{x = b} N(x,y,10))
# \end{align*}
# \begin{align*}
#     \vee
# \end{align*}
# \begin{align*}
#     \bigvee^{6}_{y = 2}(\bigwedge^{f}_{x = b} B(x,y,10))
# \end{align*}

# %%
def ytoria_v_negras(c):
    Nf = 6
    inicial = True
    for f in range(1, Nf):
        if inicial:
            formula = cods_negras.N(f,c,Nnumeros -1)
            inicial = False
        else:
            formula = cods_negras.N(f,c,Nnumeros -1) + formula + 'Y'
    return formula

def victoria_vertical_negras():
    Nc = 6
    inicial = True
    for c in range(1, Nc):
        if inicial:
            formula = ytoria_v_negras(c)
            inicial = False
        else:
            formula = ytoria_v_negras(c) + formula + 'O'
    return formula

def ytoria_v_blancas(c):
    Nf = 6
    inicial = True
    for f in range(1, Nf):
        if inicial:
            formula = cods_blancas.B(f,c,Nnumeros -1)
            inicial = False
        else:
            formula = cods_blancas.B(f,c,Nnumeros -1) + formula + 'Y'
    return formula

def victoria_vertical_blancas():
    Nc = 6
    inicial = True
    for c in range(1, Nc):
        if inicial:
            formula = ytoria_v_blancas(c)
            inicial = False
        else:
            formula = ytoria_v_blancas(c) + formula + 'O'
    return formula

def victoria_vertical():
    formula1 = victoria_vertical_negras()
    formula2 = victoria_vertical_blancas()
    formula = formula2 + formula1 + 'O'
    return formula

formula = victoria_vertical()
A = String2Tree(formula)
print(Inorderp(A))
# Out:
# (((((((((N(1,1,6)Y N(2,1,6))Y N(3,1,6))Y N(4,1,6))Y N(5,1,6))O ((((N(1,2,6)Y N(2,2,6))Y N(3,2,6))Y N(4,2,6))Y N(5,2,6)))O ((((N(1,3,6)Y N(2,3,6))Y N(3,3,6))Y N(4,3,6))Y N(5,3,6)))O ((((N(1,4,6)Y N(2,4,6))Y N(3,4,6))Y N(4,4,6))Y N(5,4,6)))O ((((N(2,0,6)Y N(3,0,6))Y N(4,0,6))Y N(5,0,6))Y N(6,0,6)))O ((((((((B(1,1,6)Y B(2,1,6))Y B(3,1,6))Y B(4,1,6))Y B(5,1,6))O ((((B(1,2,6)Y B(2,2,6))Y B(3,2,6))Y B(4,2,6))Y B(5,2,6)))O ((((B(1,3,6)Y B(2,3,6))Y B(3,3,6))Y B(4,3,6))Y B(5,3,6)))O ((((B(1,4,6)Y B(2,4,6))Y B(3,4,6))Y B(4,4,6))Y B(5,4,6)))O ((((B(2,0,6)Y B(3,0,6))Y B(4,0,6))Y B(5,0,6))Y B(6,0,6))))

# %% [markdown]
# #### Victoria horizontal
#
# \begin{align*}
#     \bigvee^{f}_{x = b}(\bigwedge^{6}_{y = 2} N(x,y,10))
# \end{align*}
# \begin{align*}
#     \vee
# \end{align*}
# \begin{align*}
#     \bigvee^{f}_{x = b}(\bigwedge^{6}_{y = 2} B(x,y,10))
# \end{align*}

# %%
def ytoria_h_negras(f):
    Nc = 6
    inicial = True
    for c in range(1, Nc):
        if inicial:
            formula = cods_negras.N(f,c,10)
            inicial = False
        else:
            formula = cods_negras.N(f,c,10) + formula + 'Y'
    return formula

def victoria_horizontal_negras():
    Nf = 6
    inicial = True
    for f in range(1, Nf):
        if inicial:
            formula = ytoria_h_negras(f)
            inicial = False
        else:
            formula = ytoria_h_negras(f) + formula + 'O'
    return formula

def ytoria_h_blancas(f):
    Nc = 6
    inicial = True
    for c in range(1, Nc):
        if inicial:
            formula = cods_blancas.B(f,c,10)
            inicial = False
        else:
            formula = cods_blancas.B(f,c,10) + formula + 'Y'
    return formula

def victoria_horizontal_blancas():
    Nf = 6
    inicial = True
    for f in range(1, Nf):
        if inicial:
            formula = ytoria_h_blancas(f)
            inicial = False
        else:
            formula = ytoria_h_blancas(f) + formula + 'O'
    return formula


def victoria_horizontal():
    formula1 = victoria_horizontal_negras()
    formula2 = victoria_horizontal_blancas()
    formula = formula2 + formula1 + 'O'
    return formula

formula = victoria_horizontal()
A = String2Tree(formula)
print(Inorderp(A))
# Out:
# (((((((((N(1,2,3)Y N(1,3,3))Y N(1,4,3))Y N(2,0,3))Y N(2,1,3))O ((((N(2,2,3)Y N(2,3,3))Y N(2,4,3))Y N(3,0,3))Y N(3,1,3)))O ((((N(3,2,3)Y N(3,3,3))Y N(3,4,3))Y N(4,0,3))Y N(4,1,3)))O ((((N(4,2,3)Y N(4,3,3))Y N(4,4,3))Y N(5,0,3))Y N(5,1,3)))O ((((N(5,2,3)Y N(5,3,3))Y N(5,4,3))Y N(6,0,3))Y N(6,1,3)))O ((((((((B(1,2,3)Y B(1,3,3))Y B(1,4,3))Y B(2,0,3))Y B(2,1,3))O ((((B(2,2,3)Y B(2,3,3))Y B(2,4,3))Y B(3,0,3))Y B(3,1,3)))O ((((B(3,2,3)Y B(3,3,3))Y B(3,4,3))Y B(4,0,3))Y B(4,1,3)))O ((((B(4,2,3)Y B(4,3,3))Y B(4,4,3))Y B(5,0,3))Y B(5,1,3)))O ((((B(5,2,3)Y B(5,3,3))Y B(5,4,3))Y B(6,0,3))Y B(6,1,3))))

# %% [markdown]
# ### Regla 3:
#
# La **regla 3** es la union de todas las posibles victorias con una 'O':
#
# \begin{align*}
#     R3\_D1 \vee R3\_D2 \vee R3 \_ V \vee R3 \_ H
# \end{align*}
#
# Se gana con cinco piedras del mismo color seguidas en línea vertical, horizontal o diagonal.

# %%
def regla3():
    diagonal_1 = victoria_diagonal_1()
    diagonal_2 = victoria_diagonal_2()
    vertical = victoria_vertical()
    horizontal = victoria_horizontal()
    victoria = horizontal + vertical + 'O' + diagonal_2 + 'O' + diagonal_1 + 'O'
    return victoria

# %%
formula = regla3()
A = String2Tree(formula)
print(Inorderp(A))
# Out:
    for t2 in range(t+1, Nnumeros):
        if inicial :
            formula2 = cods_blancas.B(x,y,t2)
            inicial=False
        else:
            formula2 = cods_blancas.B(x,y,t2) + formula2 + "Y"
    formula2 = formula2 + cods_blancas.B(x,y,t) + ">"
    formula = formula2 + formula1 + "Y"
    return formula

# %%
formula = piedas_se_quedan(1,1,2)
A = String2Tree(formula)
print(Inorderp(A))
# Out:
# ((N(1,1,2)> (((N(1,1,3)Y N(1,1,4))Y N(1,1,5))Y N(1,1,6)))Y (B(1,1,2)> (((B(1,1,3)Y B(1,1,4))Y B(1,1,5))Y B(1,1,6))))

# %% [markdown]
# 4.2 La **regla 4** se conforma para todas las posibilidades del paso 4.1
#
# \begin{align*}
#      \bigwedge_{x = a}^{e} \bigwedge_{y = 0}^{4} \bigwedge_{t = 0}^{Nnumeros-1} \left( N(x,y,t) \rightarrow \bigwedge_{t'>t} N(x,y,t')\right) \wedge \left(B(x,y,t) \rightarrow \bigwedge_{t'>t}B(x,y,t')\right)
# \end{align*}
#
# Si hay una piedra en una posición del tablero, esta se queda ahí para el siguiente turno.

# %%
def regla4():
    inicial = True
    Nf = Nfilas
    Nc = Ncolumnas
    Nt = Nnumeros
    for f in range(Nf):
        for c in range(Nc): 
            for t in range(Nt-1):
                if inicial:
                    formula = piedas_se_quedan(f,c,t)
                    inicial = False
                else:
                    formula = piedas_se_quedan(f,c,t) + formula + 'Y'
    return formula

# %%
formula = regla4()
A = String2Tree(formula)
print(Inorderp(A))
# Out:
# (((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((N(0,0,0)> (((((N(0,0,1)Y N(0,0,2))Y N(0,0,3))Y N(0,0,4))Y N(0,0,5))Y N(0,0,6)))Y (B(0,0,0)> (((((B(0,0,1)Y B(0,0,2))Y B(0,0,3))Y B(0,0,4))Y B(0,0,5))Y B(0,0,6))))Y ((N(0,0,1)> ((((N(0,0,2)Y N(0,0,3))Y N(0,0,4))Y N(0,0,5))Y N(0,0,6)))Y (B(0,0,1)> ((((B(0,0,2)Y B(0,0,3))Y B(0,0,4))Y B(0,0,5))Y B(0,0,6)))))Y ((N(0,0,2)> (((N(0,0,3)Y N(0,0,4))Y N(0,0,5))Y N(0,0,6)))Y (B(0,0,2)> (((B(0,0,3)Y B(0,0,4))Y B(0,0,5))Y B(0,0,6)))))Y ((N(0,0,3)> ((N(0,0,4)Y N(0,0,5))Y N(0,0,6)))Y (B(0,0,3)> ((B(0,0,4)Y B(0,0,5))Y B(0,0,6)))))Y ((N(0,0,4)> (N(0,0,5)Y N(0,0,6)))Y (B(0,0,4)> (B(0,0,5)Y B(0,0,6)))))Y ((N(0,0,5)> N(0,0,6))Y (B(0,0,5)> B(0,0,6))))Y ((N(0,1,0)> (((((N(0,1,1)Y N(0,1,2))Y N(0,1,3))Y N(0,1,4))Y N(0,1,5))Y N(0,1,6)))Y (B(0,1,0)> (((((B(0,1,1)Y B(0,1,2))Y B(0,1,3))Y B(0,1,4))Y B(0,1,5))Y B(0,1,6)))))Y ((N(0,1,1)> ((((N(0,1,2)Y N(0,1,3))Y N(0,1,4))Y
B(0,3,5)> B(0,3,6))))Y ((N(0,4,0)> (((((N(0,4,1)Y N(0,4,2))Y N(0,4,3))Y N(0,4,4))Y N(0,4,5))Y N(0,4,6)))Y (B(0,4,0)> (((((B(0,4,1)Y B(0,4,2))Y B(0,4,3))Y B(0,4,4))Y B(0,4,5))Y B(0,4,6)))))Y ((N(0,4,1)> ((((N(0,4,2)Y N(0,4,3))Y N(0,4,4))Y N(0,4,5))Y N(0,4,6)))Y (B(0,4,1)> ((((B(0,4,2)Y B(0,4,3))Y B(0,4,4))Y B(0,4,5))Y B(0,4,6)))))Y ((N(0,4,2)> (((N(0,4,3)Y N(0,4,4))Y N(0,4,5))Y N(0,4,6)))Y (B(0,4,2)> (((B(0,4,3)Y B(0,4,4))Y B(0,4,5))Y B(0,4,6)))))Y ((N(0,4,3)> ((N(0,4,4)Y N(0,4,5))Y N(0,4,6)))Y (B(0,4,3)> ((B(0,4,4)Y B(0,4,5))Y B(0,4,6)))))Y ((N(0,4,4)> (N(0,4,5)Y N(0,4,6)))Y (B(0,4,4)> (B(0,4,5)Y B(0,4,6)))))Y ((N(0,4,5)> N(0,4,6))Y (B(0,4,5)> B(0,4,6))))Y ((N(1,0,0)> (((((N(1,0,1)Y N(1,0,2))Y N(1,0,3))Y N(1,0,4))Y N(1,0,5))Y N(1,0,6)))Y (B(1,0,0)> (((((B(1,0,1)Y B(1,0,2))Y B(1,0,3))Y B(1,0,4))Y B(1,0,5))Y B(1,0,6)))))Y ((N(1,0,1)> ((((N(1,0,2)Y N(1,0,3))Y N(1,0,4))Y N(1,0,5))Y N(1,0,6)))Y (B(1,0,1)> ((((B(1,0,2)Y B(1,0,3))Y B(1,0,4))Y B(1,0,5))Y B(1,0,6)))))Y ((N(1,0,2)> (((N(1,0,3)Y N(1,0,4))Y N(1,0,5))Y N(1,0,6)))Y (B(1,0,2)> (((B(1,0,3)Y B(1,0,4))Y B(1,0,5))Y B(1,0,6)))))Y ((N(1,0,3)> ((N(1,0,4)Y N(1,0,5))Y N(1,0,6)))Y (B(1,0,3)> ((B(1,0,4)Y B(1,0,5))Y B(1,0,6)))))Y ((N(1,0,4)> (N(1,0,5)Y N(1,0,6)))Y (B(1,0,4)> (B(1,0,5)Y B(1,0,6)))))Y ((N(1,0,5)> N(1,0,6))Y (B(1,0,5)> B(1,0,6))))Y  ...

# %% [markdown]
# ### (Por evaluar) regla 5:
#
# \begin{align*}
#     \bigwedge_{t = 2}^{25} \bigwedge_{x = b}^{f} \bigwedge_{y = 2}^{6} ( \left( \neg(N(x,y,t-1) \vee B(x,y,t-1)) \wedge (N(x,y,t) \vee B(x,y,t)) \right) \rightarrow \bigwedge_{(u,v) \neq (x,y)} \neg (N(u,v,t-1) \vee B(u,v,t-1)) \rightarrow  \neg (N(u,v,t) \vee B(u,v,t)))
# \end{align*}

# %% [markdown]
# Se coloca una piedra a la vez en cada ronda.

# %% [markdown]
# ## Visualización de una solución
#
# Para representar el problema del go-moku descrito anteriormente, es necesario construir la función que dibuje las posibilidades de juego.
#
#
# <img src="img/gomoku.jpg" alt="drawing" width="350"/>

# %%
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.offsetbox import AnnotationBbox, OffsetImage
import time
from IPython.display import clear_output
import warnings
# %matplotlib inline

# %%
def tablero(f, T):

    #Dibuja las cuadriculas coordenadas dada una formula f
    #Input: 
        # - f : es un diccionario con literales y sus valores de verdad.
    #Output:
        # tablero.
    
    # Dibujo el tablero
    fig, axes= plt.subplots()
    plt.xticks(np.arange(0, 1, 0.165), ["-","a","b","c","d","e","-"])
    plt.yticks(np.arange(0, 1, 0.165), range(-1,6))
    
    axes.get_xaxis().set_visible(True)
    axes.get_yaxis().set_visible(True)
    
    axes.set_facecolor('peachpuff') # color del fondo
    
    step = 1./6
    cuadrados = []
    
    # Creo las líneas del tablero
    for j in range(14): #Determina que sea un tablero 6x6, con lineas 7x7
        locacion = j * step
        # Crea linea horizontal en el rectangulo
        cuadrados.append(patches.Rectangle(*[(0, step + locacion), 1, 0.005],\
                facecolor='black'))
        # Crea linea vertical en el rectangulo
        cuadrados.append(patches.Rectangle(*[(step + locacion, 0), 0.005, 1],\
                facecolor='black'))
    
    # crea el tablero
    for t in cuadrados:
        axes.add_patch(t)
    
    
    # PARA CHEQUEAR LAS INTERSECCIONES USADAS
    intersecciones_usadas = []
    
    for i in f.keys():
        
        if ord(i) < 2001 :
            fila, columna, turno = cods_negras.Ninv(i)
            p_negra = plt.imread("img/p_negra.png", format='png')
            imagebox = OffsetImage(p_negra, zoom=0.1)
        else:
            fila, columna, turno = cods_blancas.Binv(i)
            p_blanca = plt.imread("img/p_blanca.png", format= "png")
            imagebox = OffsetImage(p_blanca, zoom = 0.1)

        # CHEQUEANDO SI YA SE USÓ LA INTERSECCIÓN
        if (fila,columna) in intersecciones_usadas :
            pass
            #warnings.warn(u"Error: intersección repetida" + str((fila,columna)))
        else:
            intersecciones_usadas.append((fila,columna))
                               
        imagebox.image.axes = axes
        ab = AnnotationBbox(imagebox, [(columna+1)*1./6, (fila+1)*1./6], frameon=False)
        axes.add_artist(ab)
    
    axes.set_title("Turno: " + str(T))
    
    return axes

# AÑADÍ ESTA FUNCIÓN

def jugadas(f) :
    turnos = []
    for k in f.keys() :
        if ord(k) < 2001 :
            fila, columna, turno = cods_negras.Ninv(k)
        else:
            fila, columna, turno = cods_blancas.Binv(k)
        turnos.append(turno)
    
    turnos = list(set(turnos)) # PARA ELIMINAR REPETICIONES
    Nturnos = max(turnos) + 1
    print("Cantidad de turnos a dibujar:", Nturnos)
    gran_diccionario = {t:{} for t in turnos}
    for k in f.keys() :
        if ord(k) < 2001 :
            fila, columna, turno = cods_negras.Ninv(k)
        else:
            fila, columna, turno = cods_blancas.Binv(k)
        gran_diccionario[turno][k] = 1 
    
    I = {}
    for t in turnos :
        clear_output(wait=True)
        I.update(gran_diccionario[t])
        tablero(I, t)
        plt.show()
        time.sleep(.5)

# %%
def decod_jugadas(I) :
    jugs = []
    letras = ['a','b','c','d','e']
    for k in I.keys() :
        if ord(k) < 2001 :
            fila,c,turno=cods_negras.Ninv(k)
            columna = letras[c]
            jugs.append((fila,columna,turno,'Negras'))
        else:
            fila,c,turno=cods_blancas.Binv(k)
            columna = letras[c]
            jugs.append((fila,columna,turno,'Blancas'))
    
    jugs = sorted(jugs, key=lambda x: x[3])
    jugs = sorted(jugs, key=lambda x: x[2])

    
    return jugs

# %%
I = {}
I[cods_negras.N(1,1,0)] = 1

# %%
decod_jugadas(I)
# Out:
# [(1, 'b', 0, 'Negras')]

# %%
tablero(I, 0)
# Out:
# <AxesSubplot:title={'center':'Turno: 0'}>

# %%
I = {}
#I[cods_negras.N(1,1,0)] = 1 
I[cods_blancas.B(1,2,1)] = 1 
I[cods_negras.N(2,3,2)] = 1 
decod_jugadas(I)
# Out:
# [(1, 'c', 1, 'Blancas'), (2, 'd', 2, 'Negras')]

# %%
jugadas(I)

# %%
I = {}
#I[cods_negras.N(1,1,0)] = 1 
I[cods_blancas.B(1,2,1)] = 1 
I[cods_negras.N(2,3,2)] = 1
I[cods_blancas.B(0,2,3)] = 1 
I[cods_negras.N(0,3,4)] = 1 
I[cods_blancas.B(1,3,5)] = 1 
I[cods_negras.N(2,4,6)] = 1 
decod_jugadas(I)
# Out:
# [(1, 'c', 1, 'Blancas'),
#  (2, 'd', 2, 'Negras'),
#  (0, 'c', 3, 'Blancas'),
#  (0, 'd', 4, 'Negras'),
#  (1, 'd', 5, 'Blancas'),
#  (2, 'e', 6, 'Negras')]

# %%
jugadas(I)

# %% [markdown]
# ## Algoritmo de transformacion de Tseitin

# %%
# Subrutinas para la transformacion de una
# formula a su forma clausal

def enFNC(A):
    # Subrutina de Tseitin para encontrar la FNC de
    # la formula en la pila
    # Input: A (cadena) de la forma
    #                   p=-q
    #                   p=(qYr)
    #                   p=(qOr)
    #                   p=(q>r)
    # Output: B (cadena), equivalente en FNC
    assert(len(A)==4 or len(A)==7), u"Fórmula incorrecta! " + A
    B = ''
    p = A[0]
    # print('p', p)
    if "-" in A:
        q = A[-1]
        # print('q', q)
        B = "-"+p+"O-"+q+"Y"+p+"O"+q
    elif "Y" in A:
        q = A[3]
        # print('q', q)
        r = A[5]
        # print('r', r)
        B = q+"O-"+p+"Y"+r+"O-"+p+"Y-"+q+"O-"+r+"O"+p
    elif "O" in A:
        q = A[3]
        # print('q', q)
        r = A[5]
        # print('r', r)
        B = "-"+q+"O"+p+"Y-"+r+"O"+p+"Y"+q+"O"+r+"O-"+p
    elif ">" in A:
        q = A[3]
        # print('q', q)
        r = A[5]
        # print('r', r)
        B = q+"O"+p+"Y-"+r+"O"+p+"Y-"+q+"O"+r+"O-"+p
    elif "=" in A:
        q = A[3]
        # print('q', q)
        r = A[5]
        # print('r', r)
        B = q+"O"+"-"+r+"O"+"-"+p+"Y"+"-"+q+"O"+r+"O"+"-"+p+"Y"+"-"+q+"O"+"-"+r+"O"+p+"Y"+q+"O"+r+"O"+p
    else:
        print(u'Error enENC(): Fórmula incorrecta!')

    return B

# Algoritmo de transformacion de Tseitin
# Input: A (cadena) en notacion inorder
# Output: B (cadena), Tseitin
def Tseitin(A, letrasProposicionalesNegrasBlancas):
    
    letrasProposicionalesOtro = [chr(x) for x in range(3746,7290)]
    
    assert(not bool(set(letrasProposicionalesNegrasBlancas) & set(letrasProposicionalesOtro))), u"¡Hay letras proposicionales en común!"

    letrasProposicionales = letrasProposicionalesNegrasBlancas + letrasProposicionalesOtro

    l = [] #lista de conjuciones
    pila = [] #pila
    i = -1  #contador de variables nuevas
    s = A[0] #simbolo de trabajp

    while(len(A) > 0):
        if ((s in letrasProposicionales) and (len(pila) != 0) and (pila[-1] == '-')):
            i += 1
            atomo = letrasProposicionalesOtro[i]
            pila = pila[:-1]
            pila.append(atomo)
            l.append(atomo + "=" + "-" + s)
            A = A[1:]

            if (len(A) > 0):
                s = A[0]

        elif (s == ')'):
            w = pila[-1]
            u = pila[-2]
            v = pila[-3]
            pila = pila[:len(pila)-4]
            i += 1
            atomo = letrasProposicionalesOtro[i]
            l.append(atomo + "=" + '(' + v + u + w + ')')
            s = atomo

        else:
            pila.append(s)
            A = A[1:]

            if (len(A) > 0):
                s = A[0]

    B= ''

    if (i < 0):
        atomo = pila[-1]

    else:
        atomo = letrasProposicionalesOtro[i]

    for x in l:
        y = enFNC(x)
        B += "Y" + y

    B = atomo + B

    return B

# Subrutina Clausula para obtener lista de literales
# Input: C (cadena) una clausula
# Output: L (lista), lista de literales
# Se asume que cada literal es un solo caracter
def Clausula(C):

    #  IMPLEMENTAR AQUI ALGORITMO CLAUSULA
    L = [] #lista de literales
    while(len(C) > 0):
        s = C[0]

        if (s == '-'):
            print(C)
            L.append(s + C[1])
            C = C[3:]

        else:
            L.append(s)
            C = C[2:]

    return L


# Algoritmo para obtencion de forma clausal
# Input: A (cadena) en notacion inorder en FNC
# Output: L (lista), lista de listas de literales
def formaClausal(A):

    #  IMPLEMENTAR AQUI ALGORITMO FORMA CLAUSAL
    l = []
    i = 0

    while(len(A) > 0):
        if i >= len(A):
                l.append(Clausula(A))
                A = []
        else:
            if A[i] == 'Y':
                l.append(Clausula(A[:i]))
                A = A[i+1:]
                i = 0
            else:
                i += 1

    return l

# %%
def complemento(letra):
    if len(letra) == 1:
        complemento = '-' + letra
        return complemento

    elif (len(letra) > 1):
        if (letra[0] == '-'):
            return letra[1]

    else:
        raise(f"error, literal invalido {letra}")

def hay_unidad(S):

    for x in S:
        if len(x) == 1:
            return x[0]
    return None

def unit_propagate(S, I):

    unidad = hay_unidad(S)
    while ([] not in S) and (unidad != None):
        Comple = complemento(unidad)
        S = [c for c in S if unidad not in c]
        count = 0
        for c in S:
            if Comple in c:
                c = [x for x in c if x != Comple]
                S[count] = c
            count += 1

        if '-' in unidad:
            I[unidad] = 0
        else:
            I[unidad] = 1
        unidad = hay_unidad(S)
    return S, I

def DPLL(S,I):
    S, I = unit_propagate(S,I)

    if [] in S:
        return "Insatisfacible", {}
    elif len(S) == 0:
        return "Satisfacible", I

    else:

        l = S[0][0]
        S2 = [x for x in S if l not in x]
        Comple = complemento(l)
        count = 0
        for c in S2:
            if Comple in c:
                c = [x for x in c if x != Comple]
                S2[count] = c
            count += 1
        count = 0
        # print("S2 = ", S2)
        I2 = I

        if len(l)==1:
            I2[l] = 1
        else:
            I2[l[1]] = 0

        conj2, interp2 = DPLL(S2,I2)

        if (conj2 == "Satisfacible") and (interp2 == I2):
            return conj2, interp2


        for x in S:
            for p in x:
                if p not in I.keys():
                    l = p
                    break
        Comple = complemento(l)
        S3 = [x for x in S if Comple not in x]
        count = 0

        for c in S3:
            if l in c:
                c = [x for x in c if x != l]
                S3[count] = c
            count += 1
        count = 0

        I3 = I
        if len(l)==1:
            I3[l] = 0
        else:
            I3[l[1]] = 1
        return DPLL(S3, I3)

# %% [markdown]
# ## Prueba de reglas

# %% [markdown]
# ### Prueba de regla 1:
#
# La primera piedra en ser colocada en el tablero, debe ser una piedra negra, no hay restricción en cual intersección puede ser colocada.

# %%
R1 = regla1()
formula_polacaI = R1 
formula_inorder = Inorder(String2Tree(formula_polacaI))
print("Corriendo Tseitin...")
T = Tseitin(formula_inorder, letrasProposicionales)
formula = formaClausal(T)
print("Corriendo DPLL...")
prueba_DPLL = DPLL(formula,{})
print(prueba_DPLL[0])
I = {}
for k in letrasProposicionales:
    if k in prueba_DPLL[1].keys():
        I[k] = prueba_DPLL[1][k]
# Out:
# Corriendo Tseitin...
# -ĀOຢ
# -ćOຢ
# -ຢ
# -ຢOຣ
# -ĎOຣ
# -ຣ
# -ຣO຤
# -ĕO຤
# -຤
# -຤Oລ
# -ĜOລ
# -ລ
# -ລO຦
# -ģO຦
# -຦
# -຦Oວ
# -ĪOວ
# -ວ
# -ວOຨ
# -ıOຨ
# -ຨ
# -ຨOຩ
# -ĸOຩ
# -ຩ
# -ຩOສ
# -ĿOສ
# -ສ
# -ສOຫ
# -ņOຫ
# -ຫ
# -ຫOຬ
# -ōOຬ
# -ຬ
# -ຬOອ
# -ŔOອ
# -ອ
# -ອOຮ
# -śOຮ
# -ຮ
# -ຮOຯ
# -ŢOຯ
# -ຯ
# -ຯOະ
# -ũOະ
# -ະ
# -ະOັ
# -ŰOັ
# -ັ
# -ັOາ
# -ŷOາ
# -າ
# -າOຳ
# -žOຳ
# -ຳ
# -ຳOິ
# -ƅOິ
# -ິ
# -ິOີ
# -ƌOີ
# -ີ
# -ີOຶ
# -ƓOຶ
# -ຶ
# -ຶOື
# -ƚOື
# -ື
# -ືOຸ
# -ơOຸ
# -ຸ
# -ຸOູ
# -ƨOູ
# -ູ
# -຺O-ߑ
# -ߑ
# -ົO-ߘ
# -ߘ
# -ຼ
# -ຼ
# -຺O-ົOຼ
# -ົOຼ
# -ຽO-ߟ
# -ߟ
# -຾
# -຾
# -ຼO-ຽO຾
# -ຽO຾
# -຿O-ߦ
# -ߦ
# -ເ
# -ເ
# -຾O-຿Oເ
# -຿Oເ
# -ແO-߭
# -߭
# -ໂ
# -ໂ
# -ເO-ແOໂ
# -ແOໂ
# -ໃO-ߴ
# -ߴ
# -ໄ
# -ໄ
# -ໂO-ໃOໄ
# -ໃOໄ
# -໅O-߻
# -߻
# -ໆ
# -ໆ
# -ໄO-໅Oໆ
# -໅Oໆ
# -໇O-ࠂ
# -ࠂ
# -່
# -່
# -ໆO-໇O່
# -໇O່
# -້O-ࠉ
# -ࠉ
# -໊
# -໊
# -່O-້O໊
# -້O໊
# -໋O-ࠐ
# -ࠐ
# -໌
# -໌
# -໊O-໋O໌
# -໋O໌
# -ໍO-ࠗ
# -ࠗ
# -໎
# -໎
# -໌O-ໍO໎
# -ໍO໎
# -໏O-ࠞ
# -ࠞ
# -໐
# -໐
# -໎O-໏O໐
# -໏O໐
# -໑O-ࠥ
# -ࠥ
# -໒
# -໒
# -໐O-໑O໒
# -໑O໒
# -໓O-ࠬ
# -ࠬ
# -໔
# -໔
# -໒O-໓O໔
# -໓O໔
# -໕O-࠳
# -࠳
# -໖
# -໖
# -໔O-໕O໖
# -໕O໖
# -໗O-࠺
# -࠺
# -໘
# -໘
# -໖O-໗O໘
# -໗O໘
# -໙O-ࡁ
# -ࡁ
# -໚
# -໚
# -໘O-໙O໚
# -໙O໚
# -໛O-ࡈ
# -ࡈ
# -ໜ
# -ໜ
# -໚O-໛Oໜ
# -໛Oໜ
# -ໝO-ࡏ
# -ࡏ
# -ໞ
# -ໞ
# -ໜO-ໝOໞ
# -ໝOໞ
# -ໟO-ࡖ
# -ࡖ
# -໠
# -໠
# -ໞO-ໟO໠
# -ໟO໠
# -໡O-࡝
# -࡝
# -໢
# -໢
# -໠O-໡O໢
# -໡O໢
# -໣O-ࡤ
# -ࡤ
# -໤
# -໤
# -໢O-໣O໤
# -໣O໤
# -໥O-࡫
# -࡫
# -໦
# -໦
# -໤O-໥O໦
# -໥O໦
# -໧O-ࡲ
# -ࡲ
# -໨
# -໨
# -໦O-໧O໨
# -໧O໨
# -໩O-ࡹ
# -ࡹ
# -໪
# -໪
# -໨O-໩O໪
# -໩O໪
# -໫O-ć
# -ć
# -໬O-Ď
# -Ď
# -໭
# -໭
# -໫O-໬O໭
# -໬O໭
# -໮O-ĕ
# -ĕ
# -໯
# -໯
# -໭O-໮O໯
# -໮O໯
# -໰O-Ĝ
# -Ĝ
# -໱
# -໱
# -໯O-໰O໱
# -໰O໱
# -໲O-ģ
# -ģ
# -໳
# -໳
# -໱O-໲O໳
# -໲O໳
# -໴O-Ī
# -Ī
# -໵
# -໵
# -໳O-໴O໵
# -໴O໵
# -໶O-ı
# -ı
# -໷
# -໷
# -໵O-໶O໷
# -໶O໷
# -໸O-ĸ
# -ĸ
# -໹
# -໹
# -໷O-໸O໹
# -໸O໹
# -໺O-Ŀ
# -Ŀ
# -໻
# -໻
# -໹O-໺O໻
# -໺O໻
# -໼O-ņ
# -ņ
# -໽
# -໽
# -໻O-໼O໽
# -໼O໽
# -໾O-ō
# -ō
# -໿
# -໿
# -໽O-໾O໿
# -໾O໿
# -ༀO-Ŕ
# -Ŕ
# -༁
# -༁
# -໿O-ༀO༁
# -ༀO༁
# -༂O-ś
# -ś
# -ƅ
# -႖
# -႖
# -႔O-႕O႖
# -႕O႖
# -႗O-ƌ
# -ƌ
# -႘
# -႘
# -႖O-႗O႘
# -႗O႘
# -႙O-Ɠ
# -Ɠ
# -ႚ
# -ႚ
# -႘O-႙Oႚ
# -႙Oႚ
# -ႛO-ƚ
# -ƚ
# -ႜ
# -ႜ
# -ႚO-ႛOႜ
# -ႛOႜ
# -ႝO-ơ
# -ơ
# -႞
# -႞
# -ႜO-ႝO႞
# -ႝO႞
# -႟O-ƨ
# -ƨ
# -Ⴀ
# -Ⴀ
# -႞O-႟OႠ
# -႟OႠ
# -ႠOႡ
# -ĸOႠO-Ⴁ
# -Ⴁ
# -Ⴂ
# -Ⴂ
# -ၱO-ႡOႢ
# -ႡOႢ
# -ႣO-Ā
# -Ā
# -ႤO-ć
# -ć
# -Ⴅ
# -Ⴅ
# -ႣO-ႤOႥ
# -ႤOႥ
# -ႦO-Ď
# -Ď
# -Ⴇ
# -Ⴇ
# -ႥO-ႦOႧ
# -ႦOႧ
# -ႨO-ĕ
# -ĕ
# -Ⴉ
# -Ⴉ
# -ႧO-ႨOႩ
# -ႨOႩ
# -ႪO-Ĝ
# -Ĝ
# -Ⴋ
# -Ⴋ
# -ႩO-ႪOႫ
# -ႪOႫ
# -ႬO-ģ
# -ģ
# -Ⴍ
# -Ⴍ
# -ႫO-ႬOႭ
# -ႬOႭ
# -ႮO-Ī
# -Ī
# -Ⴏ
# -Ⴏ
# -ႭO-ႮOႯ
# -ႮOႯ
# -ႰO-ı
# -ı
# -Ⴑ
# -Ⴑ
# -ႯO-ႰOႱ
# -ႰOႱ
# -ႲO-ĸ
# -ĸ
# -Ⴓ
# -Ⴓ
# -ႱO-ႲOႳ
# -ႲOႳ
# -ႴO-ņ
# -ņ
# -Ⴕ
# -Ⴕ
# -ႳO-ႴOႵ
# -ႴOႵ
# -ႶO-ō
# -ō
# -Ⴗ
# -Ⴗ
# -ႵO-ႶOႷ
# -ႶOႷ
# -ႸO-Ŕ
# -Ŕ
# -Ⴙ
# -Ⴙ
# -ႷO-ႸOႹ
# -ႸOႹ
# -ႺO-ś
# -ś
# -Ⴛ
# -Ⴛ
# -ႹO-ႺOႻ
# -ႺOႻ
# -ႼO-Ţ
# -Ţ
# -Ⴝ
# -Ⴝ
# -ႻO-ႼOႽ
# -ႼOႽ
# -ႾO-ũ
# -ũ
# -Ⴟ
# -Ⴟ
# -ႽO-ႾOႿ
# -ႾOႿ
# -ჀO-Ű
# -Ű
# -Ⴡ
# -Ⴡ
# -ႿO-ჀOჁ
# -ჀOჁ
# -ჂO-ŷ
# -ŷ
# -Ⴣ
# -Ⴣ
# -ჁO-ჂOჃ
# -ჂOჃ
# -ჄO-ž
# -ž
# -Ⴥ
# -Ⴥ
# -ჃO-ჄOჅ
# -ჄOჅ
# -჆O-ƅ
# -ƅ
# -Ⴧ
# -Ⴧ
# -ჅO-჆OჇ
# -჆OჇ
# -჈O-ƌ
# -ƌ
# -჉
# -჉
# -ჇO-჈O჉
# -ጄOጅ
# -ጆO-Ŕ
# -Ŕ
# -ጇ
# -ጇ
# -ጅO-ጆOጇ
# -ጆOጇ
# -ገO-ś
# -ś
# -ጉ
# -ጉ
# -ጇO-ገOጉ
# -ገOጉ
# -ጊO-Ţ
# -Ţ
# -ጋ
# -ጋ
# -ጉO-ጊOጋ
# -ጊOጋ
# -ጌO-ũ
# -ũ
# -ግ
# -ግ
# -ጋO-ጌOግ
# -ጌOግ
# -ጎO-Ű
# -Ű
# -ጏ
# -ጏ
# -ግO-ጎOጏ
# -ጎOጏ
# -ጐO-ŷ
# -ŷ
# -጑
# -጑
# -ጏO-ጐO጑
# -ጐO጑
# -ጒO-ž
# -ž
# -ጓ
# -ጓ
# -጑O-ጒOጓ
# -ጒOጓ
# -ጔO-ƅ
# -ƅ
# -ጕ
# -ጕ
# -ጓO-ጔOጕ
# -ጔOጕ
# -጖O-ƌ
# -ƌ
# -጗
# -጗
# -ጕO-጖O጗
# -጖O጗
# -ጘO-ƚ
# -ƚ
# -ጙ
# -ጙ
# -጗O-ጘOጙ
# -ጘOጙ
# -ጚO-ơ
# -ơ
# -ጛ
# -ጛ
# -ጙO-ጚOጛ
# -ጚOጛ
# -ጜO-ƨ
# -ƨ
# -ጝ
# -ጝ
# -ጛO-ጜOጝ
# -ጜOጝ
# -ጝOጞ
# -ƓOጝO-ጞ
# -ጞ
# -ጟ
# -ጟ
# -ዮO-ጞOጟ
# -ጞOጟ
# -ጠO-Ā
# -Ā
# -ጡO-ć
# -ć
# -ጢ
# -ጢ
# -ጠO-ጡOጢ
# -ጡOጢ
# -ጣO-Ď
# -Ď
# -ጤ
# -ጤ
# -ጢO-ጣOጤ
# -ጣOጤ
# -ጥO-ĕ
# -ĕ
# -ጦ
# -ጦ
# -ጤO-ጥOጦ
# -ጥOጦ
# -ጧO-Ĝ
# -Ĝ
# -ጨ
# -ጨ
# -ጦO-ጧOጨ
# -ጧOጨ
# -ጩO-ģ
# -ģ
# -ጪ
# -ጪ
# -ጨO-ጩOጪ
# -ጩOጪ
# -ጫO-Ī
# -Ī
# -ጬ
# -ጬ
# -ጪO-ጫOጬ
# -ጫOጬ
# -ጭO-ı
# -ı
# -ጮ
# -ጮ
# -ጬO-ጭOጮ
# -ጭOጮ
# -ጯO-ĸ
# -ĸ
# -ጰ
# -ጰ
# -ጮO-ጯOጰ
# -ጯOጰ
# -ጱO-Ŀ
# -Ŀ
# -ጲ
# -ጲ
# -ጰO-ጱOጲ
# -ጱOጲ
# -ጳO-ņ
# -ņ
# -ጴ
# -ጴ
# -ጲO-ጳOጴ
# -ጳOጴ
# -ጵO-ō
# -ō
# -ጶ
# -ጶ
# -ጴO-ጵOጶ
# -ጵOጶ
# -ጷO-Ŕ
# -Ŕ
# -ጸ
# -ጸ
# -ጶO-ጷOጸ
# -ጷOጸ
# -ጹO-ś
# -ś
# -ጺ
# -ጺ
# -ጸO-ጹOጺ
# -ጹOጺ
# -ጻO-Ţ
# -Ţ
# -ጼ
# -ጼ
# -ጺO-ጻOጼ
# -፶O፷
# -፸O-ƌ
# -ƌ
# -፹
# -፹
# -፷O-፸O፹
# -፸O፹
# -፺O-Ɠ
# -Ɠ
# -፻
# -፻
# -፹O-፺O፻
# -፺O፻
# -፼O-ƚ
# -ƚ
# -፽
# -፽
# -፻O-፼O፽
# -፼O፽
# -፾O-ƨ
# -ƨ
# -፿
# -፿
# -፽O-፾O፿
# -፾O፿
# -፿Oᎀ
# -ơO፿O-ᎀ
# -ᎀ
# -ᎁ
# -ᎁ
# -ፐO-ᎀOᎁ
# -ᎀOᎁ
# -ᎂO-Ā
# -Ā
# -ᎃO-ć
# -ć
# -ᎄ
# -ᎄ
# -ᎂO-ᎃOᎄ
# -ᎃOᎄ
# -ᎅO-Ď
# -Ď
# -ᎆ
# -ᎆ
# -ᎄO-ᎅOᎆ
# -ᎅOᎆ
# -ᎇO-ĕ
# -ĕ
# -ᎈ
# -ᎈ
# -ᎆO-ᎇOᎈ
# -ᎇOᎈ
# -ᎉO-Ĝ
# -Ĝ
# -ᎊ
# -ᎊ
# -ᎈO-ᎉOᎊ
# -ᎉOᎊ
# -ᎋO-ģ
# -ģ
# -ᎌ
# -ᎌ
# -ᎊO-ᎋOᎌ
# -ᎋOᎌ
# -ᎍO-Ī
# -Ī
# -ᎎ
# -ᎎ
# -ᎌO-ᎍOᎎ
# -ᎍOᎎ
# -ᎏO-ı
# -ı
# -᎐
# -᎐
# -ᎎO-ᎏO᎐
# -ᎏO᎐
# -᎑O-ĸ
# -ĸ
# -᎒
# -᎒
# -᎐O-᎑O᎒
# -᎑O᎒
# -᎓O-Ŀ
# -Ŀ
# -᎔
# -᎔
# -᎒O-᎓O᎔
# -᎓O᎔
# -᎕O-ņ
# -ņ
# -᎖
# -᎖
# -᎔O-᎕O᎖
# -᎕O᎖
# -᎗O-ō
# -ō
# -᎘
# -᎘
# -᎖O-᎗O᎘
# -᎗O᎘
# -᎙O-Ŕ
# -Ŕ
# -᎚
# -᎚
# -᎘O-᎙O᎚
# -᎙O᎚
# -᎛O-ś
# -ś
# -᎜
# -᎜
# -᎚O-᎛O᎜
# -᎛O᎜
# -᎝O-Ţ
# -Ţ
# -᎞
# -᎞
# -᎜O-᎝O᎞
# -᎝O᎞
# -᎟O-ũ
# -ũ
# -Ꭰ
# -Ꭰ
# -᎞O-᎟OᎠ
# -᎟OᎠ
# -ᎡO-Ű
# -Ű
# -Ꭲ
# -Ꭲ
# -ᎠO-ᎡOᎢ
# -ᎡOᎢ
# -ᎣO-ŷ
# -ŷ
# -Ꭴ
# -Ꭴ
# -ᎢO-ᎣOᎤ
# -ᎣOᎤ
# -ᎥO-ž
# -ž
# -Ꭶ
# -Ꭶ
# -ᎤO-ᎥOᎦ
# -ᎥOᎦ
# -ᎧO-ƅ
# -ƅ
# -Ꭸ
# -Ꭸ
# -ᎦO-ᎧOᎨ
# -ᎧOᎨ
# -ᎩO-ƌ
# -ƌ
# -Ꭺ
# -Ꭺ
# -ᎨO-ᎩOᎪ
# -ᎩOᎪ
# -ᎫO-Ɠ
# -Ɠ
# -Ꭼ
# -Ꭼ
# -ᎪO-ᎫOᎬ
# -ᎫOᎬ
# -ᎭO-ƚ
# -ƚ
# -Ꭾ
# -Ꭾ
# -ᎬO-ᎭOᎮ
# -ᎭOᎮ
# -ᎯO-ơ
# -ơ
# -Ꮀ
# -Ꮀ
# -ᎮO-ᎯOᎰ
# -ᎯOᎰ
# -ᎰOᎱ
# -ƨOᎰO-Ꮁ
# -Ꮁ
# -Ꮂ
# -Ꮂ
# -ᎁO-ᎱOᎲ
# -ᎱOᎲ
# -Ꮃ
# -Ꮃ
# -໪O-ᎲOᎳ
# -ᎲOᎳ
# -Ꮄ
# -Ꮄ
# -ູO-ᎳOᎴ
# -ᎳOᎴ
# Corriendo DPLL...
# Satisfacible

# %%
jugadas(I)

# %% [markdown]
# ### Prueba de regla 2:
#
# No puede haber más de una piedra en cada intersección, sin importar el color que está.

# %%
R2 = regla2()
formula_polacaI = R2 
formula_inorder = Inorder(String2Tree(formula_polacaI))
print("Corriendo Tseitin...")
T = Tseitin(formula_inorder, letrasProposicionales)
formula = formaClausal(T)
print("Corriendo DPLL...")
prueba_DPLL = DPLL(formula,{})
print(prueba_DPLL[0])
I = {}
for k in letrasProposicionales:
    if k in prueba_DPLL[1].keys():
        I[k] = prueba_DPLL[1][k]
# Out:
# Corriendo Tseitin...
# -ຢO-ߑ
# -ߑ
# -ຢOຣ
# -ĀOຢO-ຣ
# -ຣ
# -຤O-Ā
# -Ā
# -຤Oລ
# -ߑO຤O-ລ
# -ລ
# -຦
# -຦
# -ຣO-ລO຦
# -ລO຦
# -ວO-ߒ
# -ߒ
# -ວOຨ
# -āOວO-ຨ
# -ຨ
# -ຩO-ā
# -ā
# -ຩOສ
# -ߒOຩO-ສ
# -ສ
# -ຫ
# -ຫ
# -ຨO-ສOຫ
# -ສOຫ
# -ຬ
# -ຬ
# -຦O-ຫOຬ
# -ຫOຬ
# -ອO-ߓ
# -ߓ
# -ອOຮ
# -ĂOອO-ຮ
# -ຮ
# -ຯO-Ă
# -Ă
# -ຯOະ
# -ߓOຯO-ະ
# -ະ
# -ັ
# -ັ
# -ຮO-ະOັ
# -ະOັ
# -າ
# -າ
# -ຬO-ັOາ
# -ັOາ
# -ຳO-ߔ
# -ߔ
# -ຳOິ
# -ăOຳO-ິ
# -ິ
# -ີO-ă
# -ă
# -ີOຶ
# -ߔOີO-ຶ
# -ຶ
# -ື
# -ື
# -ິO-ຶOື
# -ຶOື
# -ຸ
# -ຸ
# -າO-ືOຸ
# -ືOຸ
# -ູO-ߕ
# -ߕ
# -ູO຺
# -ĄOູO-຺
# -຺
# -ົO-Ą
# -Ą
# -ົOຼ
# -ߕOົO-ຼ
# -ຼ
# -ຽ
# -ຽ
# -຺O-ຼOຽ
# -ຼOຽ
# -຾
# -຾
# -ຸO-ຽO຾
# -ຽO຾
# -຿O-ߖ
# -ߖ
# -຿Oເ
# -ąO຿O-ເ
# -ເ
# -ແO-ą
# -ą
# -ແOໂ
# -ߖOແO-ໂ
# -ໂ
# -ႃOႄ
# -ࠡOႃO-ႄ
# -ႄ
# -ႅ
# -ႅ
# -ႂO-ႄOႅ
# -ႄOႅ
# -ႆ
# -ႆ
# -ႀO-ႅOႆ
# -ႅOႆ
# -ႇO-ࠢ
# -ࠢ
# -ႇOႈ
# -őOႇO-ႈ
# -ႈ
# -ႉO-ő
# -ő
# -ႉOႊ
# -ࠢOႉO-ႊ
# -ႊ
# -ႋ
# -ႋ
# -ႈO-ႊOႋ
# -ႊOႋ
# -ႌ
# -ႌ
# -ႆO-ႋOႌ
# -ႋOႌ
# -ႍO-ࠣ
# -ࠣ
# -ႍOႎ
# -ŒOႍO-ႎ
# -ႎ
# -ႏO-Œ
# -Œ
# -ႏO႐
# -ࠣOႏO-႐
# -႐
# -႑
# -႑
# -ႎO-႐O႑
# -႐O႑
# -႒
# -႒
# -ႌO-႑O႒
# -႑O႒
# -႓O-ࠤ
# -ࠤ
# -႓O႔
# -œO႓O-႔
# -႔
# -႕O-œ
# -œ
# -႕O႖
# -ࠤO႕O-႖
# -႖
# -႗
# -႗
# -႔O-႖O႗
# -႖O႗
# -႘
# -႘
# -႒O-႗O႘
# -႗O႘
# -႙O-ࠥ
# -ࠥ
# -႙Oႚ
# -ŔO႙O-ႚ
# -ႚ
# -ႛO-Ŕ
# -Ŕ
# -ႛOႜ
# -ࠥOႛO-ႜ
# -ႜ
# -ႝ
# -ႝ
# -ႚO-ႜOႝ
# -ႜOႝ
# -႞
# -႞
# -႘O-ႝO႞
# -ႝO႞
# -႟O-ࠦ
# -ࠦ
# -႟OႠ
# -ŕO႟O-Ⴀ
# -Ⴀ
# -ႡO-ŕ
# -ŕ
# -ႡOႢ
# -ࠦOႡO-Ⴂ
# -Ⴂ
# -Ⴃ
# -Ⴃ
# -ႠO-ႢOႣ
# -ႢOႣ
# -Ⴄ
# -Ⴄ
# -႞O-ႣOႤ
# -ႣOႤ
# -ႥO-ࠧ
# -ࠧ
# -ႥOႦ
# -ŖOႥO-Ⴆ
# -Ⴆ
# -ႧO-Ŗ
# -Ŗ
# -ႧOႨ
# -ࠧOႧO-Ⴈ
# -Ⴈ
# -Ⴉ
# -Ⴉ
# -ႦO-ႨOႩ
# -ႨOႩ
# -Ⴊ
# -Ⴊ
# -ႤO-ႩOႪ
# -ႩOႪ
# -ႫO-ࠨ
# -ࠨ
# -ႫOႬ
# -ŗOႫO-Ⴌ
# -Ⴌ
# -ႭO-ŗ
# -ŗ
# -ႭOႮ
# -ࠨOႭO-Ⴎ
# -Ⴎ
# -Ⴏ
# -Ⴏ
# -ႬO-ႮOႯ
# -ႮOႯ
# -Ⴐ
# -Ⴐ
# -ႪO-ႯOႰ
# -ႯOႰ
# -ႱO-ࠩ
# -ࠩ
# -ႱOႲ
# -ŘOႱO-Ⴒ
# -Ⴒ
# -ႳO-Ř
# -Ř
# -ႳOႴ
# -ࠩOႳO-Ⴔ
# -Ⴔ
# -Ⴕ
# -Ⴕ
# -ႲO-ႴOႵ
# -ႴOႵ
# -Ⴖ
# -Ⴖ
# -ኚOኛ
# -ኜ
# -ኜ
# -ኖO-ኛOኜ
# -ኛOኜ
# -ኝO-ࡻ
# -ࡻ
# -ኝOኞ
# -ƪOኝO-ኞ
# -ኞ
# -ኟO-ƪ
# -ƪ
# -ኟOአ
# -ࡻOኟO-አ
# -አ
# -ኡ
# -ኡ
# -ኞO-አOኡ
# -አOኡ
# -ኢ
# -ኢ
# -ኜO-ኡOኢ
# -ኡOኢ
# -ኣO-ࡼ
# -ࡼ
# -ኣOኤ
# -ƫOኣO-ኤ
# -ኤ
# -እO-ƫ
# -ƫ
# -እOኦ
# -ࡼOእO-ኦ
# -ኦ
# -ኧ
# -ኧ
# -ኤO-ኦOኧ
# -ኦOኧ
# -ከ
# -ከ
# -ኢO-ኧOከ
# -ኧOከ
# -ኩO-ࡽ
# -ࡽ
# -ኩOኪ
# -ƬOኩO-ኪ
# -ኪ
# -ካO-Ƭ
# -Ƭ
# -ካOኬ
# -ࡽOካO-ኬ
# -ኬ
# -ክ
# -ክ
# -ኪO-ኬOክ
# -ኬOክ
# -ኮ
# -ኮ
# -ከO-ክOኮ
# -ክOኮ
# -ኯO-ࡾ
# -ࡾ
# -ኯOኰ
# -ƭOኯO-ኰ
# -ኰ
# -኱O-ƭ
# -ƭ
# -኱Oኲ
# -ࡾO኱O-ኲ
# -ኲ
# -ኳ
# -ኳ
# -ኰO-ኲOኳ
# -ኲOኳ
# -ኴ
# -ኴ
# -ኮO-ኳOኴ
# -ኳOኴ
# -ኵO-ࡿ
# -ࡿ
# -ኵO኶
# -ƮOኵO-኶
# -኶
# -኷O-Ʈ
# -Ʈ
# -኷Oኸ
# -ࡿO኷O-ኸ
# -ኸ
# -ኹ
# -ኹ
# -኶O-ኸOኹ
# -ኸOኹ
# -ኺ
# -ኺ
# -ኴO-ኹOኺ
# -ኹOኺ
# Corriendo DPLL...
# Satisfacible

# %%
jugadas(I)

# %% [markdown]
# ### Prueba de regla 3:
#
# Se gana con cinco piedras del mismo color seguidas en línea vertical, horizontal o diagonal.

# %%
R3 = regla3()
formula_polacaI = R3 
formula_inorder = Inorder(String2Tree(formula_polacaI))
print("Corriendo Tseitin...")
T = Tseitin(formula_inorder, letrasProposicionales)
formula = formaClausal(T)
print("Corriendo DPLL...")
prueba_DPLL = DPLL(formula,{})
print(prueba_DPLL[0])
I = {}
for k in letrasProposicionales:
    if k in prueba_DPLL[1].keys():
        I[k] = prueba_DPLL[1][k]

# %%
jugadas(I)

# %% [markdown]
# ### Prueba de regla 4:
#
#
# Si hay una piedra en una posición del tablero, esta se queda ahí para todos los turnos siguientes.

# %%
R4 = regla4()
formula_polacaI = R4 
formula_inorder = Inorder(String2Tree(formula_polacaI))
print("Corriendo Tseitin...")
T = Tseitin(formula_inorder, letrasProposicionales)
formula = formaClausal(T)
print("Corriendo DPLL...")
prueba_DPLL = DPLL(formula,{})
print(prueba_DPLL[0])
I = {}
for k in letrasProposicionales:
    if k in prueba_DPLL[1].keys():
        I[k] = prueba_DPLL[1][k]

# %%
jugadas(I)
