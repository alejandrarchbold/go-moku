# %% [markdown]
# <table><tr>
#     <td><img src="img/Macc.png"/></td>
#     <td><p style="font-size:22px;">Lógica para ciencias de la computación</p></td>
# </tr></table>

# %% [markdown]
# ## Problema: Go-moku
#
# Go-moku es un juego de mesa para dos personas. Se juega con piedras blancas y negras en un tablero de Go de intersección de 15x15 o 19x19.
#
# Las negras juegan primero y los jugadores se alternan para colocar una piedra de su color en una intersección vacía. No hay restricción de dónde colocar, los jugadores colocan sus piedras alternativamente hasta que se recolectan una fila ininterrumpida de cinco piedras, ya sea horizontal, vertical o diagonalmente.
#
# <img src="img/hh.jpeg" alt="drawing" width="250"/>

# %% [markdown]
# ## Objetivo del proyecto
#
# El objetivo es que el computador genere un tablero en el que un jugador gana.
#
# ## Representación de las letras proposicionales.
#
# $N(x,y,t)$ es verdadero sii en el turno $t$ hay una piedra negra en la intersección $x$, $y$
# $B(x,y,t)$ es verdadero sii en el turno $t$ hay una piedra blanca en la intersección $x$, $y$.
#
#
# $x$ son las filas y $y$ son las columnas del tablero.

# %% [markdown]
# ## Etapa de la codificación de las letras proposicionales
#
# (Basado en el taller de clase de Codificación)

# %%
class objetoCodificacionNegras:
    
    def __init__ (self,Nf,Nc,Nn,chrInit) :
        self.Nf = Nf
        self.Nc = Nc
        self.Nn = Nn
        self.chrInit = chrInit

    def codifica(self,f,c,n) :
        v1 = self.Nc * f + c
        return self.Nn * v1 + n

    def decodifica(self,codigo):
        n = codigo % self.Nn
        v1 = int(codigo / self.Nn)
        c = v1 % self.Nc
        f = int(v1 / self.Nc)
        return f, c, n
    
    def N(self,f,c,n):
        codigo = self.codifica(f,c,n)
        return chr(self.chrInit + codigo)
    
    def Ninv(self,codigo) :
        v = ord(codigo)-self.chrInit
        return self.decodifica(v)

# %%
class objetoCodificacionBlancas:
    
    def __init__ (self,Nf,Nc,Nn,chrInit) :
        self.Nf = Nf
        self.Nc = Nc
        self.Nn = Nn
        self.chrInit = chrInit

    def codifica(self,f,c,n) :
        v1 = self.Nc * f + c
        return self.Nn * v1 + n

    def decodifica(self,codigo):
        n = codigo % self.Nn
        v1 = int(codigo / self.Nn)
        c = v1 % self.Nc
        f = int(v1 / self.Nc)
        return f, c, n
    
    def B(self,f,c,n):
        codigo = self.codifica(f,c,n)
        return chr(self.chrInit + codigo)
    
    def Binv(self,codigo) :
        v = ord(codigo)-self.chrInit
        return self.decodifica(v)

# %% [markdown]
# #### Dimensiones de la información para la visualización de las Negras

# %%
# Se define el rango de opciones para cada dimensión de información
Nfilas = 6
Ncolumnas = 6
Nnumeros = 37

# Se crea el objeto de codificación
cods1 = objetoCodificacionNegras(Nfilas,Ncolumnas,Nnumeros,256)

# Se recorren todas las opciones de las dimensiones de información para visualizar su codificación
letras_negras = []
for n in range(1, Nnumeros):
    print("Turno: "+str(n))
    print("filas x columnas")
    for f in range(Nfilas):
        for c in range(Ncolumnas):
            cod = cods1.N(f,c,n)
            print(cod,end=" ")
            letras_negras.append(cod)
        print("")
    print('\n')
# Out:
# Turno: 1
# filas x columnas
# ā Ħ ŋ Ű ƕ ƺ
# ǟ Ȅ ȩ Ɏ ɳ ʘ
# ʽ ˢ ̇ ̬ ͑ Ͷ
# Λ π ϥ Њ Я є
# ѹ Ҟ Ӄ Ө ԍ Բ
# ՗ ռ ֡ ׆ ׫ ؐ
#
#
# Turno: 2
# filas x columnas
# Ă ħ Ō ű Ɩ ƻ
# Ǡ ȅ Ȫ ɏ ɴ ʙ
# ʾ ˣ ̈ ̭ ͒ ͷ
# Μ ρ Ϧ Ћ а ѕ
# Ѻ ҟ ӄ ө Ԏ Գ
# ՘ ս ֢ ׇ ׬ ؑ
#
#
# Turno: 3
# filas x columnas
# ă Ĩ ō Ų Ɨ Ƽ
# ǡ Ȇ ȫ ɐ ɵ ʚ
# ʿ ˤ ̉ ̮ ͓ ͸
# Ν ς ϧ Ќ б і
# ѻ Ҡ Ӆ Ӫ ԏ Դ
# ՙ վ ֣ ׈ ׭ ؒ
#
#
# Turno: 4
# filas x columnas
# Ą ĩ Ŏ ų Ƙ ƽ
# Ǣ ȇ Ȭ ɑ ɶ ʛ
# ˀ ˥ ̊ ̯ ͔ ͹
# Ξ σ Ϩ Ѝ в ї
# Ѽ ҡ ӆ ӫ Ԑ Ե
# ՚ տ ֤ ׉ ׮ ؓ
#
#
# Turno: 5
# filas x columnas
# ą Ī ŏ Ŵ ƙ ƾ
# ǣ Ȉ ȭ ɒ ɷ ʜ
# ˁ ˦ ̋ ̰ ͕ ͺ
# Ο τ ϩ Ў г ј
# ѽ Ң Ӈ Ӭ ԑ Զ
# ՛ ր ֥ ׊ ׯ ؔ
#
#
# Turno: 6
# filas x columnas
# Ć ī Ő ŵ ƚ ƿ
# Ǥ ȉ Ȯ ɓ ɸ ʝ
# ˂ ˧ ̌ ̱ ͖ ͻ
# Π υ Ϫ Џ д љ
# Ѿ ң ӈ ӭ Ԓ Է
# ՜ ց ֦ ׋ װ ؕ
#
#
# Turno: 7
# filas x columnas
# ć Ĭ ő Ŷ ƛ ǀ
# ǥ Ȋ ȯ ɔ ɹ ʞ
# ˃ ˨ ̍ ̲ ͗ ͼ
# Ρ φ ϫ А е њ
# ѿ Ҥ Ӊ Ӯ ԓ Ը
# ՝ ւ ֧ ׌ ױ ؖ
#
#
# Turno: 8
# filas x columnas
# Ĉ ĭ Œ ŷ Ɯ ǁ
# Ǧ ȋ Ȱ ɕ ɺ ʟ
# ˄ ˩ ̎ ̳ ͘ ͽ
# ΢ χ Ϭ Б ж ћ
# Ҁ ҥ ӊ ӯ Ԕ Թ
# ՞ փ ֨ ׍ ײ ؗ
#
#
# Turno: 9
# filas x columnas
# ĉ Į œ Ÿ Ɲ ǂ
# ǧ Ȍ ȱ ɖ ɻ ʠ
# ˅ ˪ ̏ ̴ ͙ ;
# Σ ψ ϭ В з ќ
# ҁ Ҧ Ӌ Ӱ ԕ Ժ
# ՟ ք ֩ ׎ ׳ ؘ
#
#
# Turno: 10
# filas x columnas
# Ċ į Ŕ Ź ƞ ǃ
# Ǩ ȍ Ȳ ɗ ɼ ʡ
# ˆ ˫ ̐ ̵ ͚ Ϳ
# Τ ω Ϯ Г и ѝ
# ҂ ҧ ӌ ӱ Ԗ Ի
# ՠ օ ֪ ׏ ״ ؙ
#
#
# Turno: 11
# filas x columnas
# ċ İ ŕ ź Ɵ Ǆ
# ǩ Ȏ ȳ ɘ ɽ ʢ
# ˇ ˬ ̑ ̶ ͛ ΀
# Υ ϊ ϯ Д й ў
# ҃ Ҩ Ӎ Ӳ ԗ Լ
# ա ֆ ֫ א ׵ ؚ
#
#
# Turno: 12
# filas x columnas
# Č ı Ŗ Ż Ơ ǅ
# Ǫ ȏ ȴ ə ɾ ʣ
# ˈ ˭ ̒ ̷ ͜ ΁
# Φ ϋ ϰ Е к џ
# ҄ ҩ ӎ ӳ Ԙ Խ
# բ և ֬ ב ׶ ؛
#
#
# Turno: 13
# filas x columnas
# č Ĳ ŗ ż ơ ǆ
# ǫ Ȑ ȵ ɚ ɿ ʤ
# ˉ ˮ ̓ ̸ ͝ ΂
# Χ ό ϱ Ж л Ѡ
# ҅ Ҫ ӏ Ӵ ԙ Ծ
# գ ֈ ֭ ג ׷ ؜
#
#
# Turno: 14
# filas x columnas
# Ď ĳ Ř Ž Ƣ Ǉ
# Ǭ ȑ ȶ ɛ ʀ ʥ
# ˊ ˯ ̔ ̹ ͞ ΃
# Ψ ύ ϲ З м ѡ
# ҆ ҫ Ӑ ӵ Ԛ Կ
# դ ։ ֮ ד ׸ ؝
#
#
# Turno: 15
# filas x columnas
# ď Ĵ ř ž ƣ ǈ
# ǭ Ȓ ȷ ɜ ʁ ʦ
# ˋ ˰ ̕ ̺ ͟ ΄
# Ω ώ ϳ И н Ѣ
# ҇ Ҭ ӑ Ӷ ԛ Հ
# ե ֊ ֯ ה ׹ ؞
#
#
# Turno: 16
# filas x columnas
# Đ ĵ Ś ſ Ƥ ǉ
# Ǯ ȓ ȸ ɝ ʂ ʧ
# ˌ ˱ ̖ ̻ ͠ ΅
# Ϊ Ϗ ϴ Й о ѣ
# ҈ ҭ Ӓ ӷ Ԝ Ձ
# զ ֋ ְ ו ׺ ؟
#
#
# Turno: 17
# filas x columnas
# đ Ķ ś ƀ ƥ Ǌ
# ǯ Ȕ ȹ ɞ ʃ ʨ
# ˍ ˲ ̗ ̼ ͡ Ά
# Ϋ ϐ ϵ К п Ѥ
# ҉ Ү ӓ Ӹ ԝ Ղ
# է ֌ ֱ ז ׻ ؠ
#
#
# Turno: 18
# filas x columnas
# Ē ķ Ŝ Ɓ Ʀ ǋ
# ǰ ȕ Ⱥ ɟ ʄ ʩ
# ˎ ˳ ̘ ̽ ͢ ·
# ά ϑ ϶ Л р ѥ
# Ҋ ү Ӕ ӹ Ԟ Ճ
# ը ֍ ֲ ח ׼ ء
#
#
# Turno: 19
# filas x columnas
# ē ĸ ŝ Ƃ Ƨ ǌ
# Ǳ Ȗ Ȼ ɠ ʅ ʪ
# ˏ ˴ ̙ ̾ ͣ Έ
# έ ϒ Ϸ М с Ѧ
# ҋ Ұ ӕ Ӻ ԟ Մ
# թ ֎ ֳ ט ׽ آ
#
#
# Turno: 20
# filas x columnas
# Ĕ Ĺ Ş ƃ ƨ Ǎ
# ǲ ȗ ȼ ɡ ʆ ʫ
# ː ˵ ̚ ̿ ͤ Ή
# ή ϓ ϸ Н т ѧ
# Ҍ ұ Ӗ ӻ Ԡ Յ
# ժ ֏ ִ י ׾ أ
#
#
# Turno: 21
# filas x columnas
# ĕ ĺ ş Ƅ Ʃ ǎ
# ǳ Ș Ƚ ɢ ʇ ʬ
# ˑ ˶ ̛ ̀ ͥ Ί
# ί ϔ Ϲ О у Ѩ
# ҍ Ҳ ӗ Ӽ ԡ Ն
# ի ֐ ֵ ך ׿ ؤ
#
#
# Turno: 22
# filas x columnas
# Ė Ļ Š ƅ ƪ Ǐ
# Ǵ ș Ⱦ ɣ ʈ ʭ
# ˒ ˷ ̜ ́ ͦ ΋
# ΰ ϕ Ϻ П ф ѩ
# Ҏ ҳ Ә ӽ Ԣ Շ
# լ ֑ ֶ כ ؀ إ
#
#
# Turno: 23
# filas x columnas
# ė ļ š Ɔ ƫ ǐ
# ǵ Ț ȿ ɤ ʉ ʮ
# ˓ ˸ ̝ ͂ ͧ Ό
# α ϖ ϻ Р х Ѫ
# ҏ Ҵ ә Ӿ ԣ Ո
# խ ֒ ַ ל ؁ ئ
#
#
# Turno: 24
# filas x columnas
# Ę Ľ Ţ Ƈ Ƭ Ǒ
# Ƕ ț ɀ ɥ ʊ ʯ
# ˔ ˹ ̞ ̓ ͨ ΍
# β ϗ ϼ С ц ѫ
# Ґ ҵ Ӛ ӿ Ԥ Չ
# ծ ֓ ָ ם ؂ ا
#
#
# Turno: 25
# filas x columnas
# ę ľ ţ ƈ ƭ ǒ
# Ƿ Ȝ Ɂ ɦ ʋ ʰ
# ˕ ˺ ̟ ̈́ ͩ Ύ
# γ Ϙ Ͻ Т ч Ѭ
# ґ Ҷ ӛ Ԁ ԥ Պ
# կ ֔ ֹ מ ؃ ب
#
#
# Turno: 26
# filas x columnas
# Ě Ŀ Ť Ɖ Ʈ Ǔ
# Ǹ ȝ ɂ ɧ ʌ ʱ
# ˖ ˻ ̠ ͅ ͪ Ώ
# δ ϙ Ͼ У ш ѭ
# Ғ ҷ Ӝ ԁ Ԧ Ջ
# հ ֕ ֺ ן ؄ ة
#
#
# Turno: 27
# filas x columnas
# ě ŀ ť Ɗ Ư ǔ
# ǹ Ȟ Ƀ ɨ ʍ ʲ
# ˗ ˼ ̡ ͆ ͫ ΐ
# ε Ϛ Ͽ Ф щ Ѯ
# ғ Ҹ ӝ Ԃ ԧ Ռ
# ձ ֖ ֻ נ ؅ ت
#
#
# Turno: 28
# filas x columnas
# Ĝ Ł Ŧ Ƌ ư Ǖ
# Ǻ ȟ Ʉ ɩ ʎ ʳ
# ˘ ˽ ̢ ͇ ͬ Α
# ζ ϛ Ѐ Х ъ ѯ
# Ҕ ҹ Ӟ ԃ Ԩ Ս
# ղ ֗ ּ ס ؆ ث
#
#
# Turno: 29
# filas x columnas
# ĝ ł ŧ ƌ Ʊ ǖ
# ǻ Ƞ Ʌ ɪ ʏ ʴ
# ˙ ˾ ̣ ͈ ͭ Β
# η Ϝ Ё Ц ы Ѱ
# ҕ Һ ӟ Ԅ ԩ Վ
# ճ ֘ ֽ ע ؇ ج
#
#
# Turno: 30
# filas x columnas
# Ğ Ń Ũ ƍ Ʋ Ǘ
# Ǽ ȡ Ɇ ɫ ʐ ʵ
# ˚ ˿ ̤ ͉ ͮ Γ
# θ ϝ Ђ Ч ь ѱ
# Җ һ Ӡ ԅ Ԫ Տ
# մ ֙ ־ ף ؈ ح
#
#
# Turno: 31
# filas x columnas
# ğ ń ũ Ǝ Ƴ ǘ
# ǽ Ȣ ɇ ɬ ʑ ʶ
# ˛ ̀ ̥ ͊ ͯ Δ
# ι Ϟ Ѓ Ш э Ѳ
# җ Ҽ ӡ Ԇ ԫ Ր
# յ ֚ ֿ פ ؉ خ
#
#
# Turno: 32
# filas x columnas
# Ġ Ņ Ū Ə ƴ Ǚ
# Ǿ ȣ Ɉ ɭ ʒ ʷ
# ˜ ́ ̦ ͋ Ͱ Ε
# κ ϟ Є Щ ю ѳ
# Ҙ ҽ Ӣ ԇ Ԭ Ց
# ն ֛ ׀ ץ ؊ د
#
#
# Turno: 33
# filas x columnas
# ġ ņ ū Ɛ Ƶ ǚ
# ǿ Ȥ ɉ ɮ ʓ ʸ
# ˝ ̂ ̧ ͌ ͱ Ζ
# λ Ϡ Ѕ Ъ я Ѵ
# ҙ Ҿ ӣ Ԉ ԭ Ւ
# շ ֜ ׁ צ ؋ ذ
#
#
# Turno: 34
# filas x columnas
# Ģ Ň Ŭ Ƒ ƶ Ǜ
# Ȁ ȥ Ɋ ɯ ʔ ʹ
# ˞ ̃ ̨ ͍ Ͳ Η
# μ ϡ І Ы ѐ ѵ
# Қ ҿ Ӥ ԉ Ԯ Փ
# ո ֝ ׂ ק ، ر
#
#
# Turno: 35
# filas x columnas
# ģ ň ŭ ƒ Ʒ ǜ
# ȁ Ȧ ɋ ɰ ʕ ʺ
# ˟ ̄ ̩ ͎ ͳ Θ
# ν Ϣ Ї Ь ё Ѷ
# қ Ӏ ӥ Ԋ ԯ Ք
# չ ֞ ׃ ר ؍ ز
#
#
# Turno: 36
# filas x columnas
# Ĥ ŉ Ů Ɠ Ƹ ǝ
# Ȃ ȧ Ɍ ɱ ʖ ʻ
# ˠ ̅ ̪ ͏ ʹ Ι
# ξ ϣ Ј Э ђ ѷ
# Ҝ Ӂ Ӧ ԋ ԰ Օ
# պ ֟ ׄ ש ؎ س

# %% [markdown]
# #### Dimensiones de la información para la visualización de las Blancas

# %%
# Se define el rango de opciones para cada dimensión de información
Nfilas = 6
Ncolumnas = 6
Nnumeros = 37

# Se crea el objeto de codificación
cods2 = objetoCodificacionBlancas(Nfilas,Ncolumnas,Nnumeros,2001)

# Se recorren todas las opciones de las dimensiones de información para visualizar su codificación
letras_blancas = []
for n in range(1, Nnumeros):
    print("Turno: "+str(n))
    print("filas x columnas")
    for f in range(Nfilas):
        for c in range(Ncolumnas):
            cod = cods2.B(f,c,n)
            print(cod,end=" ")
            letras_blancas.append( cod)
        print("")
    print('\n')
# Out:
# Turno: 1
# filas x columnas
# ߒ ߷ ࠜ ࡁ ࡦ ࢋ
# ࢰ ࣕ ࣺ ट ॄ ३
# ঎ ঳ ৘ ৽ ਢ ੇ
# ੬ ઑ શ ૛ ଀ ଥ
# ୊ ୯ ஔ ஹ ௞ ః
# న ్ ౲ ಗ ಼ ೡ
#
#
# Turno: 2
# filas x columnas
# ߓ ߸ ࠝ ࡂ ࡧ ࢌ
# ࢱ ࣖ ࣻ ठ ॅ ४
# এ ঴ ৙ ৾ ਣ ੈ
# ੭ ઒ ષ ૜ ଁ ଦ
# ୋ ୰ க ஺ ௟ ఄ
# ఩ ౎ ౳ ಘ ಽ ೢ
#
#
# Turno: 3
# filas x columnas
# ߔ ߹ ࠞ ࡃ ࡨ ࢍ
# ࢲ ࣗ ࣼ ड ॆ ५
# ঐ ঵ ৚ ৿ ਤ ੉
# ੮ ઓ સ ૝ ଂ ଧ
# ୌ ୱ ஖ ஻ ௠ అ
# ప ౏ ౴ ಙ ಾ ೣ
#
#
# Turno: 4
# filas x columnas
# ߕ ߺ ࠟ ࡄ ࡩ ࢎ
# ࢳ ࣘ ࣽ ढ े ६
# ঑ শ ৛ ਀ ਥ ੊
# ੯ ઔ હ ૞ ଃ ନ
# ୍ ୲ ஗ ஼ ௡ ఆ
# ఫ ౐ ౵ ಚ ಿ ೤
#
#
# Turno: 5
# filas x columnas
# ߖ ߻ ࠠ ࡅ ࡪ ࢏
# ࢴ ࣙ ࣾ ण ै ७
# ঒ ষ ড় ਁ ਦ ੋ
# ੰ ક ઺ ૟ ଄ ଩
# ୎ ୳ ஘ ஽ ௢ ఇ
# బ ౑ ౶ ಛ ೀ ೥
#
#
# Turno: 6
# filas x columnas
# ߗ ߼ ࠡ ࡆ ࡫ ࢐
# ࢵ ࣚ ࣿ त ॉ ८
# ও স ঢ় ਂ ਧ ੌ
# ੱ ખ ઻ ૠ ଅ ପ
# ୏ ୴ ங ா ௣ ఈ
# భ ౒ ౷ ಜ ು ೦
#
#
# Turno: 7
# filas x columnas
# ߘ ߽ ࠢ ࡇ ࡬ ࢑
# ࢶ ࣛ ऀ थ ॊ ९
# ঔ হ ৞ ਃ ਨ ੍
# ੲ ગ ઼ ૡ ଆ ଫ
# ୐ ୵ ச ி ௤ ఉ
# మ ౓ ౸ ಝ ೂ ೧
#
#
# Turno: 8
# filas x columnas
# ߙ ߾ ࠣ ࡈ ࡭ ࢒
# ࢷ ࣜ ँ द ो ॰
# ক ঺ য় ਄ ਩ ੎
# ੳ ઘ ઽ ૢ ଇ ବ
# ୑ ୶ ஛ ீ ௥ ఊ
# య ౔ ౹ ಞ ೃ ೨
#
#
# Turno: 9
# filas x columnas
# ߚ ߿ ࠤ ࡉ ࡮ ࢓
# ࢸ ࣝ ं ध ौ ॱ
# খ ঻ ৠ ਅ ਪ ੏
# ੴ ઙ ા ૣ ଈ ଭ
# ୒ ୷ ஜ ு ௦ ఋ
# ర ౕ ౺ ಟ ೄ ೩
#
#
# Turno: 10
# filas x columnas
# ߛ ࠀ ࠥ ࡊ ࡯ ࢔
# ࢹ ࣞ ः न ् ॲ
# গ ় ৡ ਆ ਫ ੐
# ੵ ચ િ ૤ ଉ ମ
# ୓ ୸ ஝ ூ ௧ ఌ
# ఱ ౖ ౻ ಠ ೅ ೪
#
#
# Turno: 11
# filas x columnas
# ߜ ࠁ ࠦ ࡋ ࡰ ࢕
# ࢺ ࣟ ऄ ऩ ॎ ॳ
# ঘ ঽ ৢ ਇ ਬ ੑ
# ੶ છ ી ૥ ଊ ଯ
# ୔ ୹ ஞ ௃ ௨ ఍
# ల ౗ ౼ ಡ ೆ ೫
#
#
# Turno: 12
# filas x columnas
# ߝ ࠂ ࠧ ࡌ ࡱ ࢖
# ࢻ ࣠ अ प ॏ ॴ
# ঙ া ৣ ਈ ਭ ੒
# ੷ જ ુ ૦ ଋ ର
# ୕ ୺ ட ௄ ௩ ఎ
# ళ ౘ ౽ ಢ ೇ ೬
#
#
# Turno: 13
# filas x columnas
# ߞ ࠃ ࠨ ࡍ ࡲ ࢗ
# ࢼ ࣡ आ फ ॐ ॵ
# চ ি ৤ ਉ ਮ ੓
# ੸ ઝ ૂ ૧ ଌ ଱
# ୖ ୻ ஠ ௅ ௪ ఏ
# ఴ ౙ ౾ ಣ ೈ ೭
#
#
# Turno: 14
# filas x columnas
# ߟ ࠄ ࠩ ࡎ ࡳ ࢘
# ࢽ ࣢ इ ब ॑ ॶ
# ছ ী ৥ ਊ ਯ ੔
# ੹ ઞ ૃ ૨ ଍ ଲ
# ୗ ୼ ஡ ெ ௫ ఐ
# వ ౚ ౿ ತ ೉ ೮
#
#
# Turno: 15
# filas x columnas
# ߠ ࠅ ࠪ ࡏ ࡴ ࢙
# ࢾ ࣣ ई भ ॒ ॷ
# জ ু ০ ਋ ਰ ੕
# ੺ ટ ૄ ૩ ଎ ଳ
# ୘ ୽ ஢ ே ௬ ఑
# శ ౛ ಀ ಥ ೊ ೯
#
#
# Turno: 16
# filas x columnas
# ߡ ࠆ ࠫ ࡐ ࡵ ࢚
# ࢿ ࣤ उ म ॓ ॸ
# ঝ ূ ১ ਌ ਱ ੖
# ੻ ઠ ૅ ૪ ଏ ଴
# ୙ ୾ ண ை ௭ ఒ
# ష ౜ ಁ ದ ೋ ೰
#
#
# Turno: 17
# filas x columnas
# ߢ ࠇ ࠬ ࡑ ࡶ ࢛
# ࣀ ࣥ ऊ य ॔ ॹ
# ঞ ৃ ২ ਍ ਲ ੗
# ੼ ડ ૆ ૫ ଐ ଵ
# ୚ ୿ த ௉ ௮ ఓ
# స ౝ ಂ ಧ ೌ ೱ
#
#
# Turno: 18
# filas x columnas
# ߣ ࠈ ࠭ ࡒ ࡷ ࢜
# ࣁ ࣦ ऋ र ॕ ॺ
# ট ৄ ৩ ਎ ਲ਼ ੘
# ੽ ઢ ે ૬ ଑ ଶ
# ୛ ஀ ஥ ொ ௯ ఔ
# హ ౞ ಃ ನ ್ ೲ
#
#
# Turno: 19
# filas x columnas
# ߤ ࠉ ࠮ ࡓ ࡸ ࢝
# ࣂ ࣧ ऌ ऱ ॖ ॻ
# ঠ ৅ ৪ ਏ ਴ ਖ਼
# ੾ ણ ૈ ૭ ଒ ଷ
# ଡ଼ ஁ ஦ ோ ௰ క
# ఺ ౟ ಄ ಩ ೎ ೳ
#
#
# Turno: 20
# filas x columnas
# ߥ ࠊ ࠯ ࡔ ࡹ ࢞
# ࣃ ࣨ ऍ ल ॗ ॼ
# ড ৆ ৫ ਐ ਵ ਗ਼
# ੿ ત ૉ ૮ ଓ ସ
# ଢ଼ ஂ ஧ ௌ ௱ ఖ
# ఻ ౠ ಅ ಪ ೏ ೴
#
#
# Turno: 21
# filas x columnas
# ߦ ࠋ ࠰ ࡕ ࡺ ࢟
# ࣄ ࣩ ऎ ळ क़ ॽ
# ঢ ে ৬ ਑ ਸ਼ ਜ਼
# ઀ થ ૊ ૯ ଔ ହ
# ୞ ஃ ந ் ௲ గ
# ఼ ౡ ಆ ಫ ೐ ೵
#
#
# Turno: 22
# filas x columnas
# ߧ ࠌ ࠱ ࡖ ࡻ ࢠ
# ࣅ ࣪ ए ऴ ख़ ॾ
# ণ ৈ ৭ ਒ ਷ ੜ
# ઁ દ ો ૰ କ ଺
# ୟ ஄ ன ௎ ௳ ఘ
# ఽ ౢ ಇ ಬ ೑ ೶
#
#
# Turno: 23
# filas x columnas
# ߨ ࠍ ࠲ ࡗ ࡼ ࢡ
# ࣆ ࣫ ऐ व ग़ ॿ
# ত ৉ ৮ ਓ ਸ ੝
# ં ધ ૌ ૱ ଖ ଻
# ୠ அ ப ௏ ௴ ఙ
# ా ౣ ಈ ಭ ೒ ೷
#
#
# Turno: 24
# filas x columnas
# ߩ ࠎ ࠳ ࡘ ࡽ ࢢ
# ࣇ ࣬ ऑ श ज़ ঀ
# থ ৊ ৯ ਔ ਹ ਫ਼
# ઃ ન ્ ૲ ଗ ଼
# ୡ ஆ ஫ ௐ ௵ చ
# ి ౤ ಉ ಮ ೓ ೸
#
#
# Turno: 25
# filas x columnas
# ߪ ࠏ ࠴ ࡙ ࡾ ࢣ
# ࣈ ࣭ ऒ ष ड़ ঁ
# দ ো ৰ ਕ ਺ ੟
# ઄ ઩ ૎ ૳ ଘ ଽ
# ୢ இ ஬ ௑ ௶ ఛ
# ీ ౥ ಊ ಯ ೔ ೹
#
#
# Turno: 26
# filas x columnas
# ߫ ࠐ ࠵ ࡚ ࡿ ࢤ
# ࣉ ࣮ ओ स ढ़ ং
# ধ ৌ ৱ ਖ ਻ ੠
# અ પ ૏ ૴ ଙ ା
# ୣ ஈ ஭ ௒ ௷ జ
# ు ౦ ಋ ರ ೕ ೺
#
#
# Turno: 27
# filas x columnas
# ߬ ࠑ ࠶ ࡛ ࢀ ࢥ
# ࣊ ࣯ औ ह फ़ ঃ
# ন ্ ৲ ਗ ਼ ੡
# આ ફ ૐ ૵ ଚ ି
# ୤ உ ம ௓ ௸ ఝ
# ూ ౧ ಌ ಱ ೖ ೻
#
#
# Turno: 28
# filas x columnas
# ߭ ࠒ ࠷ ࡜ ࢁ ࢦ
# ࣋ ࣰ क ऺ य़ ঄
# ঩ ৎ ৳ ਘ ਽ ੢
# ઇ બ ૑ ૶ ଛ ୀ
# ୥ ஊ ய ௔ ௹ ఞ
# ృ ౨ ಍ ಲ ೗ ೼
#
#
# Turno: 29
# filas x columnas
# ߮ ࠓ ࠸ ࡝ ࢂ ࢧ
# ࣌ ࣱ ख ऻ ॠ অ
# প ৏ ৴ ਙ ਾ ੣
# ઈ ભ ૒ ૷ ଜ ୁ
# ୦ ஋ ர ௕ ௺ ట
# ౄ ౩ ಎ ಳ ೘ ೽
#
#
# Turno: 30
# filas x columnas
# ߯ ࠔ ࠹ ࡞ ࢃ ࢨ
# ࣍ ࣲ ग ़ ॡ আ
# ফ ৐ ৵ ਚ ਿ ੤
# ઉ મ ૓ ૸ ଝ ୂ
# ୧ ஌ ற ௖ ௻ ఠ
# ౅ ౪ ಏ ಴ ೙ ೾
#
#
# Turno: 31
# filas x columnas
# ߰ ࠕ ࠺ ࡟ ࢄ ࢩ
# ࣎ ࣳ घ ऽ ॢ ই
# ব ৑ ৶ ਛ ੀ ੥
# ઊ ય ૔ ૹ ଞ ୃ
# ୨ ஍ ல ௗ ௼ డ
# ె ౫ ಐ ವ ೚ ೿
#
#
# Turno: 32
# filas x columnas
# ߱ ࠖ ࠻ ࡠ ࢅ ࢪ
# ࣏ ࣴ ङ ा ॣ ঈ
# ভ ৒ ৷ ਜ ੁ ੦
# ઋ ર ૕ ૺ ଟ ୄ
# ୩ எ ள ௘ ௽ ఢ
# ే ౬ ಑ ಶ ೛ ഀ
#
#
# Turno: 33
# filas x columnas
# ߲ ࠗ ࠼ ࡡ ࢆ ࢫ
# ࣐ ࣵ च ि । উ
# ম ৓ ৸ ਝ ੂ ੧
# ઌ ઱ ૖ ૻ ଠ ୅
# ୪ ஏ ழ ௙ ௾ ణ
# ై ౭ ಒ ಷ ೜ ഁ
#
#
# Turno: 34
# filas x columnas
# ߳ ࠘ ࠽ ࡢ ࢇ ࢬ
# ࣑ ࣶ छ ी ॥ ঊ
# য ৔ ৹ ਞ ੃ ੨
# ઍ લ ૗ ૼ ଡ ୆
# ୫ ஐ வ ௚ ௿ త
# ౉ ౮ ಓ ಸ ೝ ം
#
#
# Turno: 35
# filas x columnas
# ߴ ࠙ ࠾ ࡣ ࢈ ࢭ
# ࣒ ࣷ ज ु ० ঋ
# র ৕ ৺ ਟ ੄ ੩
# ઎ ળ ૘ ૽ ଢ େ
# ୬ ஑ ஶ ௛ ఀ థ
# ొ ౯ ಔ ಹ ೞ ഃ
#
#
# Turno: 36
# filas x columnas
# ߵ ࠚ ࠿ ࡤ ࢉ ࢮ
# ࣓ ࣸ झ ू १ ঌ
# ঱ ৖ ৻ ਠ ੅ ੪
# એ ઴ ૙ ૾ ଣ ୈ
# ୭ ஒ ஷ ௜ ఁ ద
# ో ౰ ಕ ಺ ೟ ഄ

# %%
for cod in letras_negras:
    print('n: ' + cod, end = ',')
    f,c,o = cods1.Ninv(cod)
    print ('Numero: ' +str(o), end = ',')
    print ('Fila: '+ str(f), end = ',')
    print ('Columnas: ' + str(c))
# Out:
# n: ā,Numero: 1,Fila: 0,Columnas: 0
# n: Ħ,Numero: 1,Fila: 0,Columnas: 1
# n: ŋ,Numero: 1,Fila: 0,Columnas: 2
# n: Ű,Numero: 1,Fila: 0,Columnas: 3
# n: ƕ,Numero: 1,Fila: 0,Columnas: 4
# n: ƺ,Numero: 1,Fila: 0,Columnas: 5
# n: ǟ,Numero: 1,Fila: 1,Columnas: 0
# n: Ȅ,Numero: 1,Fila: 1,Columnas: 1
# n: ȩ,Numero: 1,Fila: 1,Columnas: 2
# n: Ɏ,Numero: 1,Fila: 1,Columnas: 3
# n: ɳ,Numero: 1,Fila: 1,Columnas: 4
# n: ʘ,Numero: 1,Fila: 1,Columnas: 5
# n: ʽ,Numero: 1,Fila: 2,Columnas: 0
# n: ˢ,Numero: 1,Fila: 2,Columnas: 1
# n: ̇,Numero: 1,Fila: 2,Columnas: 2
# n: ̬,Numero: 1,Fila: 2,Columnas: 3
# n: ͑,Numero: 1,Fila: 2,Columnas: 4
# n: Ͷ,Numero: 1,Fila: 2,Columnas: 5
# n: Λ,Numero: 1,Fila: 3,Columnas: 0
# n: π,Numero: 1,Fila: 3,Columnas: 1
# n: ϥ,Numero: 1,Fila: 3,Columnas: 2
# n: Њ,Numero: 1,Fila: 3,Columnas: 3
# n: Я,Numero: 1,Fila: 3,Columnas: 4
# n: є,Numero: 1,Fila: 3,Columnas: 5
# n: ѹ,Numero: 1,Fila: 4,Columnas: 0
# n: Ҟ,Numero: 1,Fila: 4,Columnas: 1
# n: Ӄ,Numero: 1,Fila: 4,Columnas: 2
# n: Ө,Numero: 1,Fila: 4,Columnas: 3
# n: ԍ,Numero: 1,Fila: 4,Columnas: 4
# n: Բ,Numero: 1,Fila: 4,Columnas: 5
# n: ՗,Numero: 1,Fila: 5,Columnas: 0
# n: ռ,Numero: 1,Fila: 5,Columnas: 1
# n: ֡,Numero: 1,Fila: 5,Columnas: 2
# n: ׆,Numero: 1,Fila: 5,Columnas: 3
# n: ׫,Numero: 1,Fila: 5,Columnas: 4
# n: ؐ,Numero: 1,Fila: 5,Columnas: 5
# n: Ă,Numero: 2,Fila: 0,Columnas: 0
# n: ħ,Numero: 2,Fila: 0,Columnas: 1
# n: Ō,Numero: 2,Fila: 0,Columnas: 2
# n: ű,Numero: 2,Fila: 0,Columnas: 3
# n: Ɩ,Numero: 2,Fila: 0,Columnas: 4
# n: ƻ,Numero: 2,Fila: 0,Columnas: 5
# n: Ǡ,Numero: 2,Fila: 1,Columnas: 0
# n: ȅ,Numero: 2,Fila: 1,Columnas: 1
# n: Ȫ,Numero: 2,Fila: 1,Columnas: 2
# n: ɏ,Numero: 2,Fila: 1,Columnas: 3
# n: ɴ,Numero: 2,Fila: 1,Columnas: 4
# n: ʙ,Numero: 2,Fila: 1,Columnas: 5
# n: ʾ,Numero: 2,Fila: 2,Columnas: 0
# n: ˣ,Numero: 2,Fila: 2,Columnas: 1
# n: ̈,Numero: 2,Fila: 2,Columnas: 2
# n: ̭,Numero: 2,Fila: 2,Columnas: 3
# n: ͒,Numero: 2,Fila: 2,Columnas: 4
# n: ͷ,Numero: 2,Fila: 2,Columnas: 5
# n: Μ,Numero: 2,Fila: 3,Columnas: 0
# n: ρ,Numero: 2,Fila: 3,Columnas: 1
# n: Ϧ,Numero: 2,Fila: 3,Columnas: 2
# n: Ћ,Numero: 2,Fila: 3,Columnas: 3
# n: а,Numero: 2,Fila: 3,Columnas: 4
# n: ѕ,Numero: 2,Fila: 3,Columnas: 5
# n: Ѻ,Numero: 2,Fila: 4,Columnas: 0
# n: ҟ,Numero: 2,Fila: 4,Columnas: 1
# n: ӄ,Numero: 2,Fila: 4,Columnas: 2
# n: ө,Numero: 2,Fila: 4,Columnas: 3
# n: Ԏ,Numero: 2,Fila: 4,Columnas: 4
# n: Գ,Numero: 2,Fila: 4,Columnas: 5
# n: ՘,Numero: 2,Fila: 5,Columnas: 0
# n: ս,Numero: 2,Fila: 5,Columnas: 1
# n: ֢,Numero: 2,Fila: 5,Columnas: 2
# n: ׇ,Numero: 2,Fila: 5,Columnas: 3
# n: ׬,Numero: 2,Fila: 5,Columnas: 4
# n: ؑ,Numero: 2,Fila: 5,Columnas: 5
# n: ă,Numero: 3,Fila: 0,Columnas: 0
# n: Ĩ,Numero: 3,Fila: 0,Columnas: 1
# n: ō,Numero: 3,Fila: 0,Columnas: 2
# n: Ų,Numero: 3,Fila: 0,Columnas: 3
# n: Ɨ,Numero: 3,Fila: 0,Columnas: 4
# n: Ƽ,Numero: 3,Fila: 0,Columnas: 5
# n: ǡ,Numero: 3,Fila: 1,Columnas: 0
# n: Ȇ,Numero: 3,Fila: 1,Columnas: 1
# n: ȫ,Numero: 3,Fila: 1,Columnas: 2
# n: ɐ,Numero: 3,Fila: 1,Columnas: 3
# n: ɵ,Numero: 3,Fila: 1,Columnas: 4
# n: ʚ,Numero: 3,Fila: 1,Columnas: 5
# n: ʿ,Numero: 3,Fila: 2,Columnas: 0
# n: ˤ,Numero: 3,Fila: 2,Columnas: 1
# n: ̉,Numero: 3,Fila: 2,Columnas: 2
# n: ̮,Numero: 3,Fila: 2,Columnas: 3
# n: ͓,Numero: 3,Fila: 2,Columnas: 4
# n: ͸,Numero: 3,Fila: 2,Columnas: 5
# n: Ν,Numero: 3,Fila: 3,Columnas: 0
# n: ς,Numero: 3,Fila: 3,Columnas: 1
# n: ϧ,Numero: 3,Fila: 3,Columnas: 2
# n: Ќ,Numero: 3,Fila: 3,Columnas: 3
# n: б,Numero: 3,Fila: 3,Columnas: 4
# n: і,Numero: 3,Fila: 3,Columnas: 5
# n: ѻ,Numero: 3,Fila: 4,Columnas: 0
# n: Ҡ,Numero: 3,Fila: 4,Columnas: 1
# n: Ӆ,Numero: 3,Fila: 4,Columnas: 2
# n: Ӫ,Numero: 3,Fila: 4,Columnas: 3
# n: ԏ,Numero: 3,Fila: 4,Columnas: 4
# n: Դ,Numero: 3,Fila: 4,Columnas: 5
# n: ՙ,Numero: 3,Fila: 5,Columnas: 0
# n: վ,Numero: 3,Fila: 5,Columnas: 1
# n: ֣,Numero: 3,Fila: 5,Columnas: 2
# n: ׈,Numero: 3,Fila: 5,Columnas: 3
# n: ׭,Numero: 3,Fila: 5,Columnas: 4
# n: ؒ,Numero: 3,Fila: 5,Columnas: 5
# n: Ą,Numero: 4,Fila: 0,Columnas: 0
# n: ĩ,Numero: 4,Fila: 0,Columnas: 1
# n: Ŏ,Numero: 4,Fila: 0,Columnas: 2
# n: ų,Numero: 4,Fila: 0,Columnas: 3
# n: Ƙ,Numero: 4,Fila: 0,Columnas: 4
# n: ƽ,Numero: 4,Fila: 0,Columnas: 5
# n: Ǣ,Numero: 4,Fila: 1,Columnas: 0
# n: ȇ,Numero: 4,Fila: 1,Columnas: 1
# n: Ȭ,Numero: 4,Fila: 1,Columnas: 2
# n: ɑ,Numero: 4,Fila: 1,Columnas: 3
# n: ɶ,Numero: 4,Fila: 1,Columnas: 4
# n: ʛ,Numero: 4,Fila: 1,Columnas: 5
# n: ˀ,Numero: 4,Fila: 2,Columnas: 0
# n: ˥,Numero: 4,Fila: 2,Columnas: 1
# n: ̊,Numero: 4,Fila: 2,Columnas: 2
# n: ̯,Numero: 4,Fila: 2,Columnas: 3
# n: ͔,Numero: 4,Fila: 2,Columnas: 4
# n: ͹,Numero: 4,Fila: 2,Columnas: 5
# n: Ξ,Numero: 4,Fila: 3,Columnas: 0
# n: σ,Numero: 4,Fila: 3,Columnas: 1
# n: Ϩ,Numero: 4,Fila: 3,Columnas: 2
# n: Ѝ,Numero: 4,Fila: 3,Columnas: 3
# n: в,Numero: 4,Fila: 3,Columnas: 4
# n: ї,Numero: 4,Fila: 3,Columnas: 5
# n: Ѽ,Numero: 4,Fila: 4,Columnas: 0
# n: ҡ,Numero: 4,Fila: 4,Columnas: 1
# n: ӆ,Numero: 4,Fila: 4,Columnas: 2
# n: ӫ,Numero: 4,Fila: 4,Columnas: 3
# n: Ԑ,Numero: 4,Fila: 4,Columnas: 4
# n: Ե,Numero: 4,Fila: 4,Columnas: 5
# n: ՚,Numero: 4,Fila: 5,Columnas: 0
# n: տ,Numero: 4,Fila: 5,Columnas: 1
# n: ֤,Numero: 4,Fila: 5,Columnas: 2
# n: ׉,Numero: 4,Fila: 5,Columnas: 3
# n: ׮,Numero: 4,Fila: 5,Columnas: 4
# n: ؓ,Numero: 4,Fila: 5,Columnas: 5
# n: ą,Numero: 5,Fila: 0,Columnas: 0
# n: Ī,Numero: 5,Fila: 0,Columnas: 1
# n: ŏ,Numero: 5,Fila: 0,Columnas: 2
# n: Ŵ,Numero: 5,Fila: 0,Columnas: 3
# n: ƙ,Numero: 5,Fila: 0,Columnas: 4
# n: ƾ,Numero: 5,Fila: 0,Columnas: 5
# n: ǣ,Numero: 5,Fila: 1,Columnas: 0
# n: Ȉ,Numero: 5,Fila: 1,Columnas: 1
# n: ȭ,Numero: 5,Fila: 1,Columnas: 2
# n: ɒ,Numero: 5,Fila: 1,Columnas: 3
# n: ɷ,Numero: 5,Fila: 1,Columnas: 4
# n: ʜ,Numero: 5,Fila: 1,Columnas: 5
# n: ˁ,Numero: 5,Fila: 2,Columnas: 0
# n: ˦,Numero: 5,Fila: 2,Columnas: 1
# n: ̋,Numero: 5,Fila: 2,Columnas: 2
# n: ̰,Numero: 5,Fila: 2,Columnas: 3
# n: ͕,Numero: 5,Fila: 2,Columnas: 4
# n: ͺ,Numero: 5,Fila: 2,Columnas: 5
# n: Ο,Numero: 5,Fila: 3,Columnas: 0
# n: τ,Numero: 5,Fila: 3,Columnas: 1
# n: ϩ,Numero: 5,Fila: 3,Columnas: 2
# n: Ў,Numero: 5,Fila: 3,Columnas: 3
# n: г,Numero: 5,Fila: 3,Columnas: 4
# n: ј,Numero: 5,Fila: 3,Columnas: 5
# n: ѽ,Numero: 5,Fila: 4,Columnas: 0
# n: Ң,Numero: 5,Fila: 4,Columnas: 1
# n: Ӈ,Numero: 5,Fila: 4,Columnas: 2
# n: Ӭ,Numero: 5,Fila: 4,Columnas: 3
# n: ԑ,Numero: 5,Fila: 4,Columnas: 4
# n: Զ,Numero: 5,Fila: 4,Columnas: 5
# n: ՛,Numero: 5,Fila: 5,Columnas: 0
# n: ր,Numero: 5,Fila: 5,Columnas: 1
# n: ֥,Numero: 5,Fila: 5,Columnas: 2
# n: ׊,Numero: 5,Fila: 5,Columnas: 3
# n: ׯ,Numero: 5,Fila: 5,Columnas: 4
# n: ؔ,Numero: 5,Fila: 5,Columnas: 5
# n: Ć,Numero: 6,Fila: 0,Columnas: 0
# n: ī,Numero: 6,Fila: 0,Columnas: 1
# n: Ő,Numero: 6,Fila: 0,Columnas: 2
# n: ŵ,Numero: 6,Fila: 0,Columnas: 3
# n: ƚ,Numero: 6,Fila: 0,Columnas: 4
# n: ƿ,Numero: 6,Fila: 0,Columnas: 5
# n: Ǥ,Numero: 6,Fila: 1,Columnas: 0
# n: ȉ,Numero: 6,Fila: 1,Columnas: 1
# n: Ȯ,Numero: 6,Fila: 1,Columnas: 2
# n: ɓ,Numero: 6,Fila: 1,Columnas: 3
# n: ɸ,Numero: 6,Fila: 1,Columnas: 4
# n: ʝ,Numero: 6,Fila: 1,Columnas: 5
# n: ˂,Numero: 6,Fila: 2,Columnas: 0
# n: ˧,Numero: 6,Fila: 2,Columnas: 1
# n: ̌,Numero: 6,Fila: 2,Columnas: 2
# n: ̱,Numero: 6,Fila: 2,Columnas: 3
# n: ͖,Numero: 6,Fila: 2,Columnas: 4
# n: ͻ,Numero: 6,Fila: 2,Columnas: 5
# n: Π,Numero: 6,Fila: 3,Columnas: 0
# n: υ,Numero: 6,Fila: 3,Columnas: 1
# n: Ϫ,Numero: 6,Fila: 3,Columnas: 2
# n: Џ,Numero: 6,Fila: 3,Columnas: 3
# n: д,Numero: 6,Fila: 3,Columnas: 4
# n: љ,Numero: 6,Fila: 3,Columnas: 5
# n: Ѿ,Numero: 6,Fila: 4,Columnas: 0
# n: ң,Numero: 6,Fila: 4,Columnas: 1
# n: ӈ,Numero: 6,Fila: 4,Columnas: 2
# n: ӭ,Numero: 6,Fila: 4,Columnas: 3
# n: Ԓ,Numero: 6,Fila: 4,Columnas: 4
# n: Է,Numero: 6,Fila: 4,Columnas: 5
# n: ՜,Numero: 6,Fila: 5,Columnas: 0
# n: ց,Numero: 6,Fila: 5,Columnas: 1
# n: ֦,Numero: 6,Fila: 5,Columnas: 2
# n: ׋,Numero: 6,Fila: 5,Columnas: 3
# n: װ,Numero: 6,Fila: 5,Columnas: 4
# n: ؕ,Numero: 6,Fila: 5,Columnas: 5
# n: ć,Numero: 7,Fila: 0,Columnas: 0
# n: Ĭ,Numero: 7,Fila: 0,Columnas: 1
# n: ő,Numero: 7,Fila: 0,Columnas: 2
# n: Ŷ,Numero: 7,Fila: 0,Columnas: 3
# n: ƛ,Numero: 7,Fila: 0,Columnas: 4
# n: ǀ,Numero: 7,Fila: 0,Columnas: 5
# n: ǥ,Numero: 7,Fila: 1,Columnas: 0
# n: Ȋ,Numero: 7,Fila: 1,Columnas: 1
# n: ȯ,Numero: 7,Fila: 1,Columnas: 2
# n: ɔ,Numero: 7,Fila: 1,Columnas: 3
# n: ɹ,Numero: 7,Fila: 1,Columnas: 4
# n: ʞ,Numero: 7,Fila: 1,Columnas: 5
# n: ˃,Numero: 7,Fila: 2,Columnas: 0
# n: ˨,Numero: 7,Fila: 2,Columnas: 1
# n: ̍,Numero: 7,Fila: 2,Columnas: 2
# n: ̲,Numero: 7,Fila: 2,Columnas: 3
# n: ͗,Numero: 7,Fila: 2,Columnas: 4
# n: ͼ,Numero: 7,Fila: 2,Columnas: 5
# n: Ρ,Numero: 7,Fila: 3,Columnas: 0
# n: φ,Numero: 7,Fila: 3,Columnas: 1
# n: ϫ,Numero: 7,Fila: 3,Columnas: 2
# n: А,Numero: 7,Fila: 3,Columnas: 3
# n: е,Numero: 7,Fila: 3,Columnas: 4
# n: њ,Numero: 7,Fila: 3,Columnas: 5
# n: ѿ,Numero: 7,Fila: 4,Columnas: 0
# n: Ҥ,Numero: 7,Fila: 4,Columnas: 1
# n: Ӊ,Numero: 7,Fila: 4,Columnas: 2
# n: Ӯ,Numero: 7,Fila: 4,Columnas: 3
# n: ԓ,Numero: 7,Fila: 4,Columnas: 4
# n: Ը,Numero: 7,Fila: 4,Columnas: 5
# n: ՝,Numero: 7,Fila: 5,Columnas: 0
# n: ւ,Numero: 7,Fila: 5,Columnas: 1
# n: ֧,Numero: 7,Fila: 5,Columnas: 2
# n: ׌,Numero: 7,Fila: 5,Columnas: 3
# n: ױ,Numero: 7,Fila: 5,Columnas: 4
# n: ؖ,Numero: 7,Fila: 5,Columnas: 5
# n: Ĉ,Numero: 8,Fila: 0,Columnas: 0
# n: ĭ,Numero: 8,Fila: 0,Columnas: 1
# n: Œ,Numero: 8,Fila: 0,Columnas: 2
# n: ŷ,Numero: 8,Fila: 0,Columnas: 3
# n: Ɯ,Numero: 8,Fila: 0,Columnas: 4
# n: ǁ,Numero: 8,Fila: 0,Columnas: 5
# n: Ǧ,Numero: 8,Fila: 1,Columnas: 0
# n: ȋ,Numero: 8,Fila: 1,Columnas: 1
# n: Ȱ,Numero: 8,Fila: 1,Columnas: 2
# n: ɕ,Numero: 8,Fila: 1,Columnas: 3
# n: ɺ,Numero: 8,Fila: 1,Columnas: 4
# n: ʟ,Numero: 8,Fila: 1,Columnas: 5
# n: ˄,Numero: 8,Fila: 2,Columnas: 0
# n: ˩,Numero: 8,Fila: 2,Columnas: 1
# n: ̎,Numero: 8,Fila: 2,Columnas: 2
# n: ̳,Numero: 8,Fila: 2,Columnas: 3
# n: ͘,Numero: 8,Fila: 2,Columnas: 4
# n: ͽ,Numero: 8,Fila: 2,Columnas: 5
# n: ΢,Numero: 8,Fila: 3,Columnas: 0
# n: χ,Numero: 8,Fila: 3,Columnas: 1
# n: Ϭ,Numero: 8,Fila: 3,Columnas: 2
# n: Б,Numero: 8,Fila: 3,Columnas: 3
# n: ж,Numero: 8,Fila: 3,Columnas: 4
# n: ћ,Numero: 8,Fila: 3,Columnas: 5
# n: Ҁ,Numero: 8,Fila: 4,Columnas: 0
# n: ҥ,Numero: 8,Fila: 4,Columnas: 1
# n: ӊ,Numero: 8,Fila: 4,Columnas: 2
# n: ӯ,Numero: 8,Fila: 4,Columnas: 3
# n: Ԕ,Numero: 8,Fila: 4,Columnas: 4
# n: Թ,Numero: 8,Fila: 4,Columnas: 5
# n: ՞,Numero: 8,Fila: 5,Columnas: 0
# n: փ,Numero: 8,Fila: 5,Columnas: 1
# n: ֨,Numero: 8,Fila: 5,Columnas: 2
# n: ׍,Numero: 8,Fila: 5,Columnas: 3
# n: ײ,Numero: 8,Fila: 5,Columnas: 4
# n: ؗ,Numero: 8,Fila: 5,Columnas: 5
# n: ĉ,Numero: 9,Fila: 0,Columnas: 0
# n: Į,Numero: 9,Fila: 0,Columnas: 1
# n: œ,Numero: 9,Fila: 0,Columnas: 2
# n: Ÿ,Numero: 9,Fila: 0,Columnas: 3
# n: Ɲ,Numero: 9,Fila: 0,Columnas: 4
# n: ǂ,Numero: 9,Fila: 0,Columnas: 5
# n: ǧ,Numero: 9,Fila: 1,Columnas: 0
# n: Ȍ,Numero: 9,Fila: 1,Columnas: 1
# n: ȱ,Numero: 9,Fila: 1,Columnas: 2
# n: ɖ,Numero: 9,Fila: 1,Columnas: 3
# n: ɻ,Numero: 9,Fila: 1,Columnas: 4
# n: ʠ,Numero: 9,Fila: 1,Columnas: 5
# n: ˅,Numero: 9,Fila: 2,Columnas: 0
# n: ˪,Numero: 9,Fila: 2,Columnas: 1
# n: ̏,Numero: 9,Fila: 2,Columnas: 2
# n: ̴,Numero: 9,Fila: 2,Columnas: 3
# n: ͙,Numero: 9,Fila: 2,Columnas: 4
# n: ;,Numero: 9,Fila: 2,Columnas: 5
# n: Σ,Numero: 9,Fila: 3,Columnas: 0
# n: ψ,Numero: 9,Fila: 3,Columnas: 1
# n: ϭ,Numero: 9,Fila: 3,Columnas: 2
# n: В,Numero: 9,Fila: 3,Columnas: 3
# n: з,Numero: 9,Fila: 3,Columnas: 4
# n: ќ,Numero: 9,Fila: 3,Columnas: 5
# n: ҁ,Numero: 9,Fila: 4,Columnas: 0
# n: Ҧ,Numero: 9,Fila: 4,Columnas: 1
# n: Ӌ,Numero: 9,Fila: 4,Columnas: 2
# n: Ӱ,Numero: 9,Fila: 4,Columnas: 3
# n: ԕ,Numero: 9,Fila: 4,Columnas: 4
# n: Ժ,Numero: 9,Fila: 4,Columnas: 5
# n: ՟,Numero: 9,Fila: 5,Columnas: 0
# n: ք,Numero: 9,Fila: 5,Columnas: 1
# n: ֩,Numero: 9,Fila: 5,Columnas: 2
# n: ׎,Numero: 9,Fila: 5,Columnas: 3
# n: ׳,Numero: 9,Fila: 5,Columnas: 4
# n: ؘ,Numero: 9,Fila: 5,Columnas: 5
# n: Ċ,Numero: 10,Fila: 0,Columnas: 0
# n: į,Numero: 10,Fila: 0,Columnas: 1
# n: Ŕ,Numero: 10,Fila: 0,Columnas: 2
# n: Ź,Numero: 10,Fila: 0,Columnas: 3
# n: ƞ,Numero: 10,Fila: 0,Columnas: 4
# n: ǃ,Numero: 10,Fila: 0,Columnas: 5
# n: Ǩ,Numero: 10,Fila: 1,Columnas: 0
# n: ȍ,Numero: 10,Fila: 1,Columnas: 1
# n: Ȳ,Numero: 10,Fila: 1,Columnas: 2
# n: ɗ,Numero: 10,Fila: 1,Columnas: 3
# n: ɼ,Numero: 10,Fila: 1,Columnas: 4
# n: ʡ,Numero: 10,Fila: 1,Columnas: 5
# n: ˆ,Numero: 10,Fila: 2,Columnas: 0
# n: ˫,Numero: 10,Fila: 2,Columnas: 1
# n: ̐,Numero: 10,Fila: 2,Columnas: 2
# n: ̵,Numero: 10,Fila: 2,Columnas: 3
# n: ͚,Numero: 10,Fila: 2,Columnas: 4
# n: Ϳ,Numero: 10,Fila: 2,Columnas: 5
# n: Τ,Numero: 10,Fila: 3,Columnas: 0
# n: ω,Numero: 10,Fila: 3,Columnas: 1
# n: Ϯ,Numero: 10,Fila: 3,Columnas: 2
# n: Г,Numero: 10,Fila: 3,Columnas: 3
# n: и,Numero: 10,Fila: 3,Columnas: 4
# n: ѝ,Numero: 10,Fila: 3,Columnas: 5
# n: ҂,Numero: 10,Fila: 4,Columnas: 0
# n: ҧ,Numero: 10,Fila: 4,Columnas: 1
# n: ӌ,Numero: 10,Fila: 4,Columnas: 2
# n: ӱ,Numero: 10,Fila: 4,Columnas: 3
# n: Ԗ,Numero: 10,Fila: 4,Columnas: 4
# n: Ի,Numero: 10,Fila: 4,Columnas: 5
# n: ՠ,Numero: 10,Fila: 5,Columnas: 0
# n: օ,Numero: 10,Fila: 5,Columnas: 1
# n: ֪,Numero: 10,Fila: 5,Columnas: 2
# n: ׏,Numero: 10,Fila: 5,Columnas: 3
# n: ״,Numero: 10,Fila: 5,Columnas: 4
# n: ؙ,Numero: 10,Fila: 5,Columnas: 5
# n: ċ,Numero: 11,Fila: 0,Columnas: 0
# n: İ,Numero: 11,Fila: 0,Columnas: 1
# n: ŕ,Numero: 11,Fila: 0,Columnas: 2
# n: ź,Numero: 11,Fila: 0,Columnas: 3
# n: Ɵ,Numero: 11,Fila: 0,Columnas: 4
# n: Ǆ,Numero: 11,Fila: 0,Columnas: 5
# n: ǩ,Numero: 11,Fila: 1,Columnas: 0
# n: Ȏ,Numero: 11,Fila: 1,Columnas: 1
# n: ȳ,Numero: 11,Fila: 1,Columnas: 2
# n: ɘ,Numero: 11,Fila: 1,Columnas: 3
# n: ɽ,Numero: 11,Fila: 1,Columnas: 4
# n: ʢ,Numero: 11,Fila: 1,Columnas: 5
# n: ˇ,Numero: 11,Fila: 2,Columnas: 0
# n: ˬ,Numero: 11,Fila: 2,Columnas: 1
# n: ̑,Numero: 11,Fila: 2,Columnas: 2
# n: ̶,Numero: 11,Fila: 2,Columnas: 3
# n: ͛,Numero: 11,Fila: 2,Columnas: 4
# n: ΀,Numero: 11,Fila: 2,Columnas: 5
# n: Υ,Numero: 11,Fila: 3,Columnas: 0
# n: ϊ,Numero: 11,Fila: 3,Columnas: 1
# n: ϯ,Numero: 11,Fila: 3,Columnas: 2
# n: Д,Numero: 11,Fila: 3,Columnas: 3
# n: й,Numero: 11,Fila: 3,Columnas: 4
# n: ў,Numero: 11,Fila: 3,Columnas: 5
# n: ҃,Numero: 11,Fila: 4,Columnas: 0
# n: Ҩ,Numero: 11,Fila: 4,Columnas: 1
# n: Ӎ,Numero: 11,Fila: 4,Columnas: 2
# n: Ӳ,Numero: 11,Fila: 4,Columnas: 3
# n: ԗ,Numero: 11,Fila: 4,Columnas: 4
# n: Լ,Numero: 11,Fila: 4,Columnas: 5
# n: ա,Numero: 11,Fila: 5,Columnas: 0
# n: ֆ,Numero: 11,Fila: 5,Columnas: 1
# n: ֫,Numero: 11,Fila: 5,Columnas: 2
# n: א,Numero: 11,Fila: 5,Columnas: 3
# n: ׵,Numero: 11,Fila: 5,Columnas: 4
# n: ؚ,Numero: 11,Fila: 5,Columnas: 5
# n: Č,Numero: 12,Fila: 0,Columnas: 0
# n: ı,Numero: 12,Fila: 0,Columnas: 1
# n: Ŗ,Numero: 12,Fila: 0,Columnas: 2
# n: Ż,Numero: 12,Fila: 0,Columnas: 3
# n: Ơ,Numero: 12,Fila: 0,Columnas: 4
# n: ǅ,Numero: 12,Fila: 0,Columnas: 5
# n: Ǫ,Numero: 12,Fila: 1,Columnas: 0
# n: ȏ,Numero: 12,Fila: 1,Columnas: 1
# n: ȴ,Numero: 12,Fila: 1,Columnas: 2
# n: ə,Numero: 12,Fila: 1,Columnas: 3
# n: ɾ,Numero: 12,Fila: 1,Columnas: 4
# n: ʣ,Numero: 12,Fila: 1,Columnas: 5
# n: ˈ,Numero: 12,Fila: 2,Columnas: 0
# n: ˭,Numero: 12,Fila: 2,Columnas: 1
# n: ̒,Numero: 12,Fila: 2,Columnas: 2
# n: ̷,Numero: 12,Fila: 2,Columnas: 3
# n: ͜,Numero: 12,Fila: 2,Columnas: 4
# n: ΁,Numero: 12,Fila: 2,Columnas: 5
# n: Φ,Numero: 12,Fila: 3,Columnas: 0
# n: ϋ,Numero: 12,Fila: 3,Columnas: 1
# n: ϰ,Numero: 12,Fila: 3,Columnas: 2
# n: Е,Numero: 12,Fila: 3,Columnas: 3
# n: к,Numero: 12,Fila: 3,Columnas: 4
# n: џ,Numero: 12,Fila: 3,Columnas: 5
# n: ҄,Numero: 12,Fila: 4,Columnas: 0
# n: ҩ,Numero: 12,Fila: 4,Columnas: 1
# n: ӎ,Numero: 12,Fila: 4,Columnas: 2
# n: ӳ,Numero: 12,Fila: 4,Columnas: 3
# n: Ԙ,Numero: 12,Fila: 4,Columnas: 4
# n: Խ,Numero: 12,Fila: 4,Columnas: 5
# n: բ,Numero: 12,Fila: 5,Columnas: 0
# n: և,Numero: 12,Fila: 5,Columnas: 1
# n: ֬,Numero: 12,Fila: 5,Columnas: 2
# n: ב,Numero: 12,Fila: 5,Columnas: 3
# n: ׶,Numero: 12,Fila: 5,Columnas: 4
# n: ؛,Numero: 12,Fila: 5,Columnas: 5
# n: č,Numero: 13,Fila: 0,Columnas: 0
# n: Ĳ,Numero: 13,Fila: 0,Columnas: 1
# n: ŗ,Numero: 13,Fila: 0,Columnas: 2
# n: ż,Numero: 13,Fila: 0,Columnas: 3
# n: ơ,Numero: 13,Fila: 0,Columnas: 4
# n: ǆ,Numero: 13,Fila: 0,Columnas: 5
# n: ǫ,Numero: 13,Fila: 1,Columnas: 0
# n: Ȑ,Numero: 13,Fila: 1,Columnas: 1
# n: ȵ,Numero: 13,Fila: 1,Columnas: 2
# n: ɚ,Numero: 13,Fila: 1,Columnas: 3
# n: ɿ,Numero: 13,Fila: 1,Columnas: 4
# n: ʤ,Numero: 13,Fila: 1,Columnas: 5
# n: ˉ,Numero: 13,Fila: 2,Columnas: 0
# n: ˮ,Numero: 13,Fila: 2,Columnas: 1
# n: ̓,Numero: 13,Fila: 2,Columnas: 2
# n: ̸,Numero: 13,Fila: 2,Columnas: 3
# n: ͝,Numero: 13,Fila: 2,Columnas: 4
# n: ΂,Numero: 13,Fila: 2,Columnas: 5
# n: Χ,Numero: 13,Fila: 3,Columnas: 0
# n: ό,Numero: 13,Fila: 3,Columnas: 1
# n: ϱ,Numero: 13,Fila: 3,Columnas: 2
# n: Ж,Numero: 13,Fila: 3,Columnas: 3
# n: л,Numero: 13,Fila: 3,Columnas: 4
# n: Ѡ,Numero: 13,Fila: 3,Columnas: 5
# n: ҅,Numero: 13,Fila: 4,Columnas: 0
# n: Ҫ,Numero: 13,Fila: 4,Columnas: 1
# n: ӏ,Numero: 13,Fila: 4,Columnas: 2
# n: Ӵ,Numero: 13,Fila: 4,Columnas: 3
# n: ԙ,Numero: 13,Fila: 4,Columnas: 4
# n: Ծ,Numero: 13,Fila: 4,Columnas: 5
# n: գ,Numero: 13,Fila: 5,Columnas: 0
# n: ֈ,Numero: 13,Fila: 5,Columnas: 1
# n: ֭,Numero: 13,Fila: 5,Columnas: 2
# n: ג,Numero: 13,Fila: 5,Columnas: 3
# n: ׷,Numero: 13,Fila: 5,Columnas: 4
# n: ؜,Numero: 13,Fila: 5,Columnas: 5
# n: Ď,Numero: 14,Fila: 0,Columnas: 0
# n: ĳ,Numero: 14,Fila: 0,Columnas: 1
# n: Ř,Numero: 14,Fila: 0,Columnas: 2
# n: Ž,Numero: 14,Fila: 0,Columnas: 3
# n: Ƣ,Numero: 14,Fila: 0,Columnas: 4
# n: Ǉ,Numero: 14,Fila: 0,Columnas: 5
# n: Ǭ,Numero: 14,Fila: 1,Columnas: 0
# n: ȑ,Numero: 14,Fila: 1,Columnas: 1
# n: ȶ,Numero: 14,Fila: 1,Columnas: 2
# n: ɛ,Numero: 14,Fila: 1,Columnas: 3
# n: ʀ,Numero: 14,Fila: 1,Columnas: 4
# n: ʥ,Numero: 14,Fila: 1,Columnas: 5
# n: ˊ,Numero: 14,Fila: 2,Columnas: 0
# n: ˯,Numero: 14,Fila: 2,Columnas: 1
# n: ̔,Numero: 14,Fila: 2,Columnas: 2
# n: ̹,Numero: 14,Fila: 2,Columnas: 3
# n: ͞,Numero: 14,Fila: 2,Columnas: 4
# n: ΃,Numero: 14,Fila: 2,Columnas: 5
# n: Ψ,Numero: 14,Fila: 3,Columnas: 0
# n: ύ,Numero: 14,Fila: 3,Columnas: 1
# n: ϲ,Numero: 14,Fila: 3,Columnas: 2
# n: З,Numero: 14,Fila: 3,Columnas: 3
# n: м,Numero: 14,Fila: 3,Columnas: 4
# n: ѡ,Numero: 14,Fila: 3,Columnas: 5
# n: ҆,Numero: 14,Fila: 4,Columnas: 0
# n: ҫ,Numero: 14,Fila: 4,Columnas: 1
# n: Ӑ,Numero: 14,Fila: 4,Columnas: 2
# n: ӵ,Numero: 14,Fila: 4,Columnas: 3
# n: Ԛ,Numero: 14,Fila: 4,Columnas: 4
# n: Կ,Numero: 14,Fila: 4,Columnas: 5
# n: դ,Numero: 14,Fila: 5,Columnas: 0
# n: ։,Numero: 14,Fila: 5,Columnas: 1
# n: ֮,Numero: 14,Fila: 5,Columnas: 2
# n: ד,Numero: 14,Fila: 5,Columnas: 3
# n: ׸,Numero: 14,Fila: 5,Columnas: 4
# n: ؝,Numero: 14,Fila: 5,Columnas: 5
# n: ď,Numero: 15,Fila: 0,Columnas: 0
# n: Ĵ,Numero: 15,Fila: 0,Columnas: 1
# n: ř,Numero: 15,Fila: 0,Columnas: 2
# n: ž,Numero: 15,Fila: 0,Columnas: 3
# n: ƣ,Numero: 15,Fila: 0,Columnas: 4
# n: ǈ,Numero: 15,Fila: 0,Columnas: 5
# n: ǭ,Numero: 15,Fila: 1,Columnas: 0
# n: Ȓ,Numero: 15,Fila: 1,Columnas: 1
# n: ȷ,Numero: 15,Fila: 1,Columnas: 2
# n: ɜ,Numero: 15,Fila: 1,Columnas: 3
# n: ʁ,Numero: 15,Fila: 1,Columnas: 4
# n: ʦ,Numero: 15,Fila: 1,Columnas: 5
# n: ˋ,Numero: 15,Fila: 2,Columnas: 0
# n: ˰,Numero: 15,Fila: 2,Columnas: 1
# n: ̕,Numero: 15,Fila: 2,Columnas: 2
# n: ̺,Numero: 15,Fila: 2,Columnas: 3
# n: ͟,Numero: 15,Fila: 2,Columnas: 4
# n: ΄,Numero: 15,Fila: 2,Columnas: 5
# n: Ω,Numero: 15,Fila: 3,Columnas: 0
# n: ώ,Numero: 15,Fila: 3,Columnas: 1
# n: ϳ,Numero: 15,Fila: 3,Columnas: 2
# n: И,Numero: 15,Fila: 3,Columnas: 3
# n: н,Numero: 15,Fila: 3,Columnas: 4
# n: Ѣ,Numero: 15,Fila: 3,Columnas: 5
# n: ҇,Numero: 15,Fila: 4,Columnas: 0
# n: Ҭ,Numero: 15,Fila: 4,Columnas: 1
# n: ӑ,Numero: 15,Fila: 4,Columnas: 2
# n: Ӷ,Numero: 15,Fila: 4,Columnas: 3
# n: ԛ,Numero: 15,Fila: 4,Columnas: 4
# n: Հ,Numero: 15,Fila: 4,Columnas: 5
# n: ե,Numero: 15,Fila: 5,Columnas: 0
# n: ֊,Numero: 15,Fila: 5,Columnas: 1
# n: ֯,Numero: 15,Fila: 5,Columnas: 2
# n: ה,Numero: 15,Fila: 5,Columnas: 3
# n: ׹,Numero: 15,Fila: 5,Columnas: 4
# n: ؞,Numero: 15,Fila: 5,Columnas: 5
# n: Đ,Numero: 16,Fila: 0,Columnas: 0
# n: ĵ,Numero: 16,Fila: 0,Columnas: 1
# n: Ś,Numero: 16,Fila: 0,Columnas: 2
# n: ſ,Numero: 16,Fila: 0,Columnas: 3
# n: Ƥ,Numero: 16,Fila: 0,Columnas: 4
# n: ǉ,Numero: 16,Fila: 0,Columnas: 5
# n: Ǯ,Numero: 16,Fila: 1,Columnas: 0
# n: ȓ,Numero: 16,Fila: 1,Columnas: 1
# n: ȸ,Numero: 16,Fila: 1,Columnas: 2
# n: ɝ,Numero: 16,Fila: 1,Columnas: 3
# n: ʂ,Numero: 16,Fila: 1,Columnas: 4
# n: ʧ,Numero: 16,Fila: 1,Columnas: 5
# n: ˌ,Numero: 16,Fila: 2,Columnas: 0
# n: ˱,Numero: 16,Fila: 2,Columnas: 1
# n: ̖,Numero: 16,Fila: 2,Columnas: 2
# n: ̻,Numero: 16,Fila: 2,Columnas: 3
# n: ͠,Numero: 16,Fila: 2,Columnas: 4
# n: ΅,Numero: 16,Fila: 2,Columnas: 5
# n: Ϊ,Numero: 16,Fila: 3,Columnas: 0
# n: Ϗ,Numero: 16,Fila: 3,Columnas: 1
# n: ϴ,Numero: 16,Fila: 3,Columnas: 2
# n: Й,Numero: 16,Fila: 3,Columnas: 3
# n: о,Numero: 16,Fila: 3,Columnas: 4
# n: ѣ,Numero: 16,Fila: 3,Columnas: 5
# n: ҈,Numero: 16,Fila: 4,Columnas: 0
# n: ҭ,Numero: 16,Fila: 4,Columnas: 1
# n: Ӓ,Numero: 16,Fila: 4,Columnas: 2
# n: ӷ,Numero: 16,Fila: 4,Columnas: 3
# n: Ԝ,Numero: 16,Fila: 4,Columnas: 4
# n: Ձ,Numero: 16,Fila: 4,Columnas: 5
# n: զ,Numero: 16,Fila: 5,Columnas: 0
# n: ֋,Numero: 16,Fila: 5,Columnas: 1
# n: ְ,Numero: 16,Fila: 5,Columnas: 2
# n: ו,Numero: 16,Fila: 5,Columnas: 3
# n: ׺,Numero: 16,Fila: 5,Columnas: 4
# n: ؟,Numero: 16,Fila: 5,Columnas: 5
# n: đ,Numero: 17,Fila: 0,Columnas: 0
# n: Ķ,Numero: 17,Fila: 0,Columnas: 1
# n: ś,Numero: 17,Fila: 0,Columnas: 2
# n: ƀ,Numero: 17,Fila: 0,Columnas: 3
# n: ƥ,Numero: 17,Fila: 0,Columnas: 4
# n: Ǌ,Numero: 17,Fila: 0,Columnas: 5
# n: ǯ,Numero: 17,Fila: 1,Columnas: 0
# n: Ȕ,Numero: 17,Fila: 1,Columnas: 1
# n: ȹ,Numero: 17,Fila: 1,Columnas: 2
# n: ɞ,Numero: 17,Fila: 1,Columnas: 3
# n: ʃ,Numero: 17,Fila: 1,Columnas: 4
# n: ʨ,Numero: 17,Fila: 1,Columnas: 5
# n: ˍ,Numero: 17,Fila: 2,Columnas: 0
# n: ˲,Numero: 17,Fila: 2,Columnas: 1
# n: ̗,Numero: 17,Fila: 2,Columnas: 2
# n: ̼,Numero: 17,Fila: 2,Columnas: 3
# n: ͡,Numero: 17,Fila: 2,Columnas: 4
# n: Ά,Numero: 17,Fila: 2,Columnas: 5
# n: Ϋ,Numero: 17,Fila: 3,Columnas: 0
# n: ϐ,Numero: 17,Fila: 3,Columnas: 1
# n: ϵ,Numero: 17,Fila: 3,Columnas: 2
# n: К,Numero: 17,Fila: 3,Columnas: 3
# n: п,Numero: 17,Fila: 3,Columnas: 4
# n: Ѥ,Numero: 17,Fila: 3,Columnas: 5
# n: ҉,Numero: 17,Fila: 4,Columnas: 0
# n: Ү,Numero: 17,Fila: 4,Columnas: 1
# n: ӓ,Numero: 17,Fila: 4,Columnas: 2
# n: Ӹ,Numero: 17,Fila: 4,Columnas: 3
# n: ԝ,Numero: 17,Fila: 4,Columnas: 4
# n: Ղ,Numero: 17,Fila: 4,Columnas: 5
# n: է,Numero: 17,Fila: 5,Columnas: 0
# n: ֌,Numero: 17,Fila: 5,Columnas: 1
# n: ֱ,Numero: 17,Fila: 5,Columnas: 2
# n: ז,Numero: 17,Fila: 5,Columnas: 3
# n: ׻,Numero: 17,Fila: 5,Columnas: 4
# n: ؠ,Numero: 17,Fila: 5,Columnas: 5
# n: Ē,Numero: 18,Fila: 0,Columnas: 0
# n: ķ,Numero: 18,Fila: 0,Columnas: 1
# n: Ŝ,Numero: 18,Fila: 0,Columnas: 2
# n: Ɓ,Numero: 18,Fila: 0,Columnas: 3
# n: Ʀ,Numero: 18,Fila: 0,Columnas: 4
# n: ǋ,Numero: 18,Fila: 0,Columnas: 5
# n: ǰ,Numero: 18,Fila: 1,Columnas: 0
# n: ȕ,Numero: 18,Fila: 1,Columnas: 1
# n: Ⱥ,Numero: 18,Fila: 1,Columnas: 2
# n: ɟ,Numero: 18,Fila: 1,Columnas: 3
# n: ʄ,Numero: 18,Fila: 1,Columnas: 4
# n: ʩ,Numero: 18,Fila: 1,Columnas: 5
# n: ˎ,Numero: 18,Fila: 2,Columnas: 0
# n: ˳,Numero: 18,Fila: 2,Columnas: 1
# n: ̘,Numero: 18,Fila: 2,Columnas: 2
# n: ̽,Numero: 18,Fila: 2,Columnas: 3
# n: ͢,Numero: 18,Fila: 2,Columnas: 4
# n: ·,Numero: 18,Fila: 2,Columnas: 5
# n: ά,Numero: 18,Fila: 3,Columnas: 0
# n: ϑ,Numero: 18,Fila: 3,Columnas: 1
# n: ϶,Numero: 18,Fila: 3,Columnas: 2
# n: Л,Numero: 18,Fila: 3,Columnas: 3
# n: р,Numero: 18,Fila: 3,Columnas: 4
# n: ѥ,Numero: 18,Fila: 3,Columnas: 5
# n: Ҋ,Numero: 18,Fila: 4,Columnas: 0
# n: ү,Numero: 18,Fila: 4,Columnas: 1
# n: Ӕ,Numero: 18,Fila: 4,Columnas: 2
# n: ӹ,Numero: 18,Fila: 4,Columnas: 3
# n: Ԟ,Numero: 18,Fila: 4,Columnas: 4
# n: Ճ,Numero: 18,Fila: 4,Columnas: 5
# n: ը,Numero: 18,Fila: 5,Columnas: 0
# n: ֍,Numero: 18,Fila: 5,Columnas: 1
# n: ֲ,Numero: 18,Fila: 5,Columnas: 2
# n: ח,Numero: 18,Fila: 5,Columnas: 3
# n: ׼,Numero: 18,Fila: 5,Columnas: 4
# n: ء,Numero: 18,Fila: 5,Columnas: 5
# n: ē,Numero: 19,Fila: 0,Columnas: 0
# n: ĸ,Numero: 19,Fila: 0,Columnas: 1
# n: ŝ,Numero: 19,Fila: 0,Columnas: 2
# n: Ƃ,Numero: 19,Fila: 0,Columnas: 3
# n: Ƨ,Numero: 19,Fila: 0,Columnas: 4
# n: ǌ,Numero: 19,Fila: 0,Columnas: 5
# n: Ǳ,Numero: 19,Fila: 1,Columnas: 0
# n: Ȗ,Numero: 19,Fila: 1,Columnas: 1
# n: Ȼ,Numero: 19,Fila: 1,Columnas: 2
# n: ɠ,Numero: 19,Fila: 1,Columnas: 3
# n: ʅ,Numero: 19,Fila: 1,Columnas: 4
# n: ʪ,Numero: 19,Fila: 1,Columnas: 5
# n: ˏ,Numero: 19,Fila: 2,Columnas: 0
# n: ˴,Numero: 19,Fila: 2,Columnas: 1
# n: ̙,Numero: 19,Fila: 2,Columnas: 2
# n: ̾,Numero: 19,Fila: 2,Columnas: 3
# n: ͣ,Numero: 19,Fila: 2,Columnas: 4
# n: Έ,Numero: 19,Fila: 2,Columnas: 5
# n: έ,Numero: 19,Fila: 3,Columnas: 0
# n: ϒ,Numero: 19,Fila: 3,Columnas: 1
# n: Ϸ,Numero: 19,Fila: 3,Columnas: 2
# n: М,Numero: 19,Fila: 3,Columnas: 3
# n: с,Numero: 19,Fila: 3,Columnas: 4
# n: Ѧ,Numero: 19,Fila: 3,Columnas: 5
# n: ҋ,Numero: 19,Fila: 4,Columnas: 0
# n: Ұ,Numero: 19,Fila: 4,Columnas: 1
# n: ӕ,Numero: 19,Fila: 4,Columnas: 2
# n: Ӻ,Numero: 19,Fila: 4,Columnas: 3
# n: ԟ,Numero: 19,Fila: 4,Columnas: 4
# n: Մ,Numero: 19,Fila: 4,Columnas: 5
# n: թ,Numero: 19,Fila: 5,Columnas: 0
# n: ֎,Numero: 19,Fila: 5,Columnas: 1
# n: ֳ,Numero: 19,Fila: 5,Columnas: 2
# n: ט,Numero: 19,Fila: 5,Columnas: 3
# n: ׽,Numero: 19,Fila: 5,Columnas: 4
# n: آ,Numero: 19,Fila: 5,Columnas: 5
# n: Ĕ,Numero: 20,Fila: 0,Columnas: 0
# n: Ĺ,Numero: 20,Fila: 0,Columnas: 1
# n: Ş,Numero: 20,Fila: 0,Columnas: 2
# n: ƃ,Numero: 20,Fila: 0,Columnas: 3
# n: ƨ,Numero: 20,Fila: 0,Columnas: 4
# n: Ǎ,Numero: 20,Fila: 0,Columnas: 5
# n: ǲ,Numero: 20,Fila: 1,Columnas: 0
# n: ȗ,Numero: 20,Fila: 1,Columnas: 1
# n: ȼ,Numero: 20,Fila: 1,Columnas: 2
# n: ɡ,Numero: 20,Fila: 1,Columnas: 3
# n: ʆ,Numero: 20,Fila: 1,Columnas: 4
# n: ʫ,Numero: 20,Fila: 1,Columnas: 5
# n: ː,Numero: 20,Fila: 2,Columnas: 0
# n: ˵,Numero: 20,Fila: 2,Columnas: 1
# n: ̚,Numero: 20,Fila: 2,Columnas: 2
# n: ̿,Numero: 20,Fila: 2,Columnas: 3
# n: ͤ,Numero: 20,Fila: 2,Columnas: 4
# n: Ή,Numero: 20,Fila: 2,Columnas: 5
# n: ή,Numero: 20,Fila: 3,Columnas: 0
# n: ϓ,Numero: 20,Fila: 3,Columnas: 1
# n: ϸ,Numero: 20,Fila: 3,Columnas: 2
# n: Н,Numero: 20,Fila: 3,Columnas: 3
# n: т,Numero: 20,Fila: 3,Columnas: 4
# n: ѧ,Numero: 20,Fila: 3,Columnas: 5
# n: Ҍ,Numero: 20,Fila: 4,Columnas: 0
# n: ұ,Numero: 20,Fila: 4,Columnas: 1
# n: Ӗ,Numero: 20,Fila: 4,Columnas: 2
# n: ӻ,Numero: 20,Fila: 4,Columnas: 3
# n: Ԡ,Numero: 20,Fila: 4,Columnas: 4
# n: Յ,Numero: 20,Fila: 4,Columnas: 5
# n: ժ,Numero: 20,Fila: 5,Columnas: 0
# n: ֏,Numero: 20,Fila: 5,Columnas: 1
# n: ִ,Numero: 20,Fila: 5,Columnas: 2
# n: י,Numero: 20,Fila: 5,Columnas: 3
# n: ׾,Numero: 20,Fila: 5,Columnas: 4
# n: أ,Numero: 20,Fila: 5,Columnas: 5
# n: ĕ,Numero: 21,Fila: 0,Columnas: 0
# n: ĺ,Numero: 21,Fila: 0,Columnas: 1
# n: ş,Numero: 21,Fila: 0,Columnas: 2
# n: Ƅ,Numero: 21,Fila: 0,Columnas: 3
# n: Ʃ,Numero: 21,Fila: 0,Columnas: 4
# n: ǎ,Numero: 21,Fila: 0,Columnas: 5
# n: ǳ,Numero: 21,Fila: 1,Columnas: 0
# n: Ș,Numero: 21,Fila: 1,Columnas: 1
# n: Ƚ,Numero: 21,Fila: 1,Columnas: 2
# n: ɢ,Numero: 21,Fila: 1,Columnas: 3
# n: ʇ,Numero: 21,Fila: 1,Columnas: 4
# n: ʬ,Numero: 21,Fila: 1,Columnas: 5
# n: ˑ,Numero: 21,Fila: 2,Columnas: 0
# n: ˶,Numero: 21,Fila: 2,Columnas: 1
# n: ̛,Numero: 21,Fila: 2,Columnas: 2
# n: ̀,Numero: 21,Fila: 2,Columnas: 3
# n: ͥ,Numero: 21,Fila: 2,Columnas: 4
# n: Ί,Numero: 21,Fila: 2,Columnas: 5
# n: ί,Numero: 21,Fila: 3,Columnas: 0
# n: ϔ,Numero: 21,Fila: 3,Columnas: 1
# n: Ϲ,Numero: 21,Fila: 3,Columnas: 2
# n: О,Numero: 21,Fila: 3,Columnas: 3
# n: у,Numero: 21,Fila: 3,Columnas: 4
# n: Ѩ,Numero: 21,Fila: 3,Columnas: 5
# n: ҍ,Numero: 21,Fila: 4,Columnas: 0
# n: Ҳ,Numero: 21,Fila: 4,Columnas: 1
# n: ӗ,Numero: 21,Fila: 4,Columnas: 2
# n: Ӽ,Numero: 21,Fila: 4,Columnas: 3
# n: ԡ,Numero: 21,Fila: 4,Columnas: 4
# n: Ն,Numero: 21,Fila: 4,Columnas: 5
# n: ի,Numero: 21,Fila: 5,Columnas: 0
# n: ֐,Numero: 21,Fila: 5,Columnas: 1
# n: ֵ,Numero: 21,Fila: 5,Columnas: 2
# n: ך,Numero: 21,Fila: 5,Columnas: 3
# n: ׿,Numero: 21,Fila: 5,Columnas: 4
# n: ؤ,Numero: 21,Fila: 5,Columnas: 5
# n: Ė,Numero: 22,Fila: 0,Columnas: 0
# n: Ļ,Numero: 22,Fila: 0,Columnas: 1
# n: Š,Numero: 22,Fila: 0,Columnas: 2
# n: ƅ,Numero: 22,Fila: 0,Columnas: 3
# n: ƪ,Numero: 22,Fila: 0,Columnas: 4
# n: Ǐ,Numero: 22,Fila: 0,Columnas: 5
# n: Ǵ,Numero: 22,Fila: 1,Columnas: 0
# n: ș,Numero: 22,Fila: 1,Columnas: 1
# n: Ⱦ,Numero: 22,Fila: 1,Columnas: 2
# n: ɣ,Numero: 22,Fila: 1,Columnas: 3
# n: ʈ,Numero: 22,Fila: 1,Columnas: 4
# n: ʭ,Numero: 22,Fila: 1,Columnas: 5
# n: ˒,Numero: 22,Fila: 2,Columnas: 0
# n: ˷,Numero: 22,Fila: 2,Columnas: 1
# n: ̜,Numero: 22,Fila: 2,Columnas: 2
# n: ́,Numero: 22,Fila: 2,Columnas: 3
# n: ͦ,Numero: 22,Fila: 2,Columnas: 4
# n: ΋,Numero: 22,Fila: 2,Columnas: 5
# n: ΰ,Numero: 22,Fila: 3,Columnas: 0
# n: ϕ,Numero: 22,Fila: 3,Columnas: 1
# n: Ϻ,Numero: 22,Fila: 3,Columnas: 2
# n: П,Numero: 22,Fila: 3,Columnas: 3
# n: ф,Numero: 22,Fila: 3,Columnas: 4
# n: ѩ,Numero: 22,Fila: 3,Columnas: 5
# n: Ҏ,Numero: 22,Fila: 4,Columnas: 0
# n: ҳ,Numero: 22,Fila: 4,Columnas: 1
# n: Ә,Numero: 22,Fila: 4,Columnas: 2
# n: ӽ,Numero: 22,Fila: 4,Columnas: 3
# n: Ԣ,Numero: 22,Fila: 4,Columnas: 4
# n: Շ,Numero: 22,Fila: 4,Columnas: 5
# n: լ,Numero: 22,Fila: 5,Columnas: 0
# n: ֑,Numero: 22,Fila: 5,Columnas: 1
# n: ֶ,Numero: 22,Fila: 5,Columnas: 2
# n: כ,Numero: 22,Fila: 5,Columnas: 3
# n: ؀,Numero: 22,Fila: 5,Columnas: 4
# n: إ,Numero: 22,Fila: 5,Columnas: 5
# n: ė,Numero: 23,Fila: 0,Columnas: 0
# n: ļ,Numero: 23,Fila: 0,Columnas: 1
# n: š,Numero: 23,Fila: 0,Columnas: 2
# n: Ɔ,Numero: 23,Fila: 0,Columnas: 3
# n: ƫ,Numero: 23,Fila: 0,Columnas: 4
# n: ǐ,Numero: 23,Fila: 0,Columnas: 5
# n: ǵ,Numero: 23,Fila: 1,Columnas: 0
# n: Ț,Numero: 23,Fila: 1,Columnas: 1
# n: ȿ,Numero: 23,Fila: 1,Columnas: 2
# n: ɤ,Numero: 23,Fila: 1,Columnas: 3
# n: ʉ,Numero: 23,Fila: 1,Columnas: 4
# n: ʮ,Numero: 23,Fila: 1,Columnas: 5
# n: ˓,Numero: 23,Fila: 2,Columnas: 0
# n: ˸,Numero: 23,Fila: 2,Columnas: 1
# n: ̝,Numero: 23,Fila: 2,Columnas: 2
# n: ͂,Numero: 23,Fila: 2,Columnas: 3
# n: ͧ,Numero: 23,Fila: 2,Columnas: 4
# n: Ό,Numero: 23,Fila: 2,Columnas: 5
# n: α,Numero: 23,Fila: 3,Columnas: 0
# n: ϖ,Numero: 23,Fila: 3,Columnas: 1
# n: ϻ,Numero: 23,Fila: 3,Columnas: 2
# n: Р,Numero: 23,Fila: 3,Columnas: 3
# n: х,Numero: 23,Fila: 3,Columnas: 4
# n: Ѫ,Numero: 23,Fila: 3,Columnas: 5
# n: ҏ,Numero: 23,Fila: 4,Columnas: 0
# n: Ҵ,Numero: 23,Fila: 4,Columnas: 1
# n: ә,Numero: 23,Fila: 4,Columnas: 2
# n: Ӿ,Numero: 23,Fila: 4,Columnas: 3
# n: ԣ,Numero: 23,Fila: 4,Columnas: 4
# n: Ո,Numero: 23,Fila: 4,Columnas: 5
# n: խ,Numero: 23,Fila: 5,Columnas: 0
# n: ֒,Numero: 23,Fila: 5,Columnas: 1
# n: ַ,Numero: 23,Fila: 5,Columnas: 2
# n: ל,Numero: 23,Fila: 5,Columnas: 3
# n: ؁,Numero: 23,Fila: 5,Columnas: 4
# n: ئ,Numero: 23,Fila: 5,Columnas: 5
# n: Ę,Numero: 24,Fila: 0,Columnas: 0
# n: Ľ,Numero: 24,Fila: 0,Columnas: 1
# n: Ţ,Numero: 24,Fila: 0,Columnas: 2
# n: Ƈ,Numero: 24,Fila: 0,Columnas: 3
# n: Ƭ,Numero: 24,Fila: 0,Columnas: 4
# n: Ǒ,Numero: 24,Fila: 0,Columnas: 5
# n: Ƕ,Numero: 24,Fila: 1,Columnas: 0
# n: ț,Numero: 24,Fila: 1,Columnas: 1
# n: ɀ,Numero: 24,Fila: 1,Columnas: 2
# n: ɥ,Numero: 24,Fila: 1,Columnas: 3
# n: ʊ,Numero: 24,Fila: 1,Columnas: 4
# n: ʯ,Numero: 24,Fila: 1,Columnas: 5
# n: ˔,Numero: 24,Fila: 2,Columnas: 0
# n: ˹,Numero: 24,Fila: 2,Columnas: 1
# n: ̞,Numero: 24,Fila: 2,Columnas: 2
# n: ̓,Numero: 24,Fila: 2,Columnas: 3
# n: ͨ,Numero: 24,Fila: 2,Columnas: 4
# n: ΍,Numero: 24,Fila: 2,Columnas: 5
# n: β,Numero: 24,Fila: 3,Columnas: 0
# n: ϗ,Numero: 24,Fila: 3,Columnas: 1
# n: ϼ,Numero: 24,Fila: 3,Columnas: 2
# n: С,Numero: 24,Fila: 3,Columnas: 3
# n: ц,Numero: 24,Fila: 3,Columnas: 4
# n: ѫ,Numero: 24,Fila: 3,Columnas: 5
# n: Ґ,Numero: 24,Fila: 4,Columnas: 0
# n: ҵ,Numero: 24,Fila: 4,Columnas: 1
# n: Ӛ,Numero: 24,Fila: 4,Columnas: 2
# n: ӿ,Numero: 24,Fila: 4,Columnas: 3
# n: Ԥ,Numero: 24,Fila: 4,Columnas: 4
# n: Չ,Numero: 24,Fila: 4,Columnas: 5
# n: ծ,Numero: 24,Fila: 5,Columnas: 0
# n: ֓,Numero: 24,Fila: 5,Columnas: 1
# n: ָ,Numero: 24,Fila: 5,Columnas: 2
# n: ם,Numero: 24,Fila: 5,Columnas: 3
# n: ؂,Numero: 24,Fila: 5,Columnas: 4
# n: ا,Numero: 24,Fila: 5,Columnas: 5
# n: ę,Numero: 25,Fila: 0,Columnas: 0
# n: ľ,Numero: 25,Fila: 0,Columnas: 1
# n: ţ,Numero: 25,Fila: 0,Columnas: 2
# n: ƈ,Numero: 25,Fila: 0,Columnas: 3
# n: ƭ,Numero: 25,Fila: 0,Columnas: 4
# n: ǒ,Numero: 25,Fila: 0,Columnas: 5
# n: Ƿ,Numero: 25,Fila: 1,Columnas: 0
# n: Ȝ,Numero: 25,Fila: 1,Columnas: 1
# n: Ɂ,Numero: 25,Fila: 1,Columnas: 2
# n: ɦ,Numero: 25,Fila: 1,Columnas: 3
# n: ʋ,Numero: 25,Fila: 1,Columnas: 4
# n: ʰ,Numero: 25,Fila: 1,Columnas: 5
# n: ˕,Numero: 25,Fila: 2,Columnas: 0
# n: ˺,Numero: 25,Fila: 2,Columnas: 1
# n: ̟,Numero: 25,Fila: 2,Columnas: 2
# n: ̈́,Numero: 25,Fila: 2,Columnas: 3
# n: ͩ,Numero: 25,Fila: 2,Columnas: 4
# n: Ύ,Numero: 25,Fila: 2,Columnas: 5
# n: γ,Numero: 25,Fila: 3,Columnas: 0
# n: Ϙ,Numero: 25,Fila: 3,Columnas: 1
# n: Ͻ,Numero: 25,Fila: 3,Columnas: 2
# n: Т,Numero: 25,Fila: 3,Columnas: 3
# n: ч,Numero: 25,Fila: 3,Columnas: 4
# n: Ѭ,Numero: 25,Fila: 3,Columnas: 5
# n: ґ,Numero: 25,Fila: 4,Columnas: 0
# n: Ҷ,Numero: 25,Fila: 4,Columnas: 1
# n: ӛ,Numero: 25,Fila: 4,Columnas: 2
# n: Ԁ,Numero: 25,Fila: 4,Columnas: 3
# n: ԥ,Numero: 25,Fila: 4,Columnas: 4
# n: Պ,Numero: 25,Fila: 4,Columnas: 5
# n: կ,Numero: 25,Fila: 5,Columnas: 0
# n: ֔,Numero: 25,Fila: 5,Columnas: 1
# n: ֹ,Numero: 25,Fila: 5,Columnas: 2
# n: מ,Numero: 25,Fila: 5,Columnas: 3
# n: ؃,Numero: 25,Fila: 5,Columnas: 4
# n: ب,Numero: 25,Fila: 5,Columnas: 5
# n: Ě,Numero: 26,Fila: 0,Columnas: 0
# n: Ŀ,Numero: 26,Fila: 0,Columnas: 1
# n: Ť,Numero: 26,Fila: 0,Columnas: 2
# n: Ɖ,Numero: 26,Fila: 0,Columnas: 3
# n: Ʈ,Numero: 26,Fila: 0,Columnas: 4
# n: Ǔ,Numero: 26,Fila: 0,Columnas: 5
# n: Ǹ,Numero: 26,Fila: 1,Columnas: 0
# n: ȝ,Numero: 26,Fila: 1,Columnas: 1
# n: ɂ,Numero: 26,Fila: 1,Columnas: 2
# n: ɧ,Numero: 26,Fila: 1,Columnas: 3
# n: ʌ,Numero: 26,Fila: 1,Columnas: 4
# n: ʱ,Numero: 26,Fila: 1,Columnas: 5
# n: ˖,Numero: 26,Fila: 2,Columnas: 0
# n: ˻,Numero: 26,Fila: 2,Columnas: 1
# n: ̠,Numero: 26,Fila: 2,Columnas: 2
# n: ͅ,Numero: 26,Fila: 2,Columnas: 3
# n: ͪ,Numero: 26,Fila: 2,Columnas: 4
# n: Ώ,Numero: 26,Fila: 2,Columnas: 5
# n: δ,Numero: 26,Fila: 3,Columnas: 0
# n: ϙ,Numero: 26,Fila: 3,Columnas: 1
# n: Ͼ,Numero: 26,Fila: 3,Columnas: 2
# n: У,Numero: 26,Fila: 3,Columnas: 3
# n: ш,Numero: 26,Fila: 3,Columnas: 4
# n: ѭ,Numero: 26,Fila: 3,Columnas: 5
# n: Ғ,Numero: 26,Fila: 4,Columnas: 0
# n: ҷ,Numero: 26,Fila: 4,Columnas: 1
# n: Ӝ,Numero: 26,Fila: 4,Columnas: 2
# n: ԁ,Numero: 26,Fila: 4,Columnas: 3
# n: Ԧ,Numero: 26,Fila: 4,Columnas: 4
# n: Ջ,Numero: 26,Fila: 4,Columnas: 5
# n: հ,Numero: 26,Fila: 5,Columnas: 0
# n: ֕,Numero: 26,Fila: 5,Columnas: 1
# n: ֺ,Numero: 26,Fila: 5,Columnas: 2
# n: ן,Numero: 26,Fila: 5,Columnas: 3
# n: ؄,Numero: 26,Fila: 5,Columnas: 4
# n: ة,Numero: 26,Fila: 5,Columnas: 5
# n: ě,Numero: 27,Fila: 0,Columnas: 0
# n: ŀ,Numero: 27,Fila: 0,Columnas: 1
# n: ť,Numero: 27,Fila: 0,Columnas: 2
# n: Ɗ,Numero: 27,Fila: 0,Columnas: 3
# n: Ư,Numero: 27,Fila: 0,Columnas: 4
# n: ǔ,Numero: 27,Fila: 0,Columnas: 5
# n: ǹ,Numero: 27,Fila: 1,Columnas: 0
# n: Ȟ,Numero: 27,Fila: 1,Columnas: 1
# n: Ƀ,Numero: 27,Fila: 1,Columnas: 2
# n: ɨ,Numero: 27,Fila: 1,Columnas: 3
# n: ʍ,Numero: 27,Fila: 1,Columnas: 4
# n: ʲ,Numero: 27,Fila: 1,Columnas: 5
# n: ˗,Numero: 27,Fila: 2,Columnas: 0
# n: ˼,Numero: 27,Fila: 2,Columnas: 1
# n: ̡,Numero: 27,Fila: 2,Columnas: 2
# n: ͆,Numero: 27,Fila: 2,Columnas: 3
# n: ͫ,Numero: 27,Fila: 2,Columnas: 4
# n: ΐ,Numero: 27,Fila: 2,Columnas: 5
# n: ε,Numero: 27,Fila: 3,Columnas: 0
# n: Ϛ,Numero: 27,Fila: 3,Columnas: 1
# n: Ͽ,Numero: 27,Fila: 3,Columnas: 2
# n: Ф,Numero: 27,Fila: 3,Columnas: 3
# n: щ,Numero: 27,Fila: 3,Columnas: 4
# n: Ѯ,Numero: 27,Fila: 3,Columnas: 5
# n: ғ,Numero: 27,Fila: 4,Columnas: 0
# n: Ҹ,Numero: 27,Fila: 4,Columnas: 1
# n: ӝ,Numero: 27,Fila: 4,Columnas: 2
# n: Ԃ,Numero: 27,Fila: 4,Columnas: 3
# n: ԧ,Numero: 27,Fila: 4,Columnas: 4
# n: Ռ,Numero: 27,Fila: 4,Columnas: 5
# n: ձ,Numero: 27,Fila: 5,Columnas: 0
# n: ֖,Numero: 27,Fila: 5,Columnas: 1
# n: ֻ,Numero: 27,Fila: 5,Columnas: 2
# n: נ,Numero: 27,Fila: 5,Columnas: 3
# n: ؅,Numero: 27,Fila: 5,Columnas: 4
# n: ت,Numero: 27,Fila: 5,Columnas: 5
# n: Ĝ,Numero: 28,Fila: 0,Columnas: 0
# n: Ł,Numero: 28,Fila: 0,Columnas: 1
# n: Ŧ,Numero: 28,Fila: 0,Columnas: 2
# n: Ƌ,Numero: 28,Fila: 0,Columnas: 3
# n: ư,Numero: 28,Fila: 0,Columnas: 4
# n: Ǖ,Numero: 28,Fila: 0,Columnas: 5
# n: Ǻ,Numero: 28,Fila: 1,Columnas: 0
# n: ȟ,Numero: 28,Fila: 1,Columnas: 1
# n: Ʉ,Numero: 28,Fila: 1,Columnas: 2
# n: ɩ,Numero: 28,Fila: 1,Columnas: 3
# n: ʎ,Numero: 28,Fila: 1,Columnas: 4
# n: ʳ,Numero: 28,Fila: 1,Columnas: 5
# n: ˘,Numero: 28,Fila: 2,Columnas: 0
# n: ˽,Numero: 28,Fila: 2,Columnas: 1
# n: ̢,Numero: 28,Fila: 2,Columnas: 2
# n: ͇,Numero: 28,Fila: 2,Columnas: 3
# n: ͬ,Numero: 28,Fila: 2,Columnas: 4
# n: Α,Numero: 28,Fila: 2,Columnas: 5
# n: ζ,Numero: 28,Fila: 3,Columnas: 0
# n: ϛ,Numero: 28,Fila: 3,Columnas: 1
# n: Ѐ,Numero: 28,Fila: 3,Columnas: 2
# n: Х,Numero: 28,Fila: 3,Columnas: 3
# n: ъ,Numero: 28,Fila: 3,Columnas: 4
# n: ѯ,Numero: 28,Fila: 3,Columnas: 5
# n: Ҕ,Numero: 28,Fila: 4,Columnas: 0
# n: ҹ,Numero: 28,Fila: 4,Columnas: 1
# n: Ӟ,Numero: 28,Fila: 4,Columnas: 2
# n: ԃ,Numero: 28,Fila: 4,Columnas: 3
# n: Ԩ,Numero: 28,Fila: 4,Columnas: 4
# n: Ս,Numero: 28,Fila: 4,Columnas: 5
# n: ղ,Numero: 28,Fila: 5,Columnas: 0
# n: ֗,Numero: 28,Fila: 5,Columnas: 1
# n: ּ,Numero: 28,Fila: 5,Columnas: 2
# n: ס,Numero: 28,Fila: 5,Columnas: 3
# n: ؆,Numero: 28,Fila: 5,Columnas: 4
# n: ث,Numero: 28,Fila: 5,Columnas: 5
# n: ĝ,Numero: 29,Fila: 0,Columnas: 0
# n: ł,Numero: 29,Fila: 0,Columnas: 1
# n: ŧ,Numero: 29,Fila: 0,Columnas: 2
# n: ƌ,Numero: 29,Fila: 0,Columnas: 3
# n: Ʊ,Numero: 29,Fila: 0,Columnas: 4
# n: ǖ,Numero: 29,Fila: 0,Columnas: 5
# n: ǻ,Numero: 29,Fila: 1,Columnas: 0
# n: Ƞ,Numero: 29,Fila: 1,Columnas: 1
# n: Ʌ,Numero: 29,Fila: 1,Columnas: 2
# n: ɪ,Numero: 29,Fila: 1,Columnas: 3
# n: ʏ,Numero: 29,Fila: 1,Columnas: 4
# n: ʴ,Numero: 29,Fila: 1,Columnas: 5
# n: ˙,Numero: 29,Fila: 2,Columnas: 0
# n: ˾,Numero: 29,Fila: 2,Columnas: 1
# n: ̣,Numero: 29,Fila: 2,Columnas: 2
# n: ͈,Numero: 29,Fila: 2,Columnas: 3
# n: ͭ,Numero: 29,Fila: 2,Columnas: 4
# n: Β,Numero: 29,Fila: 2,Columnas: 5
# n: η,Numero: 29,Fila: 3,Columnas: 0
# n: Ϝ,Numero: 29,Fila: 3,Columnas: 1
# n: Ё,Numero: 29,Fila: 3,Columnas: 2
# n: Ц,Numero: 29,Fila: 3,Columnas: 3
# n: ы,Numero: 29,Fila: 3,Columnas: 4
# n: Ѱ,Numero: 29,Fila: 3,Columnas: 5
# n: ҕ,Numero: 29,Fila: 4,Columnas: 0
# n: Һ,Numero: 29,Fila: 4,Columnas: 1
# n: ӟ,Numero: 29,Fila: 4,Columnas: 2
# n: Ԅ,Numero: 29,Fila: 4,Columnas: 3
# n: ԩ,Numero: 29,Fila: 4,Columnas: 4
# n: Վ,Numero: 29,Fila: 4,Columnas: 5
# n: ճ,Numero: 29,Fila: 5,Columnas: 0
# n: ֘,Numero: 29,Fila: 5,Columnas: 1
# n: ֽ,Numero: 29,Fila: 5,Columnas: 2
# n: ע,Numero: 29,Fila: 5,Columnas: 3
# n: ؇,Numero: 29,Fila: 5,Columnas: 4
# n: ج,Numero: 29,Fila: 5,Columnas: 5
# n: Ğ,Numero: 30,Fila: 0,Columnas: 0
# n: Ń,Numero: 30,Fila: 0,Columnas: 1
# n: Ũ,Numero: 30,Fila: 0,Columnas: 2
# n: ƍ,Numero: 30,Fila: 0,Columnas: 3
# n: Ʋ,Numero: 30,Fila: 0,Columnas: 4
# n: Ǘ,Numero: 30,Fila: 0,Columnas: 5
# n: Ǽ,Numero: 30,Fila: 1,Columnas: 0
# n: ȡ,Numero: 30,Fila: 1,Columnas: 1
# n: Ɇ,Numero: 30,Fila: 1,Columnas: 2
# n: ɫ,Numero: 30,Fila: 1,Columnas: 3
# n: ʐ,Numero: 30,Fila: 1,Columnas: 4
# n: ʵ,Numero: 30,Fila: 1,Columnas: 5
# n: ˚,Numero: 30,Fila: 2,Columnas: 0
# n: ˿,Numero: 30,Fila: 2,Columnas: 1
# n: ̤,Numero: 30,Fila: 2,Columnas: 2
# n: ͉,Numero: 30,Fila: 2,Columnas: 3
# n: ͮ,Numero: 30,Fila: 2,Columnas: 4
# n: Γ,Numero: 30,Fila: 2,Columnas: 5
# n: θ,Numero: 30,Fila: 3,Columnas: 0
# n: ϝ,Numero: 30,Fila: 3,Columnas: 1
# n: Ђ,Numero: 30,Fila: 3,Columnas: 2
# n: Ч,Numero: 30,Fila: 3,Columnas: 3
# n: ь,Numero: 30,Fila: 3,Columnas: 4
# n: ѱ,Numero: 30,Fila: 3,Columnas: 5
# n: Җ,Numero: 30,Fila: 4,Columnas: 0
# n: һ,Numero: 30,Fila: 4,Columnas: 1
# n: Ӡ,Numero: 30,Fila: 4,Columnas: 2
# n: ԅ,Numero: 30,Fila: 4,Columnas: 3
# n: Ԫ,Numero: 30,Fila: 4,Columnas: 4
# n: Տ,Numero: 30,Fila: 4,Columnas: 5
# n: մ,Numero: 30,Fila: 5,Columnas: 0
# n: ֙,Numero: 30,Fila: 5,Columnas: 1
# n: ־,Numero: 30,Fila: 5,Columnas: 2
# n: ף,Numero: 30,Fila: 5,Columnas: 3
# n: ؈,Numero: 30,Fila: 5,Columnas: 4
# n: ح,Numero: 30,Fila: 5,Columnas: 5
# n: ğ,Numero: 31,Fila: 0,Columnas: 0
# n: ń,Numero: 31,Fila: 0,Columnas: 1
# n: ũ,Numero: 31,Fila: 0,Columnas: 2
# n: Ǝ,Numero: 31,Fila: 0,Columnas: 3
# n: Ƴ,Numero: 31,Fila: 0,Columnas: 4
# n: ǘ,Numero: 31,Fila: 0,Columnas: 5
# n: ǽ,Numero: 31,Fila: 1,Columnas: 0
# n: Ȣ,Numero: 31,Fila: 1,Columnas: 1
# n: ɇ,Numero: 31,Fila: 1,Columnas: 2
# n: ɬ,Numero: 31,Fila: 1,Columnas: 3
# n: ʑ,Numero: 31,Fila: 1,Columnas: 4
# n: ʶ,Numero: 31,Fila: 1,Columnas: 5
# n: ˛,Numero: 31,Fila: 2,Columnas: 0
# n: ̀,Numero: 31,Fila: 2,Columnas: 1
# n: ̥,Numero: 31,Fila: 2,Columnas: 2
# n: ͊,Numero: 31,Fila: 2,Columnas: 3
# n: ͯ,Numero: 31,Fila: 2,Columnas: 4
# n: Δ,Numero: 31,Fila: 2,Columnas: 5
# n: ι,Numero: 31,Fila: 3,Columnas: 0
# n: Ϟ,Numero: 31,Fila: 3,Columnas: 1
# n: Ѓ,Numero: 31,Fila: 3,Columnas: 2
# n: Ш,Numero: 31,Fila: 3,Columnas: 3
# n: э,Numero: 31,Fila: 3,Columnas: 4
# n: Ѳ,Numero: 31,Fila: 3,Columnas: 5
# n: җ,Numero: 31,Fila: 4,Columnas: 0
# n: Ҽ,Numero: 31,Fila: 4,Columnas: 1
# n: ӡ,Numero: 31,Fila: 4,Columnas: 2
# n: Ԇ,Numero: 31,Fila: 4,Columnas: 3
# n: ԫ,Numero: 31,Fila: 4,Columnas: 4
# n: Ր,Numero: 31,Fila: 4,Columnas: 5
# n: յ,Numero: 31,Fila: 5,Columnas: 0
# n: ֚,Numero: 31,Fila: 5,Columnas: 1
# n: ֿ,Numero: 31,Fila: 5,Columnas: 2
# n: פ,Numero: 31,Fila: 5,Columnas: 3
# n: ؉,Numero: 31,Fila: 5,Columnas: 4
# n: خ,Numero: 31,Fila: 5,Columnas: 5
# n: Ġ,Numero: 32,Fila: 0,Columnas: 0
# n: Ņ,Numero: 32,Fila: 0,Columnas: 1
# n: Ū,Numero: 32,Fila: 0,Columnas: 2
# n: Ə,Numero: 32,Fila: 0,Columnas: 3
# n: ƴ,Numero: 32,Fila: 0,Columnas: 4
# n: Ǚ,Numero: 32,Fila: 0,Columnas: 5
# n: Ǿ,Numero: 32,Fila: 1,Columnas: 0
# n: ȣ,Numero: 32,Fila: 1,Columnas: 1
# n: Ɉ,Numero: 32,Fila: 1,Columnas: 2
# n: ɭ,Numero: 32,Fila: 1,Columnas: 3
# n: ʒ,Numero: 32,Fila: 1,Columnas: 4
# n: ʷ,Numero: 32,Fila: 1,Columnas: 5
# n: ˜,Numero: 32,Fila: 2,Columnas: 0
# n: ́,Numero: 32,Fila: 2,Columnas: 1
# n: ̦,Numero: 32,Fila: 2,Columnas: 2
# n: ͋,Numero: 32,Fila: 2,Columnas: 3
# n: Ͱ,Numero: 32,Fila: 2,Columnas: 4
# n: Ε,Numero: 32,Fila: 2,Columnas: 5
# n: κ,Numero: 32,Fila: 3,Columnas: 0
# n: ϟ,Numero: 32,Fila: 3,Columnas: 1
# n: Є,Numero: 32,Fila: 3,Columnas: 2
# n: Щ,Numero: 32,Fila: 3,Columnas: 3
# n: ю,Numero: 32,Fila: 3,Columnas: 4
# n: ѳ,Numero: 32,Fila: 3,Columnas: 5
# n: Ҙ,Numero: 32,Fila: 4,Columnas: 0
# n: ҽ,Numero: 32,Fila: 4,Columnas: 1
# n: Ӣ,Numero: 32,Fila: 4,Columnas: 2
# n: ԇ,Numero: 32,Fila: 4,Columnas: 3
# n: Ԭ,Numero: 32,Fila: 4,Columnas: 4
# n: Ց,Numero: 32,Fila: 4,Columnas: 5
# n: ն,Numero: 32,Fila: 5,Columnas: 0
# n: ֛,Numero: 32,Fila: 5,Columnas: 1
# n: ׀,Numero: 32,Fila: 5,Columnas: 2
# n: ץ,Numero: 32,Fila: 5,Columnas: 3
# n: ؊,Numero: 32,Fila: 5,Columnas: 4
# n: د,Numero: 32,Fila: 5,Columnas: 5
# n: ġ,Numero: 33,Fila: 0,Columnas: 0
# n: ņ,Numero: 33,Fila: 0,Columnas: 1
# n: ū,Numero: 33,Fila: 0,Columnas: 2
# n: Ɛ,Numero: 33,Fila: 0,Columnas: 3
# n: Ƶ,Numero: 33,Fila: 0,Columnas: 4
# n: ǚ,Numero: 33,Fila: 0,Columnas: 5
# n: ǿ,Numero: 33,Fila: 1,Columnas: 0
# n: Ȥ,Numero: 33,Fila: 1,Columnas: 1
# n: ɉ,Numero: 33,Fila: 1,Columnas: 2
# n: ɮ,Numero: 33,Fila: 1,Columnas: 3
# n: ʓ,Numero: 33,Fila: 1,Columnas: 4
# n: ʸ,Numero: 33,Fila: 1,Columnas: 5
# n: ˝,Numero: 33,Fila: 2,Columnas: 0
# n: ̂,Numero: 33,Fila: 2,Columnas: 1
# n: ̧,Numero: 33,Fila: 2,Columnas: 2
# n: ͌,Numero: 33,Fila: 2,Columnas: 3
# n: ͱ,Numero: 33,Fila: 2,Columnas: 4
# n: Ζ,Numero: 33,Fila: 2,Columnas: 5
# n: λ,Numero: 33,Fila: 3,Columnas: 0
# n: Ϡ,Numero: 33,Fila: 3,Columnas: 1
# n: Ѕ,Numero: 33,Fila: 3,Columnas: 2
# n: Ъ,Numero: 33,Fila: 3,Columnas: 3
# n: я,Numero: 33,Fila: 3,Columnas: 4
# n: Ѵ,Numero: 33,Fila: 3,Columnas: 5
# n: ҙ,Numero: 33,Fila: 4,Columnas: 0
# n: Ҿ,Numero: 33,Fila: 4,Columnas: 1
# n: ӣ,Numero: 33,Fila: 4,Columnas: 2
# n: Ԉ,Numero: 33,Fila: 4,Columnas: 3
# n: ԭ,Numero: 33,Fila: 4,Columnas: 4
# n: Ւ,Numero: 33,Fila: 4,Columnas: 5
# n: շ,Numero: 33,Fila: 5,Columnas: 0
# n: ֜,Numero: 33,Fila: 5,Columnas: 1
# n: ׁ,Numero: 33,Fila: 5,Columnas: 2
# n: צ,Numero: 33,Fila: 5,Columnas: 3
# n: ؋,Numero: 33,Fila: 5,Columnas: 4
# n: ذ,Numero: 33,Fila: 5,Columnas: 5
# n: Ģ,Numero: 34,Fila: 0,Columnas: 0
# n: Ň,Numero: 34,Fila: 0,Columnas: 1
# n: Ŭ,Numero: 34,Fila: 0,Columnas: 2
# n: Ƒ,Numero: 34,Fila: 0,Columnas: 3
# n: ƶ,Numero: 34,Fila: 0,Columnas: 4
# n: Ǜ,Numero: 34,Fila: 0,Columnas: 5
# n: Ȁ,Numero: 34,Fila: 1,Columnas: 0
# n: ȥ,Numero: 34,Fila: 1,Columnas: 1
# n: Ɋ,Numero: 34,Fila: 1,Columnas: 2
# n: ɯ,Numero: 34,Fila: 1,Columnas: 3
# n: ʔ,Numero: 34,Fila: 1,Columnas: 4
# n: ʹ,Numero: 34,Fila: 1,Columnas: 5
# n: ˞,Numero: 34,Fila: 2,Columnas: 0
# n: ̃,Numero: 34,Fila: 2,Columnas: 1
# n: ̨,Numero: 34,Fila: 2,Columnas: 2
# n: ͍,Numero: 34,Fila: 2,Columnas: 3
# n: Ͳ,Numero: 34,Fila: 2,Columnas: 4
# n: Η,Numero: 34,Fila: 2,Columnas: 5
# n: μ,Numero: 34,Fila: 3,Columnas: 0
# n: ϡ,Numero: 34,Fila: 3,Columnas: 1
# n: І,Numero: 34,Fila: 3,Columnas: 2
# n: Ы,Numero: 34,Fila: 3,Columnas: 3
# n: ѐ,Numero: 34,Fila: 3,Columnas: 4
# n: ѵ,Numero: 34,Fila: 3,Columnas: 5
# n: Қ,Numero: 34,Fila: 4,Columnas: 0
# n: ҿ,Numero: 34,Fila: 4,Columnas: 1
# n: Ӥ,Numero: 34,Fila: 4,Columnas: 2
# n: ԉ,Numero: 34,Fila: 4,Columnas: 3
# n: Ԯ,Numero: 34,Fila: 4,Columnas: 4
# n: Փ,Numero: 34,Fila: 4,Columnas: 5
# n: ո,Numero: 34,Fila: 5,Columnas: 0
# n: ֝,Numero: 34,Fila: 5,Columnas: 1
# n: ׂ,Numero: 34,Fila: 5,Columnas: 2
# n: ק,Numero: 34,Fila: 5,Columnas: 3
# n: ،,Numero: 34,Fila: 5,Columnas: 4
# n: ر,Numero: 34,Fila: 5,Columnas: 5
# n: ģ,Numero: 35,Fila: 0,Columnas: 0
# n: ň,Numero: 35,Fila: 0,Columnas: 1
# n: ŭ,Numero: 35,Fila: 0,Columnas: 2
# n: ƒ,Numero: 35,Fila: 0,Columnas: 3
# n: Ʒ,Numero: 35,Fila: 0,Columnas: 4
# n: ǜ,Numero: 35,Fila: 0,Columnas: 5
# n: ȁ,Numero: 35,Fila: 1,Columnas: 0
# n: Ȧ,Numero: 35,Fila: 1,Columnas: 1
# n: ɋ,Numero: 35,Fila: 1,Columnas: 2
# n: ɰ,Numero: 35,Fila: 1,Columnas: 3
# n: ʕ,Numero: 35,Fila: 1,Columnas: 4
# n: ʺ,Numero: 35,Fila: 1,Columnas: 5
# n: ˟,Numero: 35,Fila: 2,Columnas: 0
# n: ̄,Numero: 35,Fila: 2,Columnas: 1
# n: ̩,Numero: 35,Fila: 2,Columnas: 2
# n: ͎,Numero: 35,Fila: 2,Columnas: 3
# n: ͳ,Numero: 35,Fila: 2,Columnas: 4
# n: Θ,Numero: 35,Fila: 2,Columnas: 5
# n: ν,Numero: 35,Fila: 3,Columnas: 0
# n: Ϣ,Numero: 35,Fila: 3,Columnas: 1
# n: Ї,Numero: 35,Fila: 3,Columnas: 2
# n: Ь,Numero: 35,Fila: 3,Columnas: 3
# n: ё,Numero: 35,Fila: 3,Columnas: 4
# n: Ѷ,Numero: 35,Fila: 3,Columnas: 5
# n: қ,Numero: 35,Fila: 4,Columnas: 0
# n: Ӏ,Numero: 35,Fila: 4,Columnas: 1
# n: ӥ,Numero: 35,Fila: 4,Columnas: 2
# n: Ԋ,Numero: 35,Fila: 4,Columnas: 3
# n: ԯ,Numero: 35,Fila: 4,Columnas: 4
# n: Ք,Numero: 35,Fila: 4,Columnas: 5
# n: չ,Numero: 35,Fila: 5,Columnas: 0
# n: ֞,Numero: 35,Fila: 5,Columnas: 1
# n: ׃,Numero: 35,Fila: 5,Columnas: 2
# n: ר,Numero: 35,Fila: 5,Columnas: 3
# n: ؍,Numero: 35,Fila: 5,Columnas: 4
# n: ز,Numero: 35,Fila: 5,Columnas: 5
# n: Ĥ,Numero: 36,Fila: 0,Columnas: 0
# n: ŉ,Numero: 36,Fila: 0,Columnas: 1
# n: Ů,Numero: 36,Fila: 0,Columnas: 2
# n: Ɠ,Numero: 36,Fila: 0,Columnas: 3
# n: Ƹ,Numero: 36,Fila: 0,Columnas: 4
# n: ǝ,Numero: 36,Fila: 0,Columnas: 5
# n: Ȃ,Numero: 36,Fila: 1,Columnas: 0
# n: ȧ,Numero: 36,Fila: 1,Columnas: 1
# n: Ɍ,Numero: 36,Fila: 1,Columnas: 2
# n: ɱ,Numero: 36,Fila: 1,Columnas: 3
# n: ʖ,Numero: 36,Fila: 1,Columnas: 4
# n: ʻ,Numero: 36,Fila: 1,Columnas: 5
# n: ˠ,Numero: 36,Fila: 2,Columnas: 0
# n: ̅,Numero: 36,Fila: 2,Columnas: 1
# n: ̪,Numero: 36,Fila: 2,Columnas: 2
# n: ͏,Numero: 36,Fila: 2,Columnas: 3
# n: ʹ,Numero: 36,Fila: 2,Columnas: 4
# n: Ι,Numero: 36,Fila: 2,Columnas: 5
# n: ξ,Numero: 36,Fila: 3,Columnas: 0
# n: ϣ,Numero: 36,Fila: 3,Columnas: 1
# n: Ј,Numero: 36,Fila: 3,Columnas: 2
# n: Э,Numero: 36,Fila: 3,Columnas: 3
# n: ђ,Numero: 36,Fila: 3,Columnas: 4
# n: ѷ,Numero: 36,Fila: 3,Columnas: 5
# n: Ҝ,Numero: 36,Fila: 4,Columnas: 0
# n: Ӂ,Numero: 36,Fila: 4,Columnas: 1
# n: Ӧ,Numero: 36,Fila: 4,Columnas: 2
# n: ԋ,Numero: 36,Fila: 4,Columnas: 3
# n: ԰,Numero: 36,Fila: 4,Columnas: 4
# n: Օ,Numero: 36,Fila: 4,Columnas: 5
# n: պ,Numero: 36,Fila: 5,Columnas: 0
# n: ֟,Numero: 36,Fila: 5,Columnas: 1
# n: ׄ,Numero: 36,Fila: 5,Columnas: 2
# n: ש,Numero: 36,Fila: 5,Columnas: 3
# n: ؎,Numero: 36,Fila: 5,Columnas: 4
# n: س,Numero: 36,Fila: 5,Columnas: 5

# %%
for cod in letras_blancas:
    print('n: ' + cod, end = ',')
    f,c,o = cods2.Binv(cod)
    print ('Numero: ' +str(o), end = ',')
    print ('Fila: '+ str(f), end = ',')
    print ('Columnas: ' + str(c))
# Out:
# n: ߒ,Numero: 1,Fila: 0,Columnas: 0
# n: ߷,Numero: 1,Fila: 0,Columnas: 1
# n: ࠜ,Numero: 1,Fila: 0,Columnas: 2
# n: ࡁ,Numero: 1,Fila: 0,Columnas: 3
# n: ࡦ,Numero: 1,Fila: 0,Columnas: 4
# n: ࢋ,Numero: 1,Fila: 0,Columnas: 5
# n: ࢰ,Numero: 1,Fila: 1,Columnas: 0
# n: ࣕ,Numero: 1,Fila: 1,Columnas: 1
# n: ࣺ,Numero: 1,Fila: 1,Columnas: 2
# n: ट,Numero: 1,Fila: 1,Columnas: 3
# n: ॄ,Numero: 1,Fila: 1,Columnas: 4
# n: ३,Numero: 1,Fila: 1,Columnas: 5
# n: ঎,Numero: 1,Fila: 2,Columnas: 0
# n: ঳,Numero: 1,Fila: 2,Columnas: 1
# n: ৘,Numero: 1,Fila: 2,Columnas: 2
# n: ৽,Numero: 1,Fila: 2,Columnas: 3
# n: ਢ,Numero: 1,Fila: 2,Columnas: 4
# n: ੇ,Numero: 1,Fila: 2,Columnas: 5
# n: ੬,Numero: 1,Fila: 3,Columnas: 0
# n: ઑ,Numero: 1,Fila: 3,Columnas: 1
# n: શ,Numero: 1,Fila: 3,Columnas: 2
# n: ૛,Numero: 1,Fila: 3,Columnas: 3
# n: ଀,Numero: 1,Fila: 3,Columnas: 4
# n: ଥ,Numero: 1,Fila: 3,Columnas: 5
# n: ୊,Numero: 1,Fila: 4,Columnas: 0
# n: ୯,Numero: 1,Fila: 4,Columnas: 1
# n: ஔ,Numero: 1,Fila: 4,Columnas: 2
# n: ஹ,Numero: 1,Fila: 4,Columnas: 3
# n: ௞,Numero: 1,Fila: 4,Columnas: 4
# n: ః,Numero: 1,Fila: 4,Columnas: 5
# n: న,Numero: 1,Fila: 5,Columnas: 0
# n: ్,Numero: 1,Fila: 5,Columnas: 1
# n: ౲,Numero: 1,Fila: 5,Columnas: 2
# n: ಗ,Numero: 1,Fila: 5,Columnas: 3
# n: ಼,Numero: 1,Fila: 5,Columnas: 4
# n: ೡ,Numero: 1,Fila: 5,Columnas: 5
# n: ߓ,Numero: 2,Fila: 0,Columnas: 0
# n: ߸,Numero: 2,Fila: 0,Columnas: 1
# n: ࠝ,Numero: 2,Fila: 0,Columnas: 2
# n: ࡂ,Numero: 2,Fila: 0,Columnas: 3
# n: ࡧ,Numero: 2,Fila: 0,Columnas: 4
# n: ࢌ,Numero: 2,Fila: 0,Columnas: 5
# n: ࢱ,Numero: 2,Fila: 1,Columnas: 0
# n: ࣖ,Numero: 2,Fila: 1,Columnas: 1
# n: ࣻ,Numero: 2,Fila: 1,Columnas: 2
# n: ठ,Numero: 2,Fila: 1,Columnas: 3
# n: ॅ,Numero: 2,Fila: 1,Columnas: 4
# n: ४,Numero: 2,Fila: 1,Columnas: 5
# n: এ,Numero: 2,Fila: 2,Columnas: 0
# n: ঴,Numero: 2,Fila: 2,Columnas: 1
# n: ৙,Numero: 2,Fila: 2,Columnas: 2
# n: ৾,Numero: 2,Fila: 2,Columnas: 3
# n: ਣ,Numero: 2,Fila: 2,Columnas: 4
# n: ੈ,Numero: 2,Fila: 2,Columnas: 5
# n: ੭,Numero: 2,Fila: 3,Columnas: 0
# n: ઒,Numero: 2,Fila: 3,Columnas: 1
# n: ષ,Numero: 2,Fila: 3,Columnas: 2
# n: ૜,Numero: 2,Fila: 3,Columnas: 3
# n: ଁ,Numero: 2,Fila: 3,Columnas: 4
# n: ଦ,Numero: 2,Fila: 3,Columnas: 5
# n: ୋ,Numero: 2,Fila: 4,Columnas: 0
# n: ୰,Numero: 2,Fila: 4,Columnas: 1
# n: க,Numero: 2,Fila: 4,Columnas: 2
# n: ஺,Numero: 2,Fila: 4,Columnas: 3
# n: ௟,Numero: 2,Fila: 4,Columnas: 4
# n: ఄ,Numero: 2,Fila: 4,Columnas: 5
# n: ఩,Numero: 2,Fila: 5,Columnas: 0
# n: ౎,Numero: 2,Fila: 5,Columnas: 1
# n: ౳,Numero: 2,Fila: 5,Columnas: 2
# n: ಘ,Numero: 2,Fila: 5,Columnas: 3
# n: ಽ,Numero: 2,Fila: 5,Columnas: 4
# n: ೢ,Numero: 2,Fila: 5,Columnas: 5
# n: ߔ,Numero: 3,Fila: 0,Columnas: 0
# n: ߹,Numero: 3,Fila: 0,Columnas: 1
# n: ࠞ,Numero: 3,Fila: 0,Columnas: 2
# n: ࡃ,Numero: 3,Fila: 0,Columnas: 3
# n: ࡨ,Numero: 3,Fila: 0,Columnas: 4
# n: ࢍ,Numero: 3,Fila: 0,Columnas: 5
# n: ࢲ,Numero: 3,Fila: 1,Columnas: 0
# n: ࣗ,Numero: 3,Fila: 1,Columnas: 1
# n: ࣼ,Numero: 3,Fila: 1,Columnas: 2
# n: ड,Numero: 3,Fila: 1,Columnas: 3
# n: ॆ,Numero: 3,Fila: 1,Columnas: 4
# n: ५,Numero: 3,Fila: 1,Columnas: 5
# n: ঐ,Numero: 3,Fila: 2,Columnas: 0
# n: ঵,Numero: 3,Fila: 2,Columnas: 1
# n: ৚,Numero: 3,Fila: 2,Columnas: 2
# n: ৿,Numero: 3,Fila: 2,Columnas: 3
# n: ਤ,Numero: 3,Fila: 2,Columnas: 4
# n: ੉,Numero: 3,Fila: 2,Columnas: 5
# n: ੮,Numero: 3,Fila: 3,Columnas: 0
# n: ઓ,Numero: 3,Fila: 3,Columnas: 1
# n: સ,Numero: 3,Fila: 3,Columnas: 2
# n: ૝,Numero: 3,Fila: 3,Columnas: 3
# n: ଂ,Numero: 3,Fila: 3,Columnas: 4
# n: ଧ,Numero: 3,Fila: 3,Columnas: 5
# n: ୌ,Numero: 3,Fila: 4,Columnas: 0
# n: ୱ,Numero: 3,Fila: 4,Columnas: 1
# n: ஖,Numero: 3,Fila: 4,Columnas: 2
# n: ஻,Numero: 3,Fila: 4,Columnas: 3
# n: ௠,Numero: 3,Fila: 4,Columnas: 4
# n: అ,Numero: 3,Fila: 4,Columnas: 5
# n: ప,Numero: 3,Fila: 5,Columnas: 0
# n: ౏,Numero: 3,Fila: 5,Columnas: 1
# n: ౴,Numero: 3,Fila: 5,Columnas: 2
# n: ಙ,Numero: 3,Fila: 5,Columnas: 3
# n: ಾ,Numero: 3,Fila: 5,Columnas: 4
# n: ೣ,Numero: 3,Fila: 5,Columnas: 5
# n: ߕ,Numero: 4,Fila: 0,Columnas: 0
# n: ߺ,Numero: 4,Fila: 0,Columnas: 1
# n: ࠟ,Numero: 4,Fila: 0,Columnas: 2
# n: ࡄ,Numero: 4,Fila: 0,Columnas: 3
# n: ࡩ,Numero: 4,Fila: 0,Columnas: 4
# n: ࢎ,Numero: 4,Fila: 0,Columnas: 5
# n: ࢳ,Numero: 4,Fila: 1,Columnas: 0
# n: ࣘ,Numero: 4,Fila: 1,Columnas: 1
# n: ࣽ,Numero: 4,Fila: 1,Columnas: 2
# n: ढ,Numero: 4,Fila: 1,Columnas: 3
# n: े,Numero: 4,Fila: 1,Columnas: 4
# n: ६,Numero: 4,Fila: 1,Columnas: 5
# n: ঑,Numero: 4,Fila: 2,Columnas: 0
# n: শ,Numero: 4,Fila: 2,Columnas: 1
# n: ৛,Numero: 4,Fila: 2,Columnas: 2
# n: ਀,Numero: 4,Fila: 2,Columnas: 3
# n: ਥ,Numero: 4,Fila: 2,Columnas: 4
# n: ੊,Numero: 4,Fila: 2,Columnas: 5
# n: ੯,Numero: 4,Fila: 3,Columnas: 0
# n: ઔ,Numero: 4,Fila: 3,Columnas: 1
# n: હ,Numero: 4,Fila: 3,Columnas: 2
# n: ૞,Numero: 4,Fila: 3,Columnas: 3
# n: ଃ,Numero: 4,Fila: 3,Columnas: 4
# n: ନ,Numero: 4,Fila: 3,Columnas: 5
# n: ୍,Numero: 4,Fila: 4,Columnas: 0
# n: ୲,Numero: 4,Fila: 4,Columnas: 1
# n: ஗,Numero: 4,Fila: 4,Columnas: 2
# n: ஼,Numero: 4,Fila: 4,Columnas: 3
# n: ௡,Numero: 4,Fila: 4,Columnas: 4
# n: ఆ,Numero: 4,Fila: 4,Columnas: 5
# n: ఫ,Numero: 4,Fila: 5,Columnas: 0
# n: ౐,Numero: 4,Fila: 5,Columnas: 1
# n: ౵,Numero: 4,Fila: 5,Columnas: 2
# n: ಚ,Numero: 4,Fila: 5,Columnas: 3
# n: ಿ,Numero: 4,Fila: 5,Columnas: 4
# n: ೤,Numero: 4,Fila: 5,Columnas: 5
# n: ߖ,Numero: 5,Fila: 0,Columnas: 0
# n: ߻,Numero: 5,Fila: 0,Columnas: 1
# n: ࠠ,Numero: 5,Fila: 0,Columnas: 2
# n: ࡅ,Numero: 5,Fila: 0,Columnas: 3
# n: ࡪ,Numero: 5,Fila: 0,Columnas: 4
# n: ࢏,Numero: 5,Fila: 0,Columnas: 5
# n: ࢴ,Numero: 5,Fila: 1,Columnas: 0
# n: ࣙ,Numero: 5,Fila: 1,Columnas: 1
# n: ࣾ,Numero: 5,Fila: 1,Columnas: 2
# n: ण,Numero: 5,Fila: 1,Columnas: 3
# n: ै,Numero: 5,Fila: 1,Columnas: 4
# n: ७,Numero: 5,Fila: 1,Columnas: 5
# n: ঒,Numero: 5,Fila: 2,Columnas: 0
# n: ষ,Numero: 5,Fila: 2,Columnas: 1
# n: ড়,Numero: 5,Fila: 2,Columnas: 2
# n: ਁ,Numero: 5,Fila: 2,Columnas: 3
# n: ਦ,Numero: 5,Fila: 2,Columnas: 4
# n: ੋ,Numero: 5,Fila: 2,Columnas: 5
# n: ੰ,Numero: 5,Fila: 3,Columnas: 0
# n: ક,Numero: 5,Fila: 3,Columnas: 1
# n: ઺,Numero: 5,Fila: 3,Columnas: 2
# n: ૟,Numero: 5,Fila: 3,Columnas: 3
# n: ଄,Numero: 5,Fila: 3,Columnas: 4
# n: ଩,Numero: 5,Fila: 3,Columnas: 5
# n: ୎,Numero: 5,Fila: 4,Columnas: 0
# n: ୳,Numero: 5,Fila: 4,Columnas: 1
# n: ஘,Numero: 5,Fila: 4,Columnas: 2
# n: ஽,Numero: 5,Fila: 4,Columnas: 3
# n: ௢,Numero: 5,Fila: 4,Columnas: 4
# n: ఇ,Numero: 5,Fila: 4,Columnas: 5
# n: బ,Numero: 5,Fila: 5,Columnas: 0
# n: ౑,Numero: 5,Fila: 5,Columnas: 1
# n: ౶,Numero: 5,Fila: 5,Columnas: 2
# n: ಛ,Numero: 5,Fila: 5,Columnas: 3
# n: ೀ,Numero: 5,Fila: 5,Columnas: 4
# n: ೥,Numero: 5,Fila: 5,Columnas: 5
# n: ߗ,Numero: 6,Fila: 0,Columnas: 0
# n: ߼,Numero: 6,Fila: 0,Columnas: 1
# n: ࠡ,Numero: 6,Fila: 0,Columnas: 2
# n: ࡆ,Numero: 6,Fila: 0,Columnas: 3
# n: ࡫,Numero: 6,Fila: 0,Columnas: 4
# n: ࢐,Numero: 6,Fila: 0,Columnas: 5
# n: ࢵ,Numero: 6,Fila: 1,Columnas: 0
# n: ࣚ,Numero: 6,Fila: 1,Columnas: 1
# n: ࣿ,Numero: 6,Fila: 1,Columnas: 2
# n: त,Numero: 6,Fila: 1,Columnas: 3
# n: ॉ,Numero: 6,Fila: 1,Columnas: 4
# n: ८,Numero: 6,Fila: 1,Columnas: 5
# n: ও,Numero: 6,Fila: 2,Columnas: 0
# n: স,Numero: 6,Fila: 2,Columnas: 1
# n: ঢ়,Numero: 6,Fila: 2,Columnas: 2
# n: ਂ,Numero: 6,Fila: 2,Columnas: 3
# n: ਧ,Numero: 6,Fila: 2,Columnas: 4
# n: ੌ,Numero: 6,Fila: 2,Columnas: 5
# n: ੱ,Numero: 6,Fila: 3,Columnas: 0
# n: ખ,Numero: 6,Fila: 3,Columnas: 1
# n: ઻,Numero: 6,Fila: 3,Columnas: 2
# n: ૠ,Numero: 6,Fila: 3,Columnas: 3
# n: ଅ,Numero: 6,Fila: 3,Columnas: 4
# n: ପ,Numero: 6,Fila: 3,Columnas: 5
# n: ୏,Numero: 6,Fila: 4,Columnas: 0
# n: ୴,Numero: 6,Fila: 4,Columnas: 1
# n: ங,Numero: 6,Fila: 4,Columnas: 2
# n: ா,Numero: 6,Fila: 4,Columnas: 3
# n: ௣,Numero: 6,Fila: 4,Columnas: 4
# n: ఈ,Numero: 6,Fila: 4,Columnas: 5
# n: భ,Numero: 6,Fila: 5,Columnas: 0
# n: ౒,Numero: 6,Fila: 5,Columnas: 1
# n: ౷,Numero: 6,Fila: 5,Columnas: 2
# n: ಜ,Numero: 6,Fila: 5,Columnas: 3
# n: ು,Numero: 6,Fila: 5,Columnas: 4
# n: ೦,Numero: 6,Fila: 5,Columnas: 5
# n: ߘ,Numero: 7,Fila: 0,Columnas: 0
# n: ߽,Numero: 7,Fila: 0,Columnas: 1
# n: ࠢ,Numero: 7,Fila: 0,Columnas: 2
# n: ࡇ,Numero: 7,Fila: 0,Columnas: 3
# n: ࡬,Numero: 7,Fila: 0,Columnas: 4
# n: ࢑,Numero: 7,Fila: 0,Columnas: 5
# n: ࢶ,Numero: 7,Fila: 1,Columnas: 0
# n: ࣛ,Numero: 7,Fila: 1,Columnas: 1
# n: ऀ,Numero: 7,Fila: 1,Columnas: 2
# n: थ,Numero: 7,Fila: 1,Columnas: 3
# n: ॊ,Numero: 7,Fila: 1,Columnas: 4
# n: ९,Numero: 7,Fila: 1,Columnas: 5
# n: ঔ,Numero: 7,Fila: 2,Columnas: 0
# n: হ,Numero: 7,Fila: 2,Columnas: 1
# n: ৞,Numero: 7,Fila: 2,Columnas: 2
# n: ਃ,Numero: 7,Fila: 2,Columnas: 3
# n: ਨ,Numero: 7,Fila: 2,Columnas: 4
# n: ੍,Numero: 7,Fila: 2,Columnas: 5
# n: ੲ,Numero: 7,Fila: 3,Columnas: 0
# n: ગ,Numero: 7,Fila: 3,Columnas: 1
# n: ઼,Numero: 7,Fila: 3,Columnas: 2
# n: ૡ,Numero: 7,Fila: 3,Columnas: 3
# n: ଆ,Numero: 7,Fila: 3,Columnas: 4
# n: ଫ,Numero: 7,Fila: 3,Columnas: 5
# n: ୐,Numero: 7,Fila: 4,Columnas: 0
# n: ୵,Numero: 7,Fila: 4,Columnas: 1
# n: ச,Numero: 7,Fila: 4,Columnas: 2
# n: ி,Numero: 7,Fila: 4,Columnas: 3
# n: ௤,Numero: 7,Fila: 4,Columnas: 4
# n: ఉ,Numero: 7,Fila: 4,Columnas: 5
# n: మ,Numero: 7,Fila: 5,Columnas: 0
# n: ౓,Numero: 7,Fila: 5,Columnas: 1
# n: ౸,Numero: 7,Fila: 5,Columnas: 2
# n: ಝ,Numero: 7,Fila: 5,Columnas: 3
# n: ೂ,Numero: 7,Fila: 5,Columnas: 4
# n: ೧,Numero: 7,Fila: 5,Columnas: 5
# n: ߙ,Numero: 8,Fila: 0,Columnas: 0
# n: ߾,Numero: 8,Fila: 0,Columnas: 1
# n: ࠣ,Numero: 8,Fila: 0,Columnas: 2
# n: ࡈ,Numero: 8,Fila: 0,Columnas: 3
# n: ࡭,Numero: 8,Fila: 0,Columnas: 4
# n: ࢒,Numero: 8,Fila: 0,Columnas: 5
# n: ࢷ,Numero: 8,Fila: 1,Columnas: 0
# n: ࣜ,Numero: 8,Fila: 1,Columnas: 1
# n: ँ,Numero: 8,Fila: 1,Columnas: 2
# n: द,Numero: 8,Fila: 1,Columnas: 3
# n: ो,Numero: 8,Fila: 1,Columnas: 4
# n: ॰,Numero: 8,Fila: 1,Columnas: 5
# n: ক,Numero: 8,Fila: 2,Columnas: 0
# n: ঺,Numero: 8,Fila: 2,Columnas: 1
# n: য়,Numero: 8,Fila: 2,Columnas: 2
# n: ਄,Numero: 8,Fila: 2,Columnas: 3
# n: ਩,Numero: 8,Fila: 2,Columnas: 4
# n: ੎,Numero: 8,Fila: 2,Columnas: 5
# n: ੳ,Numero: 8,Fila: 3,Columnas: 0
# n: ઘ,Numero: 8,Fila: 3,Columnas: 1
# n: ઽ,Numero: 8,Fila: 3,Columnas: 2
# n: ૢ,Numero: 8,Fila: 3,Columnas: 3
# n: ଇ,Numero: 8,Fila: 3,Columnas: 4
# n: ବ,Numero: 8,Fila: 3,Columnas: 5
# n: ୑,Numero: 8,Fila: 4,Columnas: 0
# n: ୶,Numero: 8,Fila: 4,Columnas: 1
# n: ஛,Numero: 8,Fila: 4,Columnas: 2
# n: ீ,Numero: 8,Fila: 4,Columnas: 3
# n: ௥,Numero: 8,Fila: 4,Columnas: 4
# n: ఊ,Numero: 8,Fila: 4,Columnas: 5
# n: య,Numero: 8,Fila: 5,Columnas: 0
# n: ౔,Numero: 8,Fila: 5,Columnas: 1
# n: ౹,Numero: 8,Fila: 5,Columnas: 2
# n: ಞ,Numero: 8,Fila: 5,Columnas: 3
# n: ೃ,Numero: 8,Fila: 5,Columnas: 4
# n: ೨,Numero: 8,Fila: 5,Columnas: 5
# n: ߚ,Numero: 9,Fila: 0,Columnas: 0
# n: ߿,Numero: 9,Fila: 0,Columnas: 1
# n: ࠤ,Numero: 9,Fila: 0,Columnas: 2
# n: ࡉ,Numero: 9,Fila: 0,Columnas: 3
# n: ࡮,Numero: 9,Fila: 0,Columnas: 4
# n: ࢓,Numero: 9,Fila: 0,Columnas: 5
# n: ࢸ,Numero: 9,Fila: 1,Columnas: 0
# n: ࣝ,Numero: 9,Fila: 1,Columnas: 1
# n: ं,Numero: 9,Fila: 1,Columnas: 2
# n: ध,Numero: 9,Fila: 1,Columnas: 3
# n: ौ,Numero: 9,Fila: 1,Columnas: 4
# n: ॱ,Numero: 9,Fila: 1,Columnas: 5
# n: খ,Numero: 9,Fila: 2,Columnas: 0
# n: ঻,Numero: 9,Fila: 2,Columnas: 1
# n: ৠ,Numero: 9,Fila: 2,Columnas: 2
# n: ਅ,Numero: 9,Fila: 2,Columnas: 3
# n: ਪ,Numero: 9,Fila: 2,Columnas: 4
# n: ੏,Numero: 9,Fila: 2,Columnas: 5
# n: ੴ,Numero: 9,Fila: 3,Columnas: 0
# n: ઙ,Numero: 9,Fila: 3,Columnas: 1
# n: ા,Numero: 9,Fila: 3,Columnas: 2
# n: ૣ,Numero: 9,Fila: 3,Columnas: 3
# n: ଈ,Numero: 9,Fila: 3,Columnas: 4
# n: ଭ,Numero: 9,Fila: 3,Columnas: 5
# n: ୒,Numero: 9,Fila: 4,Columnas: 0
# n: ୷,Numero: 9,Fila: 4,Columnas: 1
# n: ஜ,Numero: 9,Fila: 4,Columnas: 2
# n: ு,Numero: 9,Fila: 4,Columnas: 3
# n: ௦,Numero: 9,Fila: 4,Columnas: 4
# n: ఋ,Numero: 9,Fila: 4,Columnas: 5
# n: ర,Numero: 9,Fila: 5,Columnas: 0
# n: ౕ,Numero: 9,Fila: 5,Columnas: 1
# n: ౺,Numero: 9,Fila: 5,Columnas: 2
# n: ಟ,Numero: 9,Fila: 5,Columnas: 3
# n: ೄ,Numero: 9,Fila: 5,Columnas: 4
# n: ೩,Numero: 9,Fila: 5,Columnas: 5
# n: ߛ,Numero: 10,Fila: 0,Columnas: 0
# n: ࠀ,Numero: 10,Fila: 0,Columnas: 1
# n: ࠥ,Numero: 10,Fila: 0,Columnas: 2
# n: ࡊ,Numero: 10,Fila: 0,Columnas: 3
# n: ࡯,Numero: 10,Fila: 0,Columnas: 4
# n: ࢔,Numero: 10,Fila: 0,Columnas: 5
# n: ࢹ,Numero: 10,Fila: 1,Columnas: 0
# n: ࣞ,Numero: 10,Fila: 1,Columnas: 1
# n: ः,Numero: 10,Fila: 1,Columnas: 2
# n: न,Numero: 10,Fila: 1,Columnas: 3
# n: ्,Numero: 10,Fila: 1,Columnas: 4
# n: ॲ,Numero: 10,Fila: 1,Columnas: 5
# n: গ,Numero: 10,Fila: 2,Columnas: 0
# n: ়,Numero: 10,Fila: 2,Columnas: 1
# n: ৡ,Numero: 10,Fila: 2,Columnas: 2
# n: ਆ,Numero: 10,Fila: 2,Columnas: 3
# n: ਫ,Numero: 10,Fila: 2,Columnas: 4
# n: ੐,Numero: 10,Fila: 2,Columnas: 5
# n: ੵ,Numero: 10,Fila: 3,Columnas: 0
# n: ચ,Numero: 10,Fila: 3,Columnas: 1
# n: િ,Numero: 10,Fila: 3,Columnas: 2
# n: ૤,Numero: 10,Fila: 3,Columnas: 3
# n: ଉ,Numero: 10,Fila: 3,Columnas: 4
# n: ମ,Numero: 10,Fila: 3,Columnas: 5
# n: ୓,Numero: 10,Fila: 4,Columnas: 0
# n: ୸,Numero: 10,Fila: 4,Columnas: 1
# n: ஝,Numero: 10,Fila: 4,Columnas: 2
# n: ூ,Numero: 10,Fila: 4,Columnas: 3
# n: ௧,Numero: 10,Fila: 4,Columnas: 4
# n: ఌ,Numero: 10,Fila: 4,Columnas: 5
# n: ఱ,Numero: 10,Fila: 5,Columnas: 0
# n: ౖ,Numero: 10,Fila: 5,Columnas: 1
# n: ౻,Numero: 10,Fila: 5,Columnas: 2
# n: ಠ,Numero: 10,Fila: 5,Columnas: 3
# n: ೅,Numero: 10,Fila: 5,Columnas: 4
# n: ೪,Numero: 10,Fila: 5,Columnas: 5
# n: ߜ,Numero: 11,Fila: 0,Columnas: 0
# n: ࠁ,Numero: 11,Fila: 0,Columnas: 1
# n: ࠦ,Numero: 11,Fila: 0,Columnas: 2
# n: ࡋ,Numero: 11,Fila: 0,Columnas: 3
# n: ࡰ,Numero: 11,Fila: 0,Columnas: 4
# n: ࢕,Numero: 11,Fila: 0,Columnas: 5
# n: ࢺ,Numero: 11,Fila: 1,Columnas: 0
# n: ࣟ,Numero: 11,Fila: 1,Columnas: 1
# n: ऄ,Numero: 11,Fila: 1,Columnas: 2
# n: ऩ,Numero: 11,Fila: 1,Columnas: 3
# n: ॎ,Numero: 11,Fila: 1,Columnas: 4
# n: ॳ,Numero: 11,Fila: 1,Columnas: 5
# n: ঘ,Numero: 11,Fila: 2,Columnas: 0
# n: ঽ,Numero: 11,Fila: 2,Columnas: 1
# n: ৢ,Numero: 11,Fila: 2,Columnas: 2
# n: ਇ,Numero: 11,Fila: 2,Columnas: 3
# n: ਬ,Numero: 11,Fila: 2,Columnas: 4
# n: ੑ,Numero: 11,Fila: 2,Columnas: 5
# n: ੶,Numero: 11,Fila: 3,Columnas: 0
# n: છ,Numero: 11,Fila: 3,Columnas: 1
# n: ી,Numero: 11,Fila: 3,Columnas: 2
# n: ૥,Numero: 11,Fila: 3,Columnas: 3
# n: ଊ,Numero: 11,Fila: 3,Columnas: 4
# n: ଯ,Numero: 11,Fila: 3,Columnas: 5
# n: ୔,Numero: 11,Fila: 4,Columnas: 0
# n: ୹,Numero: 11,Fila: 4,Columnas: 1
# n: ஞ,Numero: 11,Fila: 4,Columnas: 2
# n: ௃,Numero: 11,Fila: 4,Columnas: 3
# n: ௨,Numero: 11,Fila: 4,Columnas: 4
# n: ఍,Numero: 11,Fila: 4,Columnas: 5
# n: ల,Numero: 11,Fila: 5,Columnas: 0
# n: ౗,Numero: 11,Fila: 5,Columnas: 1
# n: ౼,Numero: 11,Fila: 5,Columnas: 2
# n: ಡ,Numero: 11,Fila: 5,Columnas: 3
# n: ೆ,Numero: 11,Fila: 5,Columnas: 4
# n: ೫,Numero: 11,Fila: 5,Columnas: 5
# n: ߝ,Numero: 12,Fila: 0,Columnas: 0
# n: ࠂ,Numero: 12,Fila: 0,Columnas: 1
# n: ࠧ,Numero: 12,Fila: 0,Columnas: 2
# n: ࡌ,Numero: 12,Fila: 0,Columnas: 3
# n: ࡱ,Numero: 12,Fila: 0,Columnas: 4
# n: ࢖,Numero: 12,Fila: 0,Columnas: 5
# n: ࢻ,Numero: 12,Fila: 1,Columnas: 0
# n: ࣠,Numero: 12,Fila: 1,Columnas: 1
# n: अ,Numero: 12,Fila: 1,Columnas: 2
# n: प,Numero: 12,Fila: 1,Columnas: 3
# n: ॏ,Numero: 12,Fila: 1,Columnas: 4
# n: ॴ,Numero: 12,Fila: 1,Columnas: 5
# n: ঙ,Numero: 12,Fila: 2,Columnas: 0
# n: া,Numero: 12,Fila: 2,Columnas: 1
# n: ৣ,Numero: 12,Fila: 2,Columnas: 2
# n: ਈ,Numero: 12,Fila: 2,Columnas: 3
# n: ਭ,Numero: 12,Fila: 2,Columnas: 4
# n: ੒,Numero: 12,Fila: 2,Columnas: 5
# n: ੷,Numero: 12,Fila: 3,Columnas: 0
# n: જ,Numero: 12,Fila: 3,Columnas: 1
# n: ુ,Numero: 12,Fila: 3,Columnas: 2
# n: ૦,Numero: 12,Fila: 3,Columnas: 3
# n: ଋ,Numero: 12,Fila: 3,Columnas: 4
# n: ର,Numero: 12,Fila: 3,Columnas: 5
# n: ୕,Numero: 12,Fila: 4,Columnas: 0
# n: ୺,Numero: 12,Fila: 4,Columnas: 1
# n: ட,Numero: 12,Fila: 4,Columnas: 2
# n: ௄,Numero: 12,Fila: 4,Columnas: 3
# n: ௩,Numero: 12,Fila: 4,Columnas: 4
# n: ఎ,Numero: 12,Fila: 4,Columnas: 5
# n: ళ,Numero: 12,Fila: 5,Columnas: 0
# n: ౘ,Numero: 12,Fila: 5,Columnas: 1
# n: ౽,Numero: 12,Fila: 5,Columnas: 2
# n: ಢ,Numero: 12,Fila: 5,Columnas: 3
# n: ೇ,Numero: 12,Fila: 5,Columnas: 4
# n: ೬,Numero: 12,Fila: 5,Columnas: 5
# n: ߞ,Numero: 13,Fila: 0,Columnas: 0
# n: ࠃ,Numero: 13,Fila: 0,Columnas: 1
# n: ࠨ,Numero: 13,Fila: 0,Columnas: 2
# n: ࡍ,Numero: 13,Fila: 0,Columnas: 3
# n: ࡲ,Numero: 13,Fila: 0,Columnas: 4
# n: ࢗ,Numero: 13,Fila: 0,Columnas: 5
# n: ࢼ,Numero: 13,Fila: 1,Columnas: 0
# n: ࣡,Numero: 13,Fila: 1,Columnas: 1
# n: आ,Numero: 13,Fila: 1,Columnas: 2
# n: फ,Numero: 13,Fila: 1,Columnas: 3
# n: ॐ,Numero: 13,Fila: 1,Columnas: 4
# n: ॵ,Numero: 13,Fila: 1,Columnas: 5
# n: চ,Numero: 13,Fila: 2,Columnas: 0
# n: ি,Numero: 13,Fila: 2,Columnas: 1
# n: ৤,Numero: 13,Fila: 2,Columnas: 2
# n: ਉ,Numero: 13,Fila: 2,Columnas: 3
# n: ਮ,Numero: 13,Fila: 2,Columnas: 4
# n: ੓,Numero: 13,Fila: 2,Columnas: 5
# n: ੸,Numero: 13,Fila: 3,Columnas: 0
# n: ઝ,Numero: 13,Fila: 3,Columnas: 1
# n: ૂ,Numero: 13,Fila: 3,Columnas: 2
# n: ૧,Numero: 13,Fila: 3,Columnas: 3
# n: ଌ,Numero: 13,Fila: 3,Columnas: 4
# n: ଱,Numero: 13,Fila: 3,Columnas: 5
# n: ୖ,Numero: 13,Fila: 4,Columnas: 0
# n: ୻,Numero: 13,Fila: 4,Columnas: 1
# n: ஠,Numero: 13,Fila: 4,Columnas: 2
# n: ௅,Numero: 13,Fila: 4,Columnas: 3
# n: ௪,Numero: 13,Fila: 4,Columnas: 4
# n: ఏ,Numero: 13,Fila: 4,Columnas: 5
# n: ఴ,Numero: 13,Fila: 5,Columnas: 0
# n: ౙ,Numero: 13,Fila: 5,Columnas: 1
# n: ౾,Numero: 13,Fila: 5,Columnas: 2
# n: ಣ,Numero: 13,Fila: 5,Columnas: 3
# n: ೈ,Numero: 13,Fila: 5,Columnas: 4
# n: ೭,Numero: 13,Fila: 5,Columnas: 5
# n: ߟ,Numero: 14,Fila: 0,Columnas: 0
# n: ࠄ,Numero: 14,Fila: 0,Columnas: 1
# n: ࠩ,Numero: 14,Fila: 0,Columnas: 2
# n: ࡎ,Numero: 14,Fila: 0,Columnas: 3
# n: ࡳ,Numero: 14,Fila: 0,Columnas: 4
# n: ࢘,Numero: 14,Fila: 0,Columnas: 5
# n: ࢽ,Numero: 14,Fila: 1,Columnas: 0
# n: ࣢,Numero: 14,Fila: 1,Columnas: 1
# n: इ,Numero: 14,Fila: 1,Columnas: 2
# n: ब,Numero: 14,Fila: 1,Columnas: 3
# n: ॑,Numero: 14,Fila: 1,Columnas: 4
# n: ॶ,Numero: 14,Fila: 1,Columnas: 5
# n: ছ,Numero: 14,Fila: 2,Columnas: 0
# n: ী,Numero: 14,Fila: 2,Columnas: 1
# n: ৥,Numero: 14,Fila: 2,Columnas: 2
# n: ਊ,Numero: 14,Fila: 2,Columnas: 3
# n: ਯ,Numero: 14,Fila: 2,Columnas: 4
# n: ੔,Numero: 14,Fila: 2,Columnas: 5
# n: ੹,Numero: 14,Fila: 3,Columnas: 0
# n: ઞ,Numero: 14,Fila: 3,Columnas: 1
# n: ૃ,Numero: 14,Fila: 3,Columnas: 2
# n: ૨,Numero: 14,Fila: 3,Columnas: 3
# n: ଍,Numero: 14,Fila: 3,Columnas: 4
# n: ଲ,Numero: 14,Fila: 3,Columnas: 5
# n: ୗ,Numero: 14,Fila: 4,Columnas: 0
# n: ୼,Numero: 14,Fila: 4,Columnas: 1
# n: ஡,Numero: 14,Fila: 4,Columnas: 2
# n: ெ,Numero: 14,Fila: 4,Columnas: 3
# n: ௫,Numero: 14,Fila: 4,Columnas: 4
# n: ఐ,Numero: 14,Fila: 4,Columnas: 5
# n: వ,Numero: 14,Fila: 5,Columnas: 0
# n: ౚ,Numero: 14,Fila: 5,Columnas: 1
# n: ౿,Numero: 14,Fila: 5,Columnas: 2
# n: ತ,Numero: 14,Fila: 5,Columnas: 3
# n: ೉,Numero: 14,Fila: 5,Columnas: 4
# n: ೮,Numero: 14,Fila: 5,Columnas: 5
# n: ߠ,Numero: 15,Fila: 0,Columnas: 0
# n: ࠅ,Numero: 15,Fila: 0,Columnas: 1
# n: ࠪ,Numero: 15,Fila: 0,Columnas: 2
# n: ࡏ,Numero: 15,Fila: 0,Columnas: 3
# n: ࡴ,Numero: 15,Fila: 0,Columnas: 4
# n: ࢙,Numero: 15,Fila: 0,Columnas: 5
# n: ࢾ,Numero: 15,Fila: 1,Columnas: 0
# n: ࣣ,Numero: 15,Fila: 1,Columnas: 1
# n: ई,Numero: 15,Fila: 1,Columnas: 2
# n: भ,Numero: 15,Fila: 1,Columnas: 3
# n: ॒,Numero: 15,Fila: 1,Columnas: 4
# n: ॷ,Numero: 15,Fila: 1,Columnas: 5
# n: জ,Numero: 15,Fila: 2,Columnas: 0
# n: ু,Numero: 15,Fila: 2,Columnas: 1
# n: ০,Numero: 15,Fila: 2,Columnas: 2
# n: ਋,Numero: 15,Fila: 2,Columnas: 3
# n: ਰ,Numero: 15,Fila: 2,Columnas: 4
# n: ੕,Numero: 15,Fila: 2,Columnas: 5
# n: ੺,Numero: 15,Fila: 3,Columnas: 0
# n: ટ,Numero: 15,Fila: 3,Columnas: 1
# n: ૄ,Numero: 15,Fila: 3,Columnas: 2
# n: ૩,Numero: 15,Fila: 3,Columnas: 3
# n: ଎,Numero: 15,Fila: 3,Columnas: 4
# n: ଳ,Numero: 15,Fila: 3,Columnas: 5
# n: ୘,Numero: 15,Fila: 4,Columnas: 0
# n: ୽,Numero: 15,Fila: 4,Columnas: 1
# n: ஢,Numero: 15,Fila: 4,Columnas: 2
# n: ே,Numero: 15,Fila: 4,Columnas: 3
# n: ௬,Numero: 15,Fila: 4,Columnas: 4
# n: ఑,Numero: 15,Fila: 4,Columnas: 5
# n: శ,Numero: 15,Fila: 5,Columnas: 0
# n: ౛,Numero: 15,Fila: 5,Columnas: 1
# n: ಀ,Numero: 15,Fila: 5,Columnas: 2
# n: ಥ,Numero: 15,Fila: 5,Columnas: 3
# n: ೊ,Numero: 15,Fila: 5,Columnas: 4
# n: ೯,Numero: 15,Fila: 5,Columnas: 5
# n: ߡ,Numero: 16,Fila: 0,Columnas: 0
# n: ࠆ,Numero: 16,Fila: 0,Columnas: 1
# n: ࠫ,Numero: 16,Fila: 0,Columnas: 2
# n: ࡐ,Numero: 16,Fila: 0,Columnas: 3
# n: ࡵ,Numero: 16,Fila: 0,Columnas: 4
# n: ࢚,Numero: 16,Fila: 0,Columnas: 5
# n: ࢿ,Numero: 16,Fila: 1,Columnas: 0
# n: ࣤ,Numero: 16,Fila: 1,Columnas: 1
# n: उ,Numero: 16,Fila: 1,Columnas: 2
# n: म,Numero: 16,Fila: 1,Columnas: 3
# n: ॓,Numero: 16,Fila: 1,Columnas: 4
# n: ॸ,Numero: 16,Fila: 1,Columnas: 5
# n: ঝ,Numero: 16,Fila: 2,Columnas: 0
# n: ূ,Numero: 16,Fila: 2,Columnas: 1
# n: ১,Numero: 16,Fila: 2,Columnas: 2
# n: ਌,Numero: 16,Fila: 2,Columnas: 3
# n: ਱,Numero: 16,Fila: 2,Columnas: 4
# n: ੖,Numero: 16,Fila: 2,Columnas: 5
# n: ੻,Numero: 16,Fila: 3,Columnas: 0
# n: ઠ,Numero: 16,Fila: 3,Columnas: 1
# n: ૅ,Numero: 16,Fila: 3,Columnas: 2
# n: ૪,Numero: 16,Fila: 3,Columnas: 3
# n: ଏ,Numero: 16,Fila: 3,Columnas: 4
# n: ଴,Numero: 16,Fila: 3,Columnas: 5
# n: ୙,Numero: 16,Fila: 4,Columnas: 0
# n: ୾,Numero: 16,Fila: 4,Columnas: 1
# n: ண,Numero: 16,Fila: 4,Columnas: 2
# n: ை,Numero: 16,Fila: 4,Columnas: 3
# n: ௭,Numero: 16,Fila: 4,Columnas: 4
# n: ఒ,Numero: 16,Fila: 4,Columnas: 5
# n: ష,Numero: 16,Fila: 5,Columnas: 0
# n: ౜,Numero: 16,Fila: 5,Columnas: 1
# n: ಁ,Numero: 16,Fila: 5,Columnas: 2
# n: ದ,Numero: 16,Fila: 5,Columnas: 3
# n: ೋ,Numero: 16,Fila: 5,Columnas: 4
# n: ೰,Numero: 16,Fila: 5,Columnas: 5
# n: ߢ,Numero: 17,Fila: 0,Columnas: 0
# n: ࠇ,Numero: 17,Fila: 0,Columnas: 1
# n: ࠬ,Numero: 17,Fila: 0,Columnas: 2
# n: ࡑ,Numero: 17,Fila: 0,Columnas: 3
# n: ࡶ,Numero: 17,Fila: 0,Columnas: 4
# n: ࢛,Numero: 17,Fila: 0,Columnas: 5
# n: ࣀ,Numero: 17,Fila: 1,Columnas: 0
# n: ࣥ,Numero: 17,Fila: 1,Columnas: 1
# n: ऊ,Numero: 17,Fila: 1,Columnas: 2
# n: य,Numero: 17,Fila: 1,Columnas: 3
# n: ॔,Numero: 17,Fila: 1,Columnas: 4
# n: ॹ,Numero: 17,Fila: 1,Columnas: 5
# n: ঞ,Numero: 17,Fila: 2,Columnas: 0
# n: ৃ,Numero: 17,Fila: 2,Columnas: 1
# n: ২,Numero: 17,Fila: 2,Columnas: 2
# n: ਍,Numero: 17,Fila: 2,Columnas: 3
# n: ਲ,Numero: 17,Fila: 2,Columnas: 4
# n: ੗,Numero: 17,Fila: 2,Columnas: 5
# n: ੼,Numero: 17,Fila: 3,Columnas: 0
# n: ડ,Numero: 17,Fila: 3,Columnas: 1
# n: ૆,Numero: 17,Fila: 3,Columnas: 2
# n: ૫,Numero: 17,Fila: 3,Columnas: 3
# n: ଐ,Numero: 17,Fila: 3,Columnas: 4
# n: ଵ,Numero: 17,Fila: 3,Columnas: 5
# n: ୚,Numero: 17,Fila: 4,Columnas: 0
# n: ୿,Numero: 17,Fila: 4,Columnas: 1
# n: த,Numero: 17,Fila: 4,Columnas: 2
# n: ௉,Numero: 17,Fila: 4,Columnas: 3
# n: ௮,Numero: 17,Fila: 4,Columnas: 4
# n: ఓ,Numero: 17,Fila: 4,Columnas: 5
# n: స,Numero: 17,Fila: 5,Columnas: 0
# n: ౝ,Numero: 17,Fila: 5,Columnas: 1
# n: ಂ,Numero: 17,Fila: 5,Columnas: 2
# n: ಧ,Numero: 17,Fila: 5,Columnas: 3
# n: ೌ,Numero: 17,Fila: 5,Columnas: 4
# n: ೱ,Numero: 17,Fila: 5,Columnas: 5
# n: ߣ,Numero: 18,Fila: 0,Columnas: 0
# n: ࠈ,Numero: 18,Fila: 0,Columnas: 1
# n: ࠭,Numero: 18,Fila: 0,Columnas: 2
# n: ࡒ,Numero: 18,Fila: 0,Columnas: 3
# n: ࡷ,Numero: 18,Fila: 0,Columnas: 4
# n: ࢜,Numero: 18,Fila: 0,Columnas: 5
# n: ࣁ,Numero: 18,Fila: 1,Columnas: 0
# n: ࣦ,Numero: 18,Fila: 1,Columnas: 1
# n: ऋ,Numero: 18,Fila: 1,Columnas: 2
# n: र,Numero: 18,Fila: 1,Columnas: 3
# n: ॕ,Numero: 18,Fila: 1,Columnas: 4
# n: ॺ,Numero: 18,Fila: 1,Columnas: 5
# n: ট,Numero: 18,Fila: 2,Columnas: 0
# n: ৄ,Numero: 18,Fila: 2,Columnas: 1
# n: ৩,Numero: 18,Fila: 2,Columnas: 2
# n: ਎,Numero: 18,Fila: 2,Columnas: 3
# n: ਲ਼,Numero: 18,Fila: 2,Columnas: 4
# n: ੘,Numero: 18,Fila: 2,Columnas: 5
# n: ੽,Numero: 18,Fila: 3,Columnas: 0
# n: ઢ,Numero: 18,Fila: 3,Columnas: 1
# n: ે,Numero: 18,Fila: 3,Columnas: 2
# n: ૬,Numero: 18,Fila: 3,Columnas: 3
# n: ଑,Numero: 18,Fila: 3,Columnas: 4
# n: ଶ,Numero: 18,Fila: 3,Columnas: 5
# n: ୛,Numero: 18,Fila: 4,Columnas: 0
# n: ஀,Numero: 18,Fila: 4,Columnas: 1
# n: ஥,Numero: 18,Fila: 4,Columnas: 2
# n: ொ,Numero: 18,Fila: 4,Columnas: 3
# n: ௯,Numero: 18,Fila: 4,Columnas: 4
# n: ఔ,Numero: 18,Fila: 4,Columnas: 5
# n: హ,Numero: 18,Fila: 5,Columnas: 0
# n: ౞,Numero: 18,Fila: 5,Columnas: 1
# n: ಃ,Numero: 18,Fila: 5,Columnas: 2
# n: ನ,Numero: 18,Fila: 5,Columnas: 3
# n: ್,Numero: 18,Fila: 5,Columnas: 4
# n: ೲ,Numero: 18,Fila: 5,Columnas: 5
# n: ߤ,Numero: 19,Fila: 0,Columnas: 0
# n: ࠉ,Numero: 19,Fila: 0,Columnas: 1
# n: ࠮,Numero: 19,Fila: 0,Columnas: 2
# n: ࡓ,Numero: 19,Fila: 0,Columnas: 3
# n: ࡸ,Numero: 19,Fila: 0,Columnas: 4
# n: ࢝,Numero: 19,Fila: 0,Columnas: 5
# n: ࣂ,Numero: 19,Fila: 1,Columnas: 0
# n: ࣧ,Numero: 19,Fila: 1,Columnas: 1
# n: ऌ,Numero: 19,Fila: 1,Columnas: 2
# n: ऱ,Numero: 19,Fila: 1,Columnas: 3
# n: ॖ,Numero: 19,Fila: 1,Columnas: 4
# n: ॻ,Numero: 19,Fila: 1,Columnas: 5
# n: ঠ,Numero: 19,Fila: 2,Columnas: 0
# n: ৅,Numero: 19,Fila: 2,Columnas: 1
# n: ৪,Numero: 19,Fila: 2,Columnas: 2
# n: ਏ,Numero: 19,Fila: 2,Columnas: 3
# n: ਴,Numero: 19,Fila: 2,Columnas: 4
# n: ਖ਼,Numero: 19,Fila: 2,Columnas: 5
# n: ੾,Numero: 19,Fila: 3,Columnas: 0
# n: ણ,Numero: 19,Fila: 3,Columnas: 1
# n: ૈ,Numero: 19,Fila: 3,Columnas: 2
# n: ૭,Numero: 19,Fila: 3,Columnas: 3
# n: ଒,Numero: 19,Fila: 3,Columnas: 4
# n: ଷ,Numero: 19,Fila: 3,Columnas: 5
# n: ଡ଼,Numero: 19,Fila: 4,Columnas: 0
# n: ஁,Numero: 19,Fila: 4,Columnas: 1
# n: ஦,Numero: 19,Fila: 4,Columnas: 2
# n: ோ,Numero: 19,Fila: 4,Columnas: 3
# n: ௰,Numero: 19,Fila: 4,Columnas: 4
# n: క,Numero: 19,Fila: 4,Columnas: 5
# n: ఺,Numero: 19,Fila: 5,Columnas: 0
# n: ౟,Numero: 19,Fila: 5,Columnas: 1
# n: ಄,Numero: 19,Fila: 5,Columnas: 2
# n: ಩,Numero: 19,Fila: 5,Columnas: 3
# n: ೎,Numero: 19,Fila: 5,Columnas: 4
# n: ೳ,Numero: 19,Fila: 5,Columnas: 5
# n: ߥ,Numero: 20,Fila: 0,Columnas: 0
# n: ࠊ,Numero: 20,Fila: 0,Columnas: 1
# n: ࠯,Numero: 20,Fila: 0,Columnas: 2
# n: ࡔ,Numero: 20,Fila: 0,Columnas: 3
# n: ࡹ,Numero: 20,Fila: 0,Columnas: 4
# n: ࢞,Numero: 20,Fila: 0,Columnas: 5
# n: ࣃ,Numero: 20,Fila: 1,Columnas: 0
# n: ࣨ,Numero: 20,Fila: 1,Columnas: 1
# n: ऍ,Numero: 20,Fila: 1,Columnas: 2
# n: ल,Numero: 20,Fila: 1,Columnas: 3
# n: ॗ,Numero: 20,Fila: 1,Columnas: 4
# n: ॼ,Numero: 20,Fila: 1,Columnas: 5
# n: ড,Numero: 20,Fila: 2,Columnas: 0
# n: ৆,Numero: 20,Fila: 2,Columnas: 1
# n: ৫,Numero: 20,Fila: 2,Columnas: 2
# n: ਐ,Numero: 20,Fila: 2,Columnas: 3
# n: ਵ,Numero: 20,Fila: 2,Columnas: 4
# n: ਗ਼,Numero: 20,Fila: 2,Columnas: 5
# n: ੿,Numero: 20,Fila: 3,Columnas: 0
# n: ત,Numero: 20,Fila: 3,Columnas: 1
# n: ૉ,Numero: 20,Fila: 3,Columnas: 2
# n: ૮,Numero: 20,Fila: 3,Columnas: 3
# n: ଓ,Numero: 20,Fila: 3,Columnas: 4
# n: ସ,Numero: 20,Fila: 3,Columnas: 5
# n: ଢ଼,Numero: 20,Fila: 4,Columnas: 0
# n: ஂ,Numero: 20,Fila: 4,Columnas: 1
# n: ஧,Numero: 20,Fila: 4,Columnas: 2
# n: ௌ,Numero: 20,Fila: 4,Columnas: 3
# n: ௱,Numero: 20,Fila: 4,Columnas: 4
# n: ఖ,Numero: 20,Fila: 4,Columnas: 5
# n: ఻,Numero: 20,Fila: 5,Columnas: 0
# n: ౠ,Numero: 20,Fila: 5,Columnas: 1
# n: ಅ,Numero: 20,Fila: 5,Columnas: 2
# n: ಪ,Numero: 20,Fila: 5,Columnas: 3
# n: ೏,Numero: 20,Fila: 5,Columnas: 4
# n: ೴,Numero: 20,Fila: 5,Columnas: 5
# n: ߦ,Numero: 21,Fila: 0,Columnas: 0
# n: ࠋ,Numero: 21,Fila: 0,Columnas: 1
# n: ࠰,Numero: 21,Fila: 0,Columnas: 2
# n: ࡕ,Numero: 21,Fila: 0,Columnas: 3
# n: ࡺ,Numero: 21,Fila: 0,Columnas: 4
# n: ࢟,Numero: 21,Fila: 0,Columnas: 5
# n: ࣄ,Numero: 21,Fila: 1,Columnas: 0
# n: ࣩ,Numero: 21,Fila: 1,Columnas: 1
# n: ऎ,Numero: 21,Fila: 1,Columnas: 2
# n: ळ,Numero: 21,Fila: 1,Columnas: 3
# n: क़,Numero: 21,Fila: 1,Columnas: 4
# n: ॽ,Numero: 21,Fila: 1,Columnas: 5
# n: ঢ,Numero: 21,Fila: 2,Columnas: 0
# n: ে,Numero: 21,Fila: 2,Columnas: 1
# n: ৬,Numero: 21,Fila: 2,Columnas: 2
# n: ਑,Numero: 21,Fila: 2,Columnas: 3
# n: ਸ਼,Numero: 21,Fila: 2,Columnas: 4
# n: ਜ਼,Numero: 21,Fila: 2,Columnas: 5
# n: ઀,Numero: 21,Fila: 3,Columnas: 0
# n: થ,Numero: 21,Fila: 3,Columnas: 1
# n: ૊,Numero: 21,Fila: 3,Columnas: 2
# n: ૯,Numero: 21,Fila: 3,Columnas: 3
# n: ଔ,Numero: 21,Fila: 3,Columnas: 4
# n: ହ,Numero: 21,Fila: 3,Columnas: 5
# n: ୞,Numero: 21,Fila: 4,Columnas: 0
# n: ஃ,Numero: 21,Fila: 4,Columnas: 1
# n: ந,Numero: 21,Fila: 4,Columnas: 2
# n: ்,Numero: 21,Fila: 4,Columnas: 3
# n: ௲,Numero: 21,Fila: 4,Columnas: 4
# n: గ,Numero: 21,Fila: 4,Columnas: 5
# n: ఼,Numero: 21,Fila: 5,Columnas: 0
# n: ౡ,Numero: 21,Fila: 5,Columnas: 1
# n: ಆ,Numero: 21,Fila: 5,Columnas: 2
# n: ಫ,Numero: 21,Fila: 5,Columnas: 3
# n: ೐,Numero: 21,Fila: 5,Columnas: 4
# n: ೵,Numero: 21,Fila: 5,Columnas: 5
# n: ߧ,Numero: 22,Fila: 0,Columnas: 0
# n: ࠌ,Numero: 22,Fila: 0,Columnas: 1
# n: ࠱,Numero: 22,Fila: 0,Columnas: 2
# n: ࡖ,Numero: 22,Fila: 0,Columnas: 3
# n: ࡻ,Numero: 22,Fila: 0,Columnas: 4
# n: ࢠ,Numero: 22,Fila: 0,Columnas: 5
# n: ࣅ,Numero: 22,Fila: 1,Columnas: 0
# n: ࣪,Numero: 22,Fila: 1,Columnas: 1
# n: ए,Numero: 22,Fila: 1,Columnas: 2
# n: ऴ,Numero: 22,Fila: 1,Columnas: 3
# n: ख़,Numero: 22,Fila: 1,Columnas: 4
# n: ॾ,Numero: 22,Fila: 1,Columnas: 5
# n: ণ,Numero: 22,Fila: 2,Columnas: 0
# n: ৈ,Numero: 22,Fila: 2,Columnas: 1
# n: ৭,Numero: 22,Fila: 2,Columnas: 2
# n: ਒,Numero: 22,Fila: 2,Columnas: 3
# n: ਷,Numero: 22,Fila: 2,Columnas: 4
# n: ੜ,Numero: 22,Fila: 2,Columnas: 5
# n: ઁ,Numero: 22,Fila: 3,Columnas: 0
# n: દ,Numero: 22,Fila: 3,Columnas: 1
# n: ો,Numero: 22,Fila: 3,Columnas: 2
# n: ૰,Numero: 22,Fila: 3,Columnas: 3
# n: କ,Numero: 22,Fila: 3,Columnas: 4
# n: ଺,Numero: 22,Fila: 3,Columnas: 5
# n: ୟ,Numero: 22,Fila: 4,Columnas: 0
# n: ஄,Numero: 22,Fila: 4,Columnas: 1
# n: ன,Numero: 22,Fila: 4,Columnas: 2
# n: ௎,Numero: 22,Fila: 4,Columnas: 3
# n: ௳,Numero: 22,Fila: 4,Columnas: 4
# n: ఘ,Numero: 22,Fila: 4,Columnas: 5
# n: ఽ,Numero: 22,Fila: 5,Columnas: 0
# n: ౢ,Numero: 22,Fila: 5,Columnas: 1
# n: ಇ,Numero: 22,Fila: 5,Columnas: 2
# n: ಬ,Numero: 22,Fila: 5,Columnas: 3
# n: ೑,Numero: 22,Fila: 5,Columnas: 4
# n: ೶,Numero: 22,Fila: 5,Columnas: 5
# n: ߨ,Numero: 23,Fila: 0,Columnas: 0
# n: ࠍ,Numero: 23,Fila: 0,Columnas: 1
# n: ࠲,Numero: 23,Fila: 0,Columnas: 2
# n: ࡗ,Numero: 23,Fila: 0,Columnas: 3
# n: ࡼ,Numero: 23,Fila: 0,Columnas: 4
# n: ࢡ,Numero: 23,Fila: 0,Columnas: 5
# n: ࣆ,Numero: 23,Fila: 1,Columnas: 0
# n: ࣫,Numero: 23,Fila: 1,Columnas: 1
# n: ऐ,Numero: 23,Fila: 1,Columnas: 2
# n: व,Numero: 23,Fila: 1,Columnas: 3
# n: ग़,Numero: 23,Fila: 1,Columnas: 4
# n: ॿ,Numero: 23,Fila: 1,Columnas: 5
# n: ত,Numero: 23,Fila: 2,Columnas: 0
# n: ৉,Numero: 23,Fila: 2,Columnas: 1
# n: ৮,Numero: 23,Fila: 2,Columnas: 2
# n: ਓ,Numero: 23,Fila: 2,Columnas: 3
# n: ਸ,Numero: 23,Fila: 2,Columnas: 4
# n: ੝,Numero: 23,Fila: 2,Columnas: 5
# n: ં,Numero: 23,Fila: 3,Columnas: 0
# n: ધ,Numero: 23,Fila: 3,Columnas: 1
# n: ૌ,Numero: 23,Fila: 3,Columnas: 2
# n: ૱,Numero: 23,Fila: 3,Columnas: 3
# n: ଖ,Numero: 23,Fila: 3,Columnas: 4
# n: ଻,Numero: 23,Fila: 3,Columnas: 5
# n: ୠ,Numero: 23,Fila: 4,Columnas: 0
# n: அ,Numero: 23,Fila: 4,Columnas: 1
# n: ப,Numero: 23,Fila: 4,Columnas: 2
# n: ௏,Numero: 23,Fila: 4,Columnas: 3
# n: ௴,Numero: 23,Fila: 4,Columnas: 4
# n: ఙ,Numero: 23,Fila: 4,Columnas: 5
# n: ా,Numero: 23,Fila: 5,Columnas: 0
# n: ౣ,Numero: 23,Fila: 5,Columnas: 1
# n: ಈ,Numero: 23,Fila: 5,Columnas: 2
# n: ಭ,Numero: 23,Fila: 5,Columnas: 3
# n: ೒,Numero: 23,Fila: 5,Columnas: 4
# n: ೷,Numero: 23,Fila: 5,Columnas: 5
# n: ߩ,Numero: 24,Fila: 0,Columnas: 0
# n: ࠎ,Numero: 24,Fila: 0,Columnas: 1
# n: ࠳,Numero: 24,Fila: 0,Columnas: 2
# n: ࡘ,Numero: 24,Fila: 0,Columnas: 3
# n: ࡽ,Numero: 24,Fila: 0,Columnas: 4
# n: ࢢ,Numero: 24,Fila: 0,Columnas: 5
# n: ࣇ,Numero: 24,Fila: 1,Columnas: 0
# n: ࣬,Numero: 24,Fila: 1,Columnas: 1
# n: ऑ,Numero: 24,Fila: 1,Columnas: 2
# n: श,Numero: 24,Fila: 1,Columnas: 3
# n: ज़,Numero: 24,Fila: 1,Columnas: 4
# n: ঀ,Numero: 24,Fila: 1,Columnas: 5
# n: থ,Numero: 24,Fila: 2,Columnas: 0
# n: ৊,Numero: 24,Fila: 2,Columnas: 1
# n: ৯,Numero: 24,Fila: 2,Columnas: 2
# n: ਔ,Numero: 24,Fila: 2,Columnas: 3
# n: ਹ,Numero: 24,Fila: 2,Columnas: 4
# n: ਫ਼,Numero: 24,Fila: 2,Columnas: 5
# n: ઃ,Numero: 24,Fila: 3,Columnas: 0
# n: ન,Numero: 24,Fila: 3,Columnas: 1
# n: ્,Numero: 24,Fila: 3,Columnas: 2
# n: ૲,Numero: 24,Fila: 3,Columnas: 3
# n: ଗ,Numero: 24,Fila: 3,Columnas: 4
# n: ଼,Numero: 24,Fila: 3,Columnas: 5
# n: ୡ,Numero: 24,Fila: 4,Columnas: 0
# n: ஆ,Numero: 24,Fila: 4,Columnas: 1
# n: ஫,Numero: 24,Fila: 4,Columnas: 2
# n: ௐ,Numero: 24,Fila: 4,Columnas: 3
# n: ௵,Numero: 24,Fila: 4,Columnas: 4
# n: చ,Numero: 24,Fila: 4,Columnas: 5
# n: ి,Numero: 24,Fila: 5,Columnas: 0
# n: ౤,Numero: 24,Fila: 5,Columnas: 1
# n: ಉ,Numero: 24,Fila: 5,Columnas: 2
# n: ಮ,Numero: 24,Fila: 5,Columnas: 3
# n: ೓,Numero: 24,Fila: 5,Columnas: 4
# n: ೸,Numero: 24,Fila: 5,Columnas: 5
# n: ߪ,Numero: 25,Fila: 0,Columnas: 0
# n: ࠏ,Numero: 25,Fila: 0,Columnas: 1
# n: ࠴,Numero: 25,Fila: 0,Columnas: 2
# n: ࡙,Numero: 25,Fila: 0,Columnas: 3
# n: ࡾ,Numero: 25,Fila: 0,Columnas: 4
# n: ࢣ,Numero: 25,Fila: 0,Columnas: 5
# n: ࣈ,Numero: 25,Fila: 1,Columnas: 0
# n: ࣭,Numero: 25,Fila: 1,Columnas: 1
# n: ऒ,Numero: 25,Fila: 1,Columnas: 2
# n: ष,Numero: 25,Fila: 1,Columnas: 3
# n: ड़,Numero: 25,Fila: 1,Columnas: 4
# n: ঁ,Numero: 25,Fila: 1,Columnas: 5
# n: দ,Numero: 25,Fila: 2,Columnas: 0
# n: ো,Numero: 25,Fila: 2,Columnas: 1
# n: ৰ,Numero: 25,Fila: 2,Columnas: 2
# n: ਕ,Numero: 25,Fila: 2,Columnas: 3
# n: ਺,Numero: 25,Fila: 2,Columnas: 4
# n: ੟,Numero: 25,Fila: 2,Columnas: 5
# n: ઄,Numero: 25,Fila: 3,Columnas: 0
# n: ઩,Numero: 25,Fila: 3,Columnas: 1
# n: ૎,Numero: 25,Fila: 3,Columnas: 2
# n: ૳,Numero: 25,Fila: 3,Columnas: 3
# n: ଘ,Numero: 25,Fila: 3,Columnas: 4
# n: ଽ,Numero: 25,Fila: 3,Columnas: 5
# n: ୢ,Numero: 25,Fila: 4,Columnas: 0
# n: இ,Numero: 25,Fila: 4,Columnas: 1
# n: ஬,Numero: 25,Fila: 4,Columnas: 2
# n: ௑,Numero: 25,Fila: 4,Columnas: 3
# n: ௶,Numero: 25,Fila: 4,Columnas: 4
# n: ఛ,Numero: 25,Fila: 4,Columnas: 5
# n: ీ,Numero: 25,Fila: 5,Columnas: 0
# n: ౥,Numero: 25,Fila: 5,Columnas: 1
# n: ಊ,Numero: 25,Fila: 5,Columnas: 2
# n: ಯ,Numero: 25,Fila: 5,Columnas: 3
# n: ೔,Numero: 25,Fila: 5,Columnas: 4
# n: ೹,Numero: 25,Fila: 5,Columnas: 5
# n: ߫,Numero: 26,Fila: 0,Columnas: 0
# n: ࠐ,Numero: 26,Fila: 0,Columnas: 1
# n: ࠵,Numero: 26,Fila: 0,Columnas: 2
# n: ࡚,Numero: 26,Fila: 0,Columnas: 3
# n: ࡿ,Numero: 26,Fila: 0,Columnas: 4
# n: ࢤ,Numero: 26,Fila: 0,Columnas: 5
# n: ࣉ,Numero: 26,Fila: 1,Columnas: 0
# n: ࣮,Numero: 26,Fila: 1,Columnas: 1
# n: ओ,Numero: 26,Fila: 1,Columnas: 2
# n: स,Numero: 26,Fila: 1,Columnas: 3
# n: ढ़,Numero: 26,Fila: 1,Columnas: 4
# n: ং,Numero: 26,Fila: 1,Columnas: 5
# n: ধ,Numero: 26,Fila: 2,Columnas: 0
# n: ৌ,Numero: 26,Fila: 2,Columnas: 1
# n: ৱ,Numero: 26,Fila: 2,Columnas: 2
# n: ਖ,Numero: 26,Fila: 2,Columnas: 3
# n: ਻,Numero: 26,Fila: 2,Columnas: 4
# n: ੠,Numero: 26,Fila: 2,Columnas: 5
# n: અ,Numero: 26,Fila: 3,Columnas: 0
# n: પ,Numero: 26,Fila: 3,Columnas: 1
# n: ૏,Numero: 26,Fila: 3,Columnas: 2
# n: ૴,Numero: 26,Fila: 3,Columnas: 3
# n: ଙ,Numero: 26,Fila: 3,Columnas: 4
# n: ା,Numero: 26,Fila: 3,Columnas: 5
# n: ୣ,Numero: 26,Fila: 4,Columnas: 0
# n: ஈ,Numero: 26,Fila: 4,Columnas: 1
# n: ஭,Numero: 26,Fila: 4,Columnas: 2
# n: ௒,Numero: 26,Fila: 4,Columnas: 3
# n: ௷,Numero: 26,Fila: 4,Columnas: 4
# n: జ,Numero: 26,Fila: 4,Columnas: 5
# n: ు,Numero: 26,Fila: 5,Columnas: 0
# n: ౦,Numero: 26,Fila: 5,Columnas: 1
# n: ಋ,Numero: 26,Fila: 5,Columnas: 2
# n: ರ,Numero: 26,Fila: 5,Columnas: 3
# n: ೕ,Numero: 26,Fila: 5,Columnas: 4
# n: ೺,Numero: 26,Fila: 5,Columnas: 5
# n: ߬,Numero: 27,Fila: 0,Columnas: 0
# n: ࠑ,Numero: 27,Fila: 0,Columnas: 1
# n: ࠶,Numero: 27,Fila: 0,Columnas: 2
# n: ࡛,Numero: 27,Fila: 0,Columnas: 3
# n: ࢀ,Numero: 27,Fila: 0,Columnas: 4
# n: ࢥ,Numero: 27,Fila: 0,Columnas: 5
# n: ࣊,Numero: 27,Fila: 1,Columnas: 0
# n: ࣯,Numero: 27,Fila: 1,Columnas: 1
# n: औ,Numero: 27,Fila: 1,Columnas: 2
# n: ह,Numero: 27,Fila: 1,Columnas: 3
# n: फ़,Numero: 27,Fila: 1,Columnas: 4
# n: ঃ,Numero: 27,Fila: 1,Columnas: 5
# n: ন,Numero: 27,Fila: 2,Columnas: 0
# n: ্,Numero: 27,Fila: 2,Columnas: 1
# n: ৲,Numero: 27,Fila: 2,Columnas: 2
# n: ਗ,Numero: 27,Fila: 2,Columnas: 3
# n: ਼,Numero: 27,Fila: 2,Columnas: 4
# n: ੡,Numero: 27,Fila: 2,Columnas: 5
# n: આ,Numero: 27,Fila: 3,Columnas: 0
# n: ફ,Numero: 27,Fila: 3,Columnas: 1
# n: ૐ,Numero: 27,Fila: 3,Columnas: 2
# n: ૵,Numero: 27,Fila: 3,Columnas: 3
# n: ଚ,Numero: 27,Fila: 3,Columnas: 4
# n: ି,Numero: 27,Fila: 3,Columnas: 5
# n: ୤,Numero: 27,Fila: 4,Columnas: 0
# n: உ,Numero: 27,Fila: 4,Columnas: 1
# n: ம,Numero: 27,Fila: 4,Columnas: 2
# n: ௓,Numero: 27,Fila: 4,Columnas: 3
# n: ௸,Numero: 27,Fila: 4,Columnas: 4
# n: ఝ,Numero: 27,Fila: 4,Columnas: 5
# n: ూ,Numero: 27,Fila: 5,Columnas: 0
# n: ౧,Numero: 27,Fila: 5,Columnas: 1
# n: ಌ,Numero: 27,Fila: 5,Columnas: 2
# n: ಱ,Numero: 27,Fila: 5,Columnas: 3
# n: ೖ,Numero: 27,Fila: 5,Columnas: 4
# n: ೻,Numero: 27,Fila: 5,Columnas: 5
# n: ߭,Numero: 28,Fila: 0,Columnas: 0
# n: ࠒ,Numero: 28,Fila: 0,Columnas: 1
# n: ࠷,Numero: 28,Fila: 0,Columnas: 2
# n: ࡜,Numero: 28,Fila: 0,Columnas: 3
# n: ࢁ,Numero: 28,Fila: 0,Columnas: 4
# n: ࢦ,Numero: 28,Fila: 0,Columnas: 5
# n: ࣋,Numero: 28,Fila: 1,Columnas: 0
# n: ࣰ,Numero: 28,Fila: 1,Columnas: 1
# n: क,Numero: 28,Fila: 1,Columnas: 2
# n: ऺ,Numero: 28,Fila: 1,Columnas: 3
# n: य़,Numero: 28,Fila: 1,Columnas: 4
# n: ঄,Numero: 28,Fila: 1,Columnas: 5
# n: ঩,Numero: 28,Fila: 2,Columnas: 0
# n: ৎ,Numero: 28,Fila: 2,Columnas: 1
# n: ৳,Numero: 28,Fila: 2,Columnas: 2
# n: ਘ,Numero: 28,Fila: 2,Columnas: 3
# n: ਽,Numero: 28,Fila: 2,Columnas: 4
# n: ੢,Numero: 28,Fila: 2,Columnas: 5
# n: ઇ,Numero: 28,Fila: 3,Columnas: 0
# n: બ,Numero: 28,Fila: 3,Columnas: 1
# n: ૑,Numero: 28,Fila: 3,Columnas: 2
# n: ૶,Numero: 28,Fila: 3,Columnas: 3
# n: ଛ,Numero: 28,Fila: 3,Columnas: 4
# n: ୀ,Numero: 28,Fila: 3,Columnas: 5
# n: ୥,Numero: 28,Fila: 4,Columnas: 0
# n: ஊ,Numero: 28,Fila: 4,Columnas: 1
# n: ய,Numero: 28,Fila: 4,Columnas: 2
# n: ௔,Numero: 28,Fila: 4,Columnas: 3
# n: ௹,Numero: 28,Fila: 4,Columnas: 4
# n: ఞ,Numero: 28,Fila: 4,Columnas: 5
# n: ృ,Numero: 28,Fila: 5,Columnas: 0
# n: ౨,Numero: 28,Fila: 5,Columnas: 1
# n: ಍,Numero: 28,Fila: 5,Columnas: 2
# n: ಲ,Numero: 28,Fila: 5,Columnas: 3
# n: ೗,Numero: 28,Fila: 5,Columnas: 4
# n: ೼,Numero: 28,Fila: 5,Columnas: 5
# n: ߮,Numero: 29,Fila: 0,Columnas: 0
# n: ࠓ,Numero: 29,Fila: 0,Columnas: 1
# n: ࠸,Numero: 29,Fila: 0,Columnas: 2
# n: ࡝,Numero: 29,Fila: 0,Columnas: 3
# n: ࢂ,Numero: 29,Fila: 0,Columnas: 4
# n: ࢧ,Numero: 29,Fila: 0,Columnas: 5
# n: ࣌,Numero: 29,Fila: 1,Columnas: 0
# n: ࣱ,Numero: 29,Fila: 1,Columnas: 1
# n: ख,Numero: 29,Fila: 1,Columnas: 2
# n: ऻ,Numero: 29,Fila: 1,Columnas: 3
# n: ॠ,Numero: 29,Fila: 1,Columnas: 4
# n: অ,Numero: 29,Fila: 1,Columnas: 5
# n: প,Numero: 29,Fila: 2,Columnas: 0
# n: ৏,Numero: 29,Fila: 2,Columnas: 1
# n: ৴,Numero: 29,Fila: 2,Columnas: 2
# n: ਙ,Numero: 29,Fila: 2,Columnas: 3
# n: ਾ,Numero: 29,Fila: 2,Columnas: 4
# n: ੣,Numero: 29,Fila: 2,Columnas: 5
# n: ઈ,Numero: 29,Fila: 3,Columnas: 0
# n: ભ,Numero: 29,Fila: 3,Columnas: 1
# n: ૒,Numero: 29,Fila: 3,Columnas: 2
# n: ૷,Numero: 29,Fila: 3,Columnas: 3
# n: ଜ,Numero: 29,Fila: 3,Columnas: 4
# n: ୁ,Numero: 29,Fila: 3,Columnas: 5
# n: ୦,Numero: 29,Fila: 4,Columnas: 0
# n: ஋,Numero: 29,Fila: 4,Columnas: 1
# n: ர,Numero: 29,Fila: 4,Columnas: 2
# n: ௕,Numero: 29,Fila: 4,Columnas: 3
# n: ௺,Numero: 29,Fila: 4,Columnas: 4
# n: ట,Numero: 29,Fila: 4,Columnas: 5
# n: ౄ,Numero: 29,Fila: 5,Columnas: 0
# n: ౩,Numero: 29,Fila: 5,Columnas: 1
# n: ಎ,Numero: 29,Fila: 5,Columnas: 2
# n: ಳ,Numero: 29,Fila: 5,Columnas: 3
# n: ೘,Numero: 29,Fila: 5,Columnas: 4
# n: ೽,Numero: 29,Fila: 5,Columnas: 5
# n: ߯,Numero: 30,Fila: 0,Columnas: 0
# n: ࠔ,Numero: 30,Fila: 0,Columnas: 1
# n: ࠹,Numero: 30,Fila: 0,Columnas: 2
# n: ࡞,Numero: 30,Fila: 0,Columnas: 3
# n: ࢃ,Numero: 30,Fila: 0,Columnas: 4
# n: ࢨ,Numero: 30,Fila: 0,Columnas: 5
# n: ࣍,Numero: 30,Fila: 1,Columnas: 0
# n: ࣲ,Numero: 30,Fila: 1,Columnas: 1
# n: ग,Numero: 30,Fila: 1,Columnas: 2
# n: ़,Numero: 30,Fila: 1,Columnas: 3
# n: ॡ,Numero: 30,Fila: 1,Columnas: 4
# n: আ,Numero: 30,Fila: 1,Columnas: 5
# n: ফ,Numero: 30,Fila: 2,Columnas: 0
# n: ৐,Numero: 30,Fila: 2,Columnas: 1
# n: ৵,Numero: 30,Fila: 2,Columnas: 2
# n: ਚ,Numero: 30,Fila: 2,Columnas: 3
# n: ਿ,Numero: 30,Fila: 2,Columnas: 4
# n: ੤,Numero: 30,Fila: 2,Columnas: 5
# n: ઉ,Numero: 30,Fila: 3,Columnas: 0
# n: મ,Numero: 30,Fila: 3,Columnas: 1
# n: ૓,Numero: 30,Fila: 3,Columnas: 2
# n: ૸,Numero: 30,Fila: 3,Columnas: 3
# n: ଝ,Numero: 30,Fila: 3,Columnas: 4
# n: ୂ,Numero: 30,Fila: 3,Columnas: 5
# n: ୧,Numero: 30,Fila: 4,Columnas: 0
# n: ஌,Numero: 30,Fila: 4,Columnas: 1
# n: ற,Numero: 30,Fila: 4,Columnas: 2
# n: ௖,Numero: 30,Fila: 4,Columnas: 3
# n: ௻,Numero: 30,Fila: 4,Columnas: 4
# n: ఠ,Numero: 30,Fila: 4,Columnas: 5
# n: ౅,Numero: 30,Fila: 5,Columnas: 0
# n: ౪,Numero: 30,Fila: 5,Columnas: 1
# n: ಏ,Numero: 30,Fila: 5,Columnas: 2
# n: ಴,Numero: 30,Fila: 5,Columnas: 3
# n: ೙,Numero: 30,Fila: 5,Columnas: 4
# n: ೾,Numero: 30,Fila: 5,Columnas: 5
# n: ߰,Numero: 31,Fila: 0,Columnas: 0
# n: ࠕ,Numero: 31,Fila: 0,Columnas: 1
# n: ࠺,Numero: 31,Fila: 0,Columnas: 2
# n: ࡟,Numero: 31,Fila: 0,Columnas: 3
# n: ࢄ,Numero: 31,Fila: 0,Columnas: 4
# n: ࢩ,Numero: 31,Fila: 0,Columnas: 5
# n: ࣎,Numero: 31,Fila: 1,Columnas: 0
# n: ࣳ,Numero: 31,Fila: 1,Columnas: 1
# n: घ,Numero: 31,Fila: 1,Columnas: 2
# n: ऽ,Numero: 31,Fila: 1,Columnas: 3
# n: ॢ,Numero: 31,Fila: 1,Columnas: 4
# n: ই,Numero: 31,Fila: 1,Columnas: 5
# n: ব,Numero: 31,Fila: 2,Columnas: 0
# n: ৑,Numero: 31,Fila: 2,Columnas: 1
# n: ৶,Numero: 31,Fila: 2,Columnas: 2
# n: ਛ,Numero: 31,Fila: 2,Columnas: 3
# n: ੀ,Numero: 31,Fila: 2,Columnas: 4
# n: ੥,Numero: 31,Fila: 2,Columnas: 5
# n: ઊ,Numero: 31,Fila: 3,Columnas: 0
# n: ય,Numero: 31,Fila: 3,Columnas: 1
# n: ૔,Numero: 31,Fila: 3,Columnas: 2
# n: ૹ,Numero: 31,Fila: 3,Columnas: 3
# n: ଞ,Numero: 31,Fila: 3,Columnas: 4
# n: ୃ,Numero: 31,Fila: 3,Columnas: 5
# n: ୨,Numero: 31,Fila: 4,Columnas: 0
# n: ஍,Numero: 31,Fila: 4,Columnas: 1
# n: ல,Numero: 31,Fila: 4,Columnas: 2
# n: ௗ,Numero: 31,Fila: 4,Columnas: 3
# n: ௼,Numero: 31,Fila: 4,Columnas: 4
# n: డ,Numero: 31,Fila: 4,Columnas: 5
# n: ె,Numero: 31,Fila: 5,Columnas: 0
# n: ౫,Numero: 31,Fila: 5,Columnas: 1
# n: ಐ,Numero: 31,Fila: 5,Columnas: 2
# n: ವ,Numero: 31,Fila: 5,Columnas: 3
# n: ೚,Numero: 31,Fila: 5,Columnas: 4
# n: ೿,Numero: 31,Fila: 5,Columnas: 5
# n: ߱,Numero: 32,Fila: 0,Columnas: 0
# n: ࠖ,Numero: 32,Fila: 0,Columnas: 1
# n: ࠻,Numero: 32,Fila: 0,Columnas: 2
# n: ࡠ,Numero: 32,Fila: 0,Columnas: 3
# n: ࢅ,Numero: 32,Fila: 0,Columnas: 4
# n: ࢪ,Numero: 32,Fila: 0,Columnas: 5
# n: ࣏,Numero: 32,Fila: 1,Columnas: 0
# n: ࣴ,Numero: 32,Fila: 1,Columnas: 1
# n: ङ,Numero: 32,Fila: 1,Columnas: 2
# n: ा,Numero: 32,Fila: 1,Columnas: 3
# n: ॣ,Numero: 32,Fila: 1,Columnas: 4
# n: ঈ,Numero: 32,Fila: 1,Columnas: 5
# n: ভ,Numero: 32,Fila: 2,Columnas: 0
# n: ৒,Numero: 32,Fila: 2,Columnas: 1
# n: ৷,Numero: 32,Fila: 2,Columnas: 2
# n: ਜ,Numero: 32,Fila: 2,Columnas: 3
# n: ੁ,Numero: 32,Fila: 2,Columnas: 4
# n: ੦,Numero: 32,Fila: 2,Columnas: 5
# n: ઋ,Numero: 32,Fila: 3,Columnas: 0
# n: ર,Numero: 32,Fila: 3,Columnas: 1
# n: ૕,Numero: 32,Fila: 3,Columnas: 2
# n: ૺ,Numero: 32,Fila: 3,Columnas: 3
# n: ଟ,Numero: 32,Fila: 3,Columnas: 4
# n: ୄ,Numero: 32,Fila: 3,Columnas: 5
# n: ୩,Numero: 32,Fila: 4,Columnas: 0
# n: எ,Numero: 32,Fila: 4,Columnas: 1
# n: ள,Numero: 32,Fila: 4,Columnas: 2
# n: ௘,Numero: 32,Fila: 4,Columnas: 3
# n: ௽,Numero: 32,Fila: 4,Columnas: 4
# n: ఢ,Numero: 32,Fila: 4,Columnas: 5
# n: ే,Numero: 32,Fila: 5,Columnas: 0
# n: ౬,Numero: 32,Fila: 5,Columnas: 1
# n: ಑,Numero: 32,Fila: 5,Columnas: 2
# n: ಶ,Numero: 32,Fila: 5,Columnas: 3
# n: ೛,Numero: 32,Fila: 5,Columnas: 4
# n: ഀ,Numero: 32,Fila: 5,Columnas: 5
# n: ߲,Numero: 33,Fila: 0,Columnas: 0
# n: ࠗ,Numero: 33,Fila: 0,Columnas: 1
# n: ࠼,Numero: 33,Fila: 0,Columnas: 2
# n: ࡡ,Numero: 33,Fila: 0,Columnas: 3
# n: ࢆ,Numero: 33,Fila: 0,Columnas: 4
# n: ࢫ,Numero: 33,Fila: 0,Columnas: 5
# n: ࣐,Numero: 33,Fila: 1,Columnas: 0
# n: ࣵ,Numero: 33,Fila: 1,Columnas: 1
# n: च,Numero: 33,Fila: 1,Columnas: 2
# n: ि,Numero: 33,Fila: 1,Columnas: 3
# n: ।,Numero: 33,Fila: 1,Columnas: 4
# n: উ,Numero: 33,Fila: 1,Columnas: 5
# n: ম,Numero: 33,Fila: 2,Columnas: 0
# n: ৓,Numero: 33,Fila: 2,Columnas: 1
# n: ৸,Numero: 33,Fila: 2,Columnas: 2
# n: ਝ,Numero: 33,Fila: 2,Columnas: 3
# n: ੂ,Numero: 33,Fila: 2,Columnas: 4
# n: ੧,Numero: 33,Fila: 2,Columnas: 5
# n: ઌ,Numero: 33,Fila: 3,Columnas: 0
# n: ઱,Numero: 33,Fila: 3,Columnas: 1
# n: ૖,Numero: 33,Fila: 3,Columnas: 2
# n: ૻ,Numero: 33,Fila: 3,Columnas: 3
# n: ଠ,Numero: 33,Fila: 3,Columnas: 4
# n: ୅,Numero: 33,Fila: 3,Columnas: 5
# n: ୪,Numero: 33,Fila: 4,Columnas: 0
# n: ஏ,Numero: 33,Fila: 4,Columnas: 1
# n: ழ,Numero: 33,Fila: 4,Columnas: 2
# n: ௙,Numero: 33,Fila: 4,Columnas: 3
# n: ௾,Numero: 33,Fila: 4,Columnas: 4
# n: ణ,Numero: 33,Fila: 4,Columnas: 5
# n: ై,Numero: 33,Fila: 5,Columnas: 0
# n: ౭,Numero: 33,Fila: 5,Columnas: 1
# n: ಒ,Numero: 33,Fila: 5,Columnas: 2
# n: ಷ,Numero: 33,Fila: 5,Columnas: 3
# n: ೜,Numero: 33,Fila: 5,Columnas: 4
# n: ഁ,Numero: 33,Fila: 5,Columnas: 5
# n: ߳,Numero: 34,Fila: 0,Columnas: 0
# n: ࠘,Numero: 34,Fila: 0,Columnas: 1
# n: ࠽,Numero: 34,Fila: 0,Columnas: 2
# n: ࡢ,Numero: 34,Fila: 0,Columnas: 3
# n: ࢇ,Numero: 34,Fila: 0,Columnas: 4
# n: ࢬ,Numero: 34,Fila: 0,Columnas: 5
# n: ࣑,Numero: 34,Fila: 1,Columnas: 0
# n: ࣶ,Numero: 34,Fila: 1,Columnas: 1
# n: छ,Numero: 34,Fila: 1,Columnas: 2
# n: ी,Numero: 34,Fila: 1,Columnas: 3
# n: ॥,Numero: 34,Fila: 1,Columnas: 4
# n: ঊ,Numero: 34,Fila: 1,Columnas: 5
# n: য,Numero: 34,Fila: 2,Columnas: 0
# n: ৔,Numero: 34,Fila: 2,Columnas: 1
# n: ৹,Numero: 34,Fila: 2,Columnas: 2
# n: ਞ,Numero: 34,Fila: 2,Columnas: 3
# n: ੃,Numero: 34,Fila: 2,Columnas: 4
# n: ੨,Numero: 34,Fila: 2,Columnas: 5
# n: ઍ,Numero: 34,Fila: 3,Columnas: 0
# n: લ,Numero: 34,Fila: 3,Columnas: 1
# n: ૗,Numero: 34,Fila: 3,Columnas: 2
# n: ૼ,Numero: 34,Fila: 3,Columnas: 3
# n: ଡ,Numero: 34,Fila: 3,Columnas: 4
# n: ୆,Numero: 34,Fila: 3,Columnas: 5
# n: ୫,Numero: 34,Fila: 4,Columnas: 0
# n: ஐ,Numero: 34,Fila: 4,Columnas: 1
# n: வ,Numero: 34,Fila: 4,Columnas: 2
# n: ௚,Numero: 34,Fila: 4,Columnas: 3
# n: ௿,Numero: 34,Fila: 4,Columnas: 4
# n: త,Numero: 34,Fila: 4,Columnas: 5
# n: ౉,Numero: 34,Fila: 5,Columnas: 0
# n: ౮,Numero: 34,Fila: 5,Columnas: 1
# n: ಓ,Numero: 34,Fila: 5,Columnas: 2
# n: ಸ,Numero: 34,Fila: 5,Columnas: 3
# n: ೝ,Numero: 34,Fila: 5,Columnas: 4
# n: ം,Numero: 34,Fila: 5,Columnas: 5
# n: ߴ,Numero: 35,Fila: 0,Columnas: 0
# n: ࠙,Numero: 35,Fila: 0,Columnas: 1
# n: ࠾,Numero: 35,Fila: 0,Columnas: 2
# n: ࡣ,Numero: 35,Fila: 0,Columnas: 3
# n: ࢈,Numero: 35,Fila: 0,Columnas: 4
# n: ࢭ,Numero: 35,Fila: 0,Columnas: 5
# n: ࣒,Numero: 35,Fila: 1,Columnas: 0
# n: ࣷ,Numero: 35,Fila: 1,Columnas: 1
# n: ज,Numero: 35,Fila: 1,Columnas: 2
# n: ु,Numero: 35,Fila: 1,Columnas: 3
# n: ०,Numero: 35,Fila: 1,Columnas: 4
# n: ঋ,Numero: 35,Fila: 1,Columnas: 5
# n: র,Numero: 35,Fila: 2,Columnas: 0
# n: ৕,Numero: 35,Fila: 2,Columnas: 1
# n: ৺,Numero: 35,Fila: 2,Columnas: 2
# n: ਟ,Numero: 35,Fila: 2,Columnas: 3
# n: ੄,Numero: 35,Fila: 2,Columnas: 4
# n: ੩,Numero: 35,Fila: 2,Columnas: 5
# n: ઎,Numero: 35,Fila: 3,Columnas: 0
# n: ળ,Numero: 35,Fila: 3,Columnas: 1
# n: ૘,Numero: 35,Fila: 3,Columnas: 2
# n: ૽,Numero: 35,Fila: 3,Columnas: 3
# n: ଢ,Numero: 35,Fila: 3,Columnas: 4
# n: େ,Numero: 35,Fila: 3,Columnas: 5
# n: ୬,Numero: 35,Fila: 4,Columnas: 0
# n: ஑,Numero: 35,Fila: 4,Columnas: 1
# n: ஶ,Numero: 35,Fila: 4,Columnas: 2
# n: ௛,Numero: 35,Fila: 4,Columnas: 3
# n: ఀ,Numero: 35,Fila: 4,Columnas: 4
# n: థ,Numero: 35,Fila: 4,Columnas: 5
# n: ొ,Numero: 35,Fila: 5,Columnas: 0
# n: ౯,Numero: 35,Fila: 5,Columnas: 1
# n: ಔ,Numero: 35,Fila: 5,Columnas: 2
# n: ಹ,Numero: 35,Fila: 5,Columnas: 3
# n: ೞ,Numero: 35,Fila: 5,Columnas: 4
# n: ഃ,Numero: 35,Fila: 5,Columnas: 5
# n: ߵ,Numero: 36,Fila: 0,Columnas: 0
# n: ࠚ,Numero: 36,Fila: 0,Columnas: 1
# n: ࠿,Numero: 36,Fila: 0,Columnas: 2
# n: ࡤ,Numero: 36,Fila: 0,Columnas: 3
# n: ࢉ,Numero: 36,Fila: 0,Columnas: 4
# n: ࢮ,Numero: 36,Fila: 0,Columnas: 5
# n: ࣓,Numero: 36,Fila: 1,Columnas: 0
# n: ࣸ,Numero: 36,Fila: 1,Columnas: 1
# n: झ,Numero: 36,Fila: 1,Columnas: 2
# n: ू,Numero: 36,Fila: 1,Columnas: 3
# n: १,Numero: 36,Fila: 1,Columnas: 4
# n: ঌ,Numero: 36,Fila: 1,Columnas: 5
# n: ঱,Numero: 36,Fila: 2,Columnas: 0
# n: ৖,Numero: 36,Fila: 2,Columnas: 1
# n: ৻,Numero: 36,Fila: 2,Columnas: 2
# n: ਠ,Numero: 36,Fila: 2,Columnas: 3
# n: ੅,Numero: 36,Fila: 2,Columnas: 4
# n: ੪,Numero: 36,Fila: 2,Columnas: 5
# n: એ,Numero: 36,Fila: 3,Columnas: 0
# n: ઴,Numero: 36,Fila: 3,Columnas: 1
# n: ૙,Numero: 36,Fila: 3,Columnas: 2
# n: ૾,Numero: 36,Fila: 3,Columnas: 3
# n: ଣ,Numero: 36,Fila: 3,Columnas: 4
# n: ୈ,Numero: 36,Fila: 3,Columnas: 5
# n: ୭,Numero: 36,Fila: 4,Columnas: 0
# n: ஒ,Numero: 36,Fila: 4,Columnas: 1
# n: ஷ,Numero: 36,Fila: 4,Columnas: 2
# n: ௜,Numero: 36,Fila: 4,Columnas: 3
# n: ఁ,Numero: 36,Fila: 4,Columnas: 4
# n: ద,Numero: 36,Fila: 4,Columnas: 5
# n: ో,Numero: 36,Fila: 5,Columnas: 0
# n: ౰,Numero: 36,Fila: 5,Columnas: 1
# n: ಕ,Numero: 36,Fila: 5,Columnas: 2
# n: ಺,Numero: 36,Fila: 5,Columnas: 3
# n: ೟,Numero: 36,Fila: 5,Columnas: 4
# n: ഄ,Numero: 36,Fila: 5,Columnas: 5

# %% [markdown]
# ## Restricciones del problema
#
# #### Reglas:
#
# 1. La primera piedra en ser colocada en el tablero, debe ser una piedra negra, no hay restricción en cual intersección puede ser colocada.
#
# 2. No puede haber más de una piedra en cada intersección, sin importar el color que está.
#
# 3. Se gana con cinco piedras del mismo color seguidas en línea vertical, horizontal o diagonal.
#
# 4. Si hay una piedra en una posición del tablero, esta se queda ahí para todos los turnos siguientes.
#
# 5. (Por evaluar) Se coloca una piedra a la vez en cada ronda.

# %%
letrasProposicionalesNegras = [chr(x) for x in range(256, 1744)]
letrasProposicionalesBlancas = [chr(x) for x in range(2001,3745)]

letrasProposicionales = letrasProposicionalesNegras + letrasProposicionalesBlancas
conectivos = ["Y", "O", ">", "="]

# %%
class Tree(object):
    def __init__(self, label, left, right):
        self.left = left
        self.right = right
        self.label = label
        
def String2Tree(A):
    # Crea una formula como tree dada una formula como cadena escrita en notacion polaca inversa
    # Input: - A, lista de caracteres con una formula escrita en notacion polaca inversa
    #        - letrasProposicionales, lista de letras proposicionales
    #        - conectivos, lista de conectivos
    # Output: formula como tree
    pila = []
    for c in A:
        # print("Examinando " + str(c))
        if c in letrasProposicionales:
            # print(u"El símbolo es letra proposicional")
            pila.append(Tree(c, None, None))
        elif c == '-':
            # print("Negamos")
            formulaAux = Tree(c, None, pila[-1])
            del pila[-1]
            pila.append(formulaAux)
        elif c in conectivos:
        # print("Unimos mediante conectivo")
            formulaAux = Tree(c, pila[-1], pila[-2])
            del pila[-1]
            del pila[-1]
            pila.append(formulaAux)
        else:
            print(u"Hay un problema: el símbolo " + str(c) + " no se reconoce")
    return pila[-1]

def Inorderp(f):
    # Imprime una formula como cadena dada una formula como arbol
    # de manera que las letras proposicionales sean legibles.
    # Input: tree, que es una formula de logica proposicional
    # Output: string de la formula

    if f.right == None:
        if f.label in letrasProposicionalesNegras:
            f,c,n = cods1.Ninv(f.label)
            return f"N({f},{c},{n})"
        elif f.label in letrasProposicionalesBlancas:
            f,c,n = cods2.Binv(f.label)
            return f"B({f},{c},{n})"
        
    elif f.label == '-':
        return f.label + Inorderp(f.right)
    else:
        return "(" + Inorderp(f.left) + f.label + " " + Inorderp(f.right) + ")"

# %% [markdown]
# ### Pasos para la regla 1:
#
# 1.1 Hay una negra en alguna coordenada ... \begin{align}
# \left( \bigvee_{x = b}^{f} \bigvee_{y = 2}^{6} N(x,y,1) \right)
# \end{align}

# %%
inicial = True
def negras_comienza():
    inicial = True
    Nf = 6
    Nc = 6
    
    for f in range(1, Nf):
        for c in range(1, Nc):
            if inicial:
                formula = cods1.N(f,c,1)
                inicial = False
            else:
                formula = cods1.N(f,c,1) + formula + "O"
    return formula

formula = negras_comienza()
A = String2Tree(formula)
print(Inorderp(A))
# Out:
# ((((((((((((((((((((((((N(1,1,1)O N(1,2,1))O N(1,3,1))O N(1,4,1))O N(1,5,1))O N(2,1,1))O N(2,2,1))O N(2,3,1))O N(2,4,1))O N(2,5,1))O N(3,1,1))O N(3,2,1))O N(3,3,1))O N(3,4,1))O N(3,5,1))O N(4,1,1))O N(4,2,1))O N(4,3,1))O N(4,4,1))O N(4,5,1))O N(5,1,1))O N(5,2,1))O N(5,3,1))O N(5,4,1))O N(5,5,1))

# %% [markdown]
# 1.2 No puede haber una blanca en el primer turno ...
#
# \begin{align}
# \left( \bigwedge_{x = b}^{f} \bigwedge_{y = 2}^{6} \neg B(x,y,1) \right)
# \end{align}

# %%
inicial = True
def no_blancas_comienza():
    inicial = True
    Nf = 6
    Nc = 6
    
    for f in range(1, Nf):
        for c in range(1, Nc):
            if inicial:
                formula = cods2.B(f,c,1) + "-"
                inicial = False
            else:
                formula = cods2.B(f,c,1) + "-" + formula + "Y"
    return formula

formula = no_blancas_comienza()
A = String2Tree(formula)
print(Inorderp(A))
# Out:
# ((((((((((((((((((((((((-B(1,1,1)Y -B(1,2,1))Y -B(1,3,1))Y -B(1,4,1))Y -B(1,5,1))Y -B(2,1,1))Y -B(2,2,1))Y -B(2,3,1))Y -B(2,4,1))Y -B(2,5,1))Y -B(3,1,1))Y -B(3,2,1))Y -B(3,3,1))Y -B(3,4,1))Y -B(3,5,1))Y -B(4,1,1))Y -B(4,2,1))Y -B(4,3,1))Y -B(4,4,1))Y -B(4,5,1))Y -B(5,1,1))Y -B(5,2,1))Y -B(5,3,1))Y -B(5,4,1))Y -B(5,5,1))

# %% [markdown]
# 1.3 Si hay una negra en una coordenada, no puede haber otra negra en otra coordenada...
#
# \begin{align}
# N(x,y,1) \rightarrow \left(\bigwedge_{(u,v) \neq (x,y)} \neg N(u,v,1)\right)
# \end{align}

# %%
inicial = True
def no_dif_negras(x,y):
    inicial = True
    Nf = 6
    Nc = 6
    rango = [(u,v) for u in range(1, cods1.Nf) for v in range(1, cods1.Nc)]
    rango = [casilla for casilla in rango if casilla != (x,y)]
    for (u,v) in rango:
        if inicial:
            formula = cods1.N(u,v,1) + '-'
            inicial = False
        else:
            formula = cods1.N(u,v,1) + '-' + formula + "Y"
    
    formula = formula + cods1.N(x,y,1) + '>'
    return formula

formula = no_dif_negras(0,0)
A = String2Tree(formula)
print(Inorderp(A))
# Out:
# (N(0,0,1)> ((((((((((((((((((((((((-N(1,1,1)Y -N(1,2,1))Y -N(1,3,1))Y -N(1,4,1))Y -N(1,5,1))Y -N(2,1,1))Y -N(2,2,1))Y -N(2,3,1))Y -N(2,4,1))Y -N(2,5,1))Y -N(3,1,1))Y -N(3,2,1))Y -N(3,3,1))Y -N(3,4,1))Y -N(3,5,1))Y -N(4,1,1))Y -N(4,2,1))Y -N(4,3,1))Y -N(4,4,1))Y -N(4,5,1))Y -N(5,1,1))Y -N(5,2,1))Y -N(5,3,1))Y -N(5,4,1))Y -N(5,5,1)))

# %% [markdown]
# 1.4  Para todas las posibilidades del paso 1.3
#
# \begin{align*}
# \left( \bigwedge_{x = b}^{f} \bigwedge_{y = 2}^{6} \left( N(x,y,1) \rightarrow \left(\bigwedge_{(u,v) \neq (x,y)} \neg N(u,v,1)\right) \right) \right)
# \end{align*}

# %%
def no_dif_negras_():
    inicial = True
    for f in range(1, cods1.Nf):
        for c in range(1, cods1.Nc): 
            if inicial:
                formula = no_dif_negras(f,c)
                inicial = False
            else:
                formula = no_dif_negras(f,c) + formula + "Y"
    return formula

# %%
formula = no_dif_negras_()
A = String2Tree(formula)
print(Inorderp(A))
# Out:
# (((((((((((((((((((((((((N(1,1,1)> (((((((((((((((((((((((-N(1,2,1)Y -N(1,3,1))Y -N(1,4,1))Y -N(1,5,1))Y -N(2,1,1))Y -N(2,2,1))Y -N(2,3,1))Y -N(2,4,1))Y -N(2,5,1))Y -N(3,1,1))Y -N(3,2,1))Y -N(3,3,1))Y -N(3,4,1))Y -N(3,5,1))Y -N(4,1,1))Y -N(4,2,1))Y -N(4,3,1))Y -N(4,4,1))Y -N(4,5,1))Y -N(5,1,1))Y -N(5,2,1))Y -N(5,3,1))Y -N(5,4,1))Y -N(5,5,1)))Y (N(1,2,1)> (((((((((((((((((((((((-N(1,1,1)Y -N(1,3,1))Y -N(1,4,1))Y -N(1,5,1))Y -N(2,1,1))Y -N(2,2,1))Y -N(2,3,1))Y -N(2,4,1))Y -N(2,5,1))Y -N(3,1,1))Y -N(3,2,1))Y -N(3,3,1))Y -N(3,4,1))Y -N(3,5,1))Y -N(4,1,1))Y -N(4,2,1))Y -N(4,3,1))Y -N(4,4,1))Y -N(4,5,1))Y -N(5,1,1))Y -N(5,2,1))Y -N(5,3,1))Y -N(5,4,1))Y -N(5,5,1))))Y (N(1,3,1)> (((((((((((((((((((((((-N(1,1,1)Y -N(1,2,1))Y -N(1,4,1))Y -N(1,5,1))Y -N(2,1,1))Y -N(2,2,1))Y -N(2,3,1))Y -N(2,4,1))Y -N(2,5,1))Y -N(3,1,1))Y -N(3,2,1))Y -N(3,3,1))Y -N(3,4,1))Y -N(3,5,1))Y -N(4,1,1))Y -N(4,2,1))Y -N(4,3,1))Y -N(4,4,1))Y -N(4,5,1))Y -N(5,1,1))Y -N(5,2,1))Y -N(5,3,1))Y -N(5,4,1))Y -N(5,5,1))))Y (N(1,4,1)> (((((((((((((((((((((((-N(1,1,1)Y -N(1,2,1))Y -N(1,3,1))Y -N(1,5,1))Y -N(2,1,1))Y -N(2,2,1))Y -N(2,3,1))Y -N(2,4,1))Y -N(2,5,1))Y -N(3,1,1))Y -N(3,2,1))Y -N(3,3,1))Y -N(3,4,1))Y -N(3,5,1))Y -N(4,1,1))Y -N(4,2,1))Y -N(4,3,1))Y -N(4,4,1))Y -N(4,5,1))Y -N(5,1,1))Y -N(5,2,1))Y -N(5,3,1))Y -N(5,4,1))Y -N(5,5,1))))Y (N(1,5,1)> (((((((((((((((((((((((-N(1,1,1)Y -N(1,2,1))Y -N(1,3,1))Y -N(1,4,1))Y -N(2,1,1))Y -N(2,2,1))Y -N(2,3,1))Y -N(2,4,1))Y -N(2,5,1))Y -N(3,1,1))Y -N(3,2,1))Y -N(3,3,1))Y -N(3,4,1))Y -N(3,5,1))Y -N(4,1,1))Y -N(4,2,1))Y -N(4,3,1))Y -N(4,4,1))Y -N(4,5,1))Y -N(5,1,1))Y -N(5,2,1))Y -N(5,3,1))Y -N(5,4,1))Y -N(5,5,1))))Y (N(2,1,1)> (((((((((((((((((((((((-N(1,1,1)Y -N(1,2,1))Y -N(1,3,1))Y -N(1,4,1))Y -N(1,5,1))Y -N(2,2,1))Y -N(2,3,1))Y -N(2,4,1))Y -N(2,5,1))Y -N(3,1,1))Y -N(3,2,1))Y -N(3,3,1))Y -N(3,4,1))Y -N(3,5,1))Y -N(4,1,1))Y -N(4,2,1))Y -N(4,3,1))Y -N(4,4,1))Y -N(4,5,1))Y -N(5,1,1))Y -N(5,2,1))Y -N(5,3,1))Y -N(5,4,1))Y -N(5,5,1))))Y (N(2,2,1)> (((((((((((((((((((((((-N(1,1,1)Y -N(1,2,1))Y -N(1,3,1))Y -N(1,4,1))Y -N(1,5,1))Y -N(2,1,1))Y -N(2,3,1))Y -N(2,4,1))Y -N(2,5,1))Y -N(3,1,1))Y -N(3,2,1))Y -N(3,3,1))Y -N(3,4,1))Y -N(3,5,1))Y -N(4,1,1))Y -N(4,2,1))Y -N(4,3,1))Y -N(4,4,1))Y -N(4,5,1))Y -N(5,1,1))Y -N(5,2,1))Y -N(5,3,1))Y -N(5,4,1))Y -N(5,5,1))))Y (N(2,3,1)> (((((((((((((((((((((((-N(1,1,1)Y -N(1,2,1))Y -N(1,3,1))Y -N(1,4,1))Y -N(1,5,1))Y -N(2,1,1))Y -N(2,2,1))Y -N(2,4,1))Y -N(2,5,1))Y -N(3,1,1))Y -N(3,2,1))Y -N(3,3,1))Y -N(3,4,1))Y -N(3,5,1))Y -N(4,1,1))Y -N(4,2,1))Y -N(4,3,1))Y -N(4,4,1))Y -N(4,5,1))Y -N(5,1,1))Y -N(5,2,1))Y -N(5,3,1))Y -N(5,4,1))Y -N(5,5,1))))Y (N(2,4,1)> (((((((((((((((((((((((-N(1,1,1)Y -N(1,2,1))Y -N(1,3,1))Y -N(1,4,1))Y -N(1,5,1))Y -N(2,1,1))Y -N(2,2,1))Y -N(2,3,1))Y -N(2,5,1))Y -N(3,1,1))Y -N(3,2,1))Y -N(3,3,1))Y -N(3,4,1))Y -N(3,5,1))Y -N(4,1,1))Y -N(4,2,1))Y -N(4,3,1))Y -N(4,4,1))Y -N(4,5,1))Y -N(5,1,1))Y -N(5,2,1))Y -N(5,3,1))Y -N(5,4,1))Y -N(5,5,1))))Y (N(2,5,1)> (((((((((((((((((((((((-N(1,1,1)Y -N(1,2,1))Y -N(1,3,1))Y -N(1,4,1))Y -N(1,5,1))Y -N(2,1,1))Y -N(2,2,1))Y -N(2,3,1))Y -N(2,4,1))Y -N(3,1,1))Y -N(3,2,1))Y -N(3,3,1))Y -N(3,4,1))Y -N(3,5,1))Y -N(4,1,1))Y -N(4,2,1))Y -N(4,3,1))Y -N(4,4,1))Y -N(4,5,1))Y -N(5,1,1))Y -N(5,2,1))Y -N(5,3,1))Y -N(5,4,1))Y -N(5,5,1))))Y (N(3,1,1)> (((((((((((((((((((((((-N(1,1,1)Y -N(1,2,1))Y -N(1,3,1))Y -N(1,4,1))Y -N(1,5,1))Y -N(2,1,1))Y -N(2,2,1))Y -N(2,3,1))Y -N(2,4,1))Y -N(2,5,1))Y -N(3,2,1))Y -N(3,3,1))Y -N(3,4,1))Y -N(3,5,1))Y -N(4,1,1))Y -N(4,2,1))Y -N(4,3,1))Y -N(4,4,1))Y -N(4,5,1))Y -N(5,1,1))Y -N(5,2,1))Y -N(5,3,1))Y -N(5,4,1))Y -N(5,5,1))))Y (N(3,2,1)> (((((((((((((((((((((((-N(1,1,1)Y -N(1,2,1))Y -N(1,3,1))Y -N(1,4,1))Y -N(1,5,1))Y -N(2,1,1))Y -N(2,2,1))Y -N(2,3,1))Y -N(2,4,1))Y -N(2,5,1))Y -N(3,1,1))Y -N(3,3,1))Y -N(3,4,1))Y -N(3,5,1))Y -N(4,1,1))Y -N(4,2,1))Y -N(4,3,1))Y -N(4,4,1))Y -N(4,5,1))Y -N(5,1,1))Y -N(5,2,1))Y -N(5,3,1))Y -N(5,4,1))Y -N(5,5,1))))Y (N(3,3,1)> (((((((((((((((((((((((-N(1,1,1)Y -N(1,2,1))Y -N(1,3,1))Y -N(1,4,1))Y -N(1,5,1))Y -N(2,1,1 ...

# %% [markdown]
# 1.5 Finalmente, uniendo las funciones anteriores, obtenemos la **regla 1**:
#
# \begin{align*}
#     \left( \bigvee_{x = b}^{f} \bigvee_{y = 2}^{6} N(x,y,1) \right) \wedge \left( \bigwedge_{x = b}^{f} \bigwedge_{y = 2}^{6} \neg B(x,y,1) \right)  \wedge \left( \bigwedge_{x = b}^{f} \bigwedge_{y = 2}^{6} \left( N(x,y,1) \rightarrow \left(\bigwedge_{(u,v) \neq (x,y)} \neg N(u,v,1)\right) \right) \right)
# \end{align*}
#
# La primera piedra en ser colocada en el tablero, debe ser una piedra negra, no hay restricción en cual intersección puede ser colocada.

# %%
def regla1():
    formula1 = negras_comienza()
    formula2 = no_blancas_comienza()
    formula3 = no_dif_negras_()
    formula = formula3 + formula2 + 'Y' + formula1 + 'Y'
    return formula

# %%
formula = regla1()
A = String2Tree(formula)
print(Inorderp(A))
# Out:
# (((((((((((((((((((((((((N(1,1,1)O N(1,2,1))O N(1,3,1))O N(1,4,1))O N(1,5,1))O N(2,1,1))O N(2,2,1))O N(2,3,1))O N(2,4,1))O N(2,5,1))O N(3,1,1))O N(3,2,1))O N(3,3,1))O N(3,4,1))O N(3,5,1))O N(4,1,1))O N(4,2,1))O N(4,3,1))O N(4,4,1))O N(4,5,1))O N(5,1,1))O N(5,2,1))O N(5,3,1))O N(5,4,1))O N(5,5,1))Y (((((((((((((((((((((((((-B(1,1,1)Y -B(1,2,1))Y -B(1,3,1))Y -B(1,4,1))Y -B(1,5,1))Y -B(2,1,1))Y -B(2,2,1))Y -B(2,3,1))Y -B(2,4,1))Y -B(2,5,1))Y -B(3,1,1))Y -B(3,2,1))Y -B(3,3,1))Y -B(3,4,1))Y -B(3,5,1))Y -B(4,1,1))Y -B(4,2,1))Y -B(4,3,1))Y -B(4,4,1))Y -B(4,5,1))Y -B(5,1,1))Y -B(5,2,1))Y -B(5,3,1))Y -B(5,4,1))Y -B(5,5,1))Y (((((((((((((((((((((((((N(1,1,1)> (((((((((((((((((((((((-N(1,2,1)Y -N(1,3,1))Y -N(1,4,1))Y -N(1,5,1))Y -N(2,1,1))Y -N(2,2,1))Y -N(2,3,1))Y -N(2,4,1))Y -N(2,5,1))Y -N(3,1,1))Y -N(3,2,1))Y -N(3,3,1))Y -N(3,4,1))Y -N(3,5,1))Y -N(4,1,1))Y -N(4,2,1))Y -N(4,3,1))Y -N(4,4,1))Y -N(4,5,1))Y -N(5,1,1))Y -N(5,2,1))Y -N(5,3,1))Y -N(5,4,1))Y -N(5,5,1)))Y (N(1,2,1)> (((((((((((((((((((((((-N(1,1,1)Y -N(1,3,1))Y -N(1,4,1))Y -N(1,5,1))Y -N(2,1,1))Y -N(2,2,1))Y -N(2,3,1))Y -N(2,4,1))Y -N(2,5,1))Y -N(3,1,1))Y -N(3,2,1))Y -N(3,3,1))Y -N(3,4,1))Y -N(3,5,1))Y -N(4,1,1))Y -N(4,2,1))Y -N(4,3,1))Y -N(4,4,1))Y -N(4,5,1))Y -N(5,1,1))Y -N(5,2,1))Y -N(5,3,1))Y -N(5,4,1))Y -N(5,5,1))))Y (N(1,3,1)> (((((((((((((((((((((((-N(1,1,1)Y -N(1,2,1))Y -N(1,4,1))Y -N(1,5,1))Y -N(2,1,1))Y -N(2,2,1))Y -N(2,3,1))Y -N(2,4,1))Y -N(2,5,1))Y -N(3,1,1))Y -N(3,2,1))Y -N(3,3,1))Y -N(3,4,1))Y -N(3,5,1))Y -N(4,1,1))Y -N(4,2,1))Y -N(4,3,1))Y -N(4,4,1))Y -N(4,5,1))Y -N(5,1,1))Y -N(5,2,1))Y -N(5,3,1))Y -N(5,4,1))Y -N(5,5,1))))Y (N(1,4,1)> (((((((((((((((((((((((-N(1,1,1)Y -N(1,2,1))Y -N(1,3,1))Y -N(1,5,1))Y -N(2,1,1))Y -N(2,2,1))Y -N(2,3,1))Y -N(2,4,1))Y -N(2,5,1))Y -N(3,1,1))Y -N(3,2,1))Y -N(3,3,1))Y -N(3,4,1))Y -N(3,5,1))Y -N(4,1,1))Y -N(4,2,1))Y -N(4,3,1))Y -N(4,4,1))Y -N(4,5,1))Y -N(5,1,1))Y -N(5,2,1))Y -N(5,3,1))Y -N(5,4,1))Y -N(5,5,1))))Y (N(1,5,1)> (((((((((((((((((((((((-N(1,1,1)Y -N(1,2,1))Y -N(1,3,1))Y -N(1,4,1))Y -N(2,1,1))Y -N(2,2,1))Y -N(2,3,1))Y -N(2,4,1))Y -N(2,5,1))Y -N(3,1,1))Y -N(3,2,1))Y -N(3,3,1))Y -N(3,4,1))Y -N(3,5,1))Y -N(4,1,1))Y -N(4,2,1))Y -N(4,3,1))Y -N(4,4,1))Y -N(4,5,1))Y -N(5,1,1))Y -N(5,2,1))Y -N(5,3,1))Y -N(5,4,1))Y -N(5,5,1))))Y (N(2,1,1)> (((((((((((((((((((((((-N(1,1,1)Y -N(1,2,1))Y -N(1,3,1))Y -N(1,4,1))Y -N(1,5,1))Y -N(2,2,1))Y -N(2,3,1))Y -N(2,4,1))Y -N(2,5,1))Y -N(3,1,1))Y -N(3,2,1))Y -N(3,3,1))Y -N(3,4,1))Y -N(3,5,1))Y -N(4,1,1))Y -N(4,2,1))Y -N(4,3,1))Y -N(4,4,1))Y -N(4,5,1))Y -N(5,1,1))Y -N(5,2,1))Y -N(5,3,1))Y -N(5,4,1))Y -N(5,5,1))))Y (N(2,2,1)> (((((((((((((((((((((((-N(1,1,1)Y -N(1,2,1))Y -N(1,3,1))Y -N(1,4,1))Y -N(1,5,1))Y -N(2,1,1))Y -N(2,3,1))Y -N(2,4,1))Y -N(2,5,1))Y -N(3,1,1))Y -N(3,2,1))Y -N(3,3,1))Y -N(3,4,1))Y -N(3,5,1))Y -N(4,1,1))Y -N(4,2,1))Y -N(4,3,1))Y -N(4,4,1))Y -N(4,5,1))Y -N(5,1,1))Y -N(5,2,1))Y -N(5,3,1))Y -N(5,4,1))Y -N(5,5,1))))Y (N(2,3,1)> (((((((((((((((((((((((-N(1,1,1)Y -N(1,2,1))Y -N(1,3,1))Y -N(1,4,1))Y -N(1,5,1))Y -N(2,1,1))Y -N(2,2,1))Y -N(2,4,1))Y -N(2,5,1))Y -N(3,1,1))Y -N(3,2,1))Y -N(3,3,1))Y -N(3,4,1))Y -N(3,5,1))Y -N(4,1,1))Y -N(4,2,1))Y -N(4,3,1))Y -N(4,4,1))Y -N(4,5,1))Y -N(5,1,1))Y -N(5,2,1))Y -N(5,3,1))Y -N(5,4,1))Y -N(5,5,1))))Y (N(2,4,1)> (((((((((((((((((((((((-N(1,1,1)Y -N(1,2,1))Y -N(1,3,1))Y -N(1,4,1))Y -N(1,5,1))Y -N(2,1,1))Y -N(2,2,1))Y -N(2,3,1))Y -N(2,5,1))Y -N(3,1,1))Y -N(3,2,1))Y -N(3,3,1))Y -N(3,4,1))Y -N(3,5,1))Y -N(4,1,1))Y -N(4,2,1))Y -N(4,3,1))Y -N(4,4,1))Y -N(4,5,1))Y -N(5,1,1))Y -N(5,2,1))Y -N(5,3,1))Y -N(5,4,1))Y -N(5,5,1))))Y (N(2,5,1)> (((((((((((((((((((((((-N(1,1,1)Y -N(1,2,1))Y -N(1,3,1))Y -N(1,4,1))Y -N(1,5,1))Y -N(2,1,1))Y -N(2,2,1))Y -N(2,3,1))Y -N(2,4,1))Y -N(3,1,1))Y -N(3,2,1))Y -N(3,3,1))Y -N(3,4,1))Y -N(3,5,1))Y -N(4,1,1))Y -N(4,2,1))Y -N(4,3,1))Y -N(4,4,1))Y -N(4,5,1))Y -N(5,1,1))Y -N(5,2,1))Y -N(5,3,1))Y -N(5,4,1))Y -N(5,5,1))))Y (N(3,1,1)> (((((((((((((((((((((((-N(1,1,1)Y -N(1,2,1))Y -N(1,3,1))Y -N(1,4,1))Y -N(1,5,1))Y -N(2,1,1))Y -N(2,2,1))Y -N(2,3, ...

# %% [markdown]
# ### Pasos para la regla 2:
#
# 2.1 No puede haber una misma piedra en una interseccion escogida.
#
# \begin{align*}
# \left( N(x,y,t) \rightarrow \neg B(x,y,t) \right) \wedge \left( B(x,y,t) \rightarrow \neg N(x,y,t) \right)
# \end{align*}

# %%
def no_piedras_misma_interseccion(x,y,t):
    formula1 = cods2.B(x,y,t) + "-" + cods1.N(x,y,t) + ">"
    formula2 = cods1.N(x,y,t) + "-" + cods2.B(x,y,t) + ">"
    formula = formula2 + formula1 + "Y"
    return formula

formula = no_piedras_misma_interseccion(1,1,2)
A = String2Tree(formula)
print(Inorderp(A))
# Out:
# ((N(1,1,2)> -B(1,1,2))Y (B(1,1,2)> -N(1,1,2)))

# %% [markdown]
# 2.2. Para todas las posibilidades del paso 2.1. Obtenemos la **regla 2**:
#
# \begin{align*}
#   \bigwedge_{t = 1}^{25} \bigwedge_{x = b}^{f} \bigwedge_{y = 2}^{6} \left( N(x,y,t) \rightarrow \neg B(x,y,t) \right) \wedge \left( B(x,y,t) \rightarrow \neg N(x,y,t) \right)
# \end{align*}
#
# No puede haber más de una piedra en cada intersección, sin importar el color que está.

# %%
def regla2():
    inicial = True
    Nf = 6
    Nc = 6
    Nt = 25
    for f in range(1, Nf):
        for c in range(1, Nc): 
            for t in range(1, Nt+1):
                if inicial:
                    formula = no_piedras_misma_interseccion(f,c,t)
                    inicial = False
                else:
                    formula = no_piedras_misma_interseccion(f,c,t) + formula + 'Y'
    return formula

# %%
formula = regla2()
A = String2Tree(formula)
print(Inorderp(A))
# Out:
# ((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((N(1,1,1)> -B(1,1,1))Y (B(1,1,1)> -N(1,1,1)))Y ((N(1,1,2)> -B(1,1,2))Y (B(1,1,2)> -N(1,1,2))))Y ((N(1,1,3)> -B(1,1,3))Y (B(1,1,3)> -N(1,1,3))))Y ((N(1,1,4)> -B(1,1,4))Y (B(1,1,4)> -N(1,1,4))))Y ((N(1,1,5)> -B(1,1,5))Y (B(1,1,5)> -N(1,1,5))))Y ((N(1,1,6)> -B(1,1,6))Y (B(1,1,6)> -N(1,1,6))))Y ((N(1,1,7)> -B(1,1,7))Y (B(1,1,7)> -N(1,1,7))))Y ((N(1,1,8)> -B(1,1,8))Y (B(1,1,8)> -N(1,1,8))))Y ((N(1,1,9)> -B(1,1,9))Y (B(1,1,9)> -N(1,1,9))))Y ((N(1,1,10)> -B(1,1,10))Y (B(1,1,10)> -N(1,1,10))))Y ((N(1,1,11)> -B(1,1,11))Y (B(1,1,11)> -N(1,1,11))))Y ((N(1,1,12)> -B(1,1,12))Y (B(1,1,12)> -N(1,1,12))))Y ((N(1,1,13)> -B(1,1,13))Y (B(1,1,13)> -N(1,1,13))))Y ((N(1,1,14)> -B(1,1,14))Y (B(1,1,14)> -N(1,1,14))))Y ((N(1,1,15)> -B(1,1,15))Y (B(1,1,15)> -N(1,1,15))))Y ((N(1,1,16)> -B(1,1,16))Y (B(1,1,16)> -N(1,1,16))))Y ((N(1,1,17)> -B(1,1,17))Y (B(1,1,17)> -N(1,1,17))))Y ((N(1,1,18)> -B(1,1,18))Y (B(1,1,18)> -N(1,1,18))))Y ((N(1,1,19)> -B(1,1,19))Y (B(1,1,19)> -N(1,1,19))))Y ((N(1,1,20)> -B(1,1,20))Y (B(1,1,20)> -N(1,1,20))))Y ((N(1,1,21)> -B(1,1,21))Y (B(1,1,21)> -N(1,1,21))))Y ((N(1,1,22)> -B(1,1,22))Y (B(1,1,22)> -N(1,1,22))))Y ((N(1,1,23)> -B(1,1,23))Y (B(1,1,23)> -N(1,1,23))))Y ((N(1,1,24)> -B(1,1,24))Y (B(1,1,24)> -N(1,1,24))))Y ((N(1,1,25)> -B(1,1,25))Y (B(1,1,25)> -N(1,1,25))))Y ((N(1,2,1)> -B(1,2,1))Y (B(1,2,1)> -N(1,2,1))))Y ((N(1,2,2)> -B(1,2,2))Y (B(1,2,2)> -N(1,2,2))))Y ((N(1,2,3)> -B(1,2,3))Y (B(1,2,3)> -N(1,2,3))))Y ((N(1,2,4)> -B(1,2,4))Y (B(1,2,4)> -N(1,2,4))))Y ((N(1,2,5)> -B(1,2,5))Y (B(1,2,5)> -N(1,2,5))))Y ((N(1,2,6)> -B(1,2,6))Y (B(1,2,6)> -N(1,2,6))))Y ((N(1,2,7)> -B(1,2,7))Y (B(1,2,7)> -N(1,2,7))))Y ((N(1,2,8)> -B(1,2,8))Y (B(1,2,8)> -N(1,2,8))))Y ((N(1,2,9)> -B(1,2,9))Y (B(1,2,9)> -N(1,2,9))))Y ((N(1,2,10)> -B(1,2,10))Y (B(1,2,10)> -N(1,2,10))))Y ((N(1,2,11)> -B(1,2,11))Y (B(1,2,11)> -N(1,2,11))))Y ((N(1,2,12)> -B(1,2,12))Y (B(1,2,12)> -N(1,2,12))))Y ((N(1,2,13)> -B(1,2,13))Y (B(1,2,13)> -N(1,2,13))))Y ((N(1,2,14)> -B(1,2,14))Y (B(1,2,14)> -N(1,2,14))))Y ((N(1,2,15)> -B(1,2,15))Y (B(1,2,15)> -N(1,2,15))))Y ((N(1,2,16)> -B(1,2,16))Y (B(1,2,16)> -N(1,2,16))))Y ((N(1,2,17)> -B(1,2,17))Y (B(1,2,17)> -N(1,2,17))))Y ((N(1,2,18)> -B(1,2,18))Y (B(1,2,18)> -N(1,2,18))))Y ((N(1,2,19)> -B(1,2,19))Y (B(1,2,19)> -N(1,2,19))))Y ((N(1,2,20)> -B(1,2,20))Y (B(1,2,20)> -N(1,2,20))))Y ((N(1,2,21)> -B(1,2,21))Y (B(1,2,21)> -N(1,2,21))))Y ((N(1,2,22)> -B(1,2,22))Y (B(1,2,22)> -N(1,2,22))))Y ((N(1,2,23)> -B(1,2,23))Y (B(1,2,23)> -N(1,2,23))))Y ((N(1,2,24)> -B(1,2,24))Y (B(1,2,24)> -N(1,2,24))))Y ((N(1,2,25)> -B(1,2,25))Y (B(1,2,25)> -N(1,2,25))))Y ((N(1,3,1)> -B(1,3,1))Y (B(1,3,1)> -N(1,3,1))))Y ((N(1,3,2)> -B(1,3,2))Y (B(1,3,2)> -N(1,3,2))))Y ((N(1,3,3)> -B(1,3,3))Y (B(1,3,3)> -N(1,3,3))))Y ((N(1,3,4)> -B(1,3,4))Y (B(1,3,4)> -N(1,3,4))))Y ((N(1,3,5)> -B(1,3,5))Y (B(1,3,5)> -N(1,3,5))))Y ((N(1,3,6)> -B(1,3,6))Y (B(1,3,6)> -N(1,3,6))))Y ((N(1,3,7)> -B(1,3,7))Y (B(1,3,7)> -N(1,3,7))))Y ((N(1,3,8)> -B(1,3,8))Y (B(1,3,8)> -N(1,3,8))))Y ((N(1,3,9)> -B(1,3,9))Y (B(1,3,9)> -N(1,3,9))))Y ((N(1,3,10)> -B(1,3,10))Y (B(1,3,10)> -N(1,3,10))))Y ((N(1,3,11)> -B(1,3,11))Y (B(1,3,11)> -N(1,3,11))))Y ((N(1,3,12)> -B(1,3,12))Y (B(1,3,12)> -N(1,3,12))))Y ((N(1,3,13)> -B(1,3,13))Y (B(1,3,13)> -N(1,3,13))))Y ((N(1,3,14)> -B(1,3,14))Y (B(1,3,14)> -N(1,3,14))))Y ((N(1,3,15)> -B(1,3,15))Y (B(1,3,15)> -N(1,3,15))))Y ((N(1,3,16)> -B(1,3,16))Y (B(1,3,16)> -N ...

# %% [markdown]
# ### Pasos para la regla 3:
#
# #### Victoria diagonal 1
#
# \begin{align*}
#     (\bigwedge^{4}_{i = 0} N(b + i,2 + i, 10))
# \end{align*}
# \begin{align*}
#     \vee
# \end{align*}
#
# \begin{align*}
#     (\bigwedge^{4}_{i = 0} B(b + i,2 + i, 10))
# \end{align*}

# %%
def victoria_negras_diagonal_1():
    inicial = True
    for i in range(5):
        if inicial:
            formula = cods1.N(1 + i, 1 + i, 10)
            inicial = False
        else:
            formula = cods1.N(1 + i, 1 + i, 10) + formula + 'Y'
    return formula

def victoria_blancas_diagonal_1():
    inicial = True
    for i in range(5):
        if inicial:
            formula = cods2.B(1 + i, 1 + i, 10)
            inicial = False
        else:
            formula = cods2.B(1 + i, 1 + i, 10) + formula + 'Y'
    return formula

def victoria_diagonal_1():
    formula1 = victoria_negras_diagonal_1()
    formula2 = victoria_blancas_diagonal_1()
    formula = formula2 + formula1 + 'O'
    return formula

formula = victoria_diagonal_1()
A = String2Tree(formula)
print(Inorderp(A))
# Out:
# (((((N(1,1,10)Y N(2,2,10))Y N(3,3,10))Y N(4,4,10))Y N(5,5,10))O ((((B(1,1,10)Y B(2,2,10))Y B(3,3,10))Y B(4,4,10))Y B(5,5,10)))

# %% [markdown]
# #### Victoria diagonal 2
#
# \begin{align*}
#     (\bigwedge^{4}_{i = 0} N(b + 1, 6 - i, 10))
# \end{align*}
# \begin{align*}
#     \vee
# \end{align*}
# \begin{align*}
#     (\bigwedge^{4}_{i = 0} B(b + 1, 6 - i, 10))
# \end{align*}

# %%
def victoria_negras_diagonal_2():
    inicial = True
    for i in range(5):
        if inicial:
            formula = cods1.N(1 + i, 5 - i, 10)
            inicial = False
        else:
            formula = cods1.N(1 + i, 5 - i, 10) + formula + 'Y'
    return formula

def victoria_blancas_diagonal_2():
    inicial = True
    for i in range(5):
        if inicial:
            formula = cods2.B(1 + i, 5 - i, 10)
            inicial = False
        else:
            formula = cods2.B(1 + i, 5 - i, 10) + formula + 'Y'
    return formula

def victoria_diagonal_2():
    formula1 = victoria_negras_diagonal_2()
    formula2 = victoria_blancas_diagonal_2()
    formula = formula2 + formula1 + 'O'
    return formula

formula = victoria_diagonal_2()
A = String2Tree(formula)
print(Inorderp(A))
# Out:
# (((((N(1,5,10)Y N(2,4,10))Y N(3,3,10))Y N(4,2,10))Y N(5,1,10))O ((((B(1,5,10)Y B(2,4,10))Y B(3,3,10))Y B(4,2,10))Y B(5,1,10)))

# %% [markdown]
# #### Victoria vertical
#
# \begin{align*}
#     \bigvee^{6}_{y = 2}(\bigwedge^{f}_{x = b} N(x,y,10))
# \end{align*}
# \begin{align*}
#     \vee
# \end{align*}
# \begin{align*}
#     \bigvee^{6}_{y = 2}(\bigwedge^{f}_{x = b} B(x,y,10))
# \end{align*}

# %%
def ytoria_v_negras(c):
    Nf = 6
    inicial = True
    for f in range(1, Nf):
        if inicial:
            formula = cods1.N(f,c,10)
            inicial = False
        else:
            formula = cods1.N(f,c,10) + formula + 'Y'
    return formula

def victoria_vertical_negras():
    Nc = 6
    inicial = True
    for c in range(1, Nc):
        if inicial:
            formula = ytoria_v_negras(c)
            inicial = False
        else:
            formula = ytoria_v_negras(c) + formula + 'O'
    return formula

def ytoria_v_blancas(c):
    Nf = 6
    inicial = True
    for f in range(1, Nf):
        if inicial:
            formula = cods2.B(f,c,10)
            inicial = False
        else:
            formula = cods2.B(f,c,10) + formula + 'Y'
    return formula

def victoria_vertical_blancas():
    Nc = 6
    inicial = True
    for c in range(1, Nc):
        if inicial:
            formula = ytoria_v_blancas(c)
            inicial = False
        else:
            formula = ytoria_v_blancas(c) + formula + 'O'
    return formula

def victoria_vertical():
    formula1 = victoria_vertical_negras()
    formula2 = victoria_vertical_blancas()
    formula = formula2 + formula1 + 'O'
    return formula

formula = victoria_vertical()
A = String2Tree(formula)
print(Inorderp(A))
# Out:
# (((((((((N(1,1,10)Y N(2,1,10))Y N(3,1,10))Y N(4,1,10))Y N(5,1,10))O ((((N(1,2,10)Y N(2,2,10))Y N(3,2,10))Y N(4,2,10))Y N(5,2,10)))O ((((N(1,3,10)Y N(2,3,10))Y N(3,3,10))Y N(4,3,10))Y N(5,3,10)))O ((((N(1,4,10)Y N(2,4,10))Y N(3,4,10))Y N(4,4,10))Y N(5,4,10)))O ((((N(1,5,10)Y N(2,5,10))Y N(3,5,10))Y N(4,5,10))Y N(5,5,10)))O ((((((((B(1,1,10)Y B(2,1,10))Y B(3,1,10))Y B(4,1,10))Y B(5,1,10))O ((((B(1,2,10)Y B(2,2,10))Y B(3,2,10))Y B(4,2,10))Y B(5,2,10)))O ((((B(1,3,10)Y B(2,3,10))Y B(3,3,10))Y B(4,3,10))Y B(5,3,10)))O ((((B(1,4,10)Y B(2,4,10))Y B(3,4,10))Y B(4,4,10))Y B(5,4,10)))O ((((B(1,5,10)Y B(2,5,10))Y B(3,5,10))Y B(4,5,10))Y B(5,5,10))))

# %% [markdown]
# #### Victoria horizontal
#
# \begin{align*}
#     \bigvee^{f}_{x = b}(\bigwedge^{6}_{y = 2} N(x,y,10))
# \end{align*}
# \begin{align*}
#     \vee
# \end{align*}
# \begin{align*}
#     \bigvee^{f}_{x = b}(\bigwedge^{6}_{y = 2} B(x,y,10))
# \end{align*}

# %%
def ytoria_h_negras(f):
    Nc = 6
    inicial = True
    for c in range(1, Nc):
        if inicial:
            formula = cods1.N(f,c,10)
            inicial = False
        else:
            formula = cods1.N(f,c,10) + formula + 'Y'
    return formula

def victoria_horizontal_negras():
    Nf = 6
    inicial = True
    for f in range(1, Nf):
        if inicial:
            formula = ytoria_h_negras(f)
            inicial = False
        else:
            formula = ytoria_h_negras(f) + formula + 'O'
    return formula

def ytoria_h_blancas(f):
    Nc = 6
    inicial = True
    for c in range(1, Nc):
        if inicial:
            formula = cods2.B(f,c,10)
            inicial = False
        else:
            formula = cods2.B(f,c,10) + formula + 'Y'
    return formula

def victoria_horizontal_blancas():
    Nf = 6
    inicial = True
    for f in range(1, Nf):
        if inicial:
            formula = ytoria_h_blancas(f)
            inicial = False
        else:
            formula = ytoria_h_blancas(f) + formula + 'O'
    return formula


def victoria_horizontal():
    formula1 = victoria_horizontal_negras()
    formula2 = victoria_horizontal_blancas()
    formula = formula2 + formula1 + 'O'
    return formula

formula = victoria_horizontal()
A = String2Tree(formula)
print(Inorderp(A))
# Out:
# (((((((((N(1,1,10)Y N(1,2,10))Y N(1,3,10))Y N(1,4,10))Y N(1,5,10))O ((((N(2,1,10)Y N(2,2,10))Y N(2,3,10))Y N(2,4,10))Y N(2,5,10)))O ((((N(3,1,10)Y N(3,2,10))Y N(3,3,10))Y N(3,4,10))Y N(3,5,10)))O ((((N(4,1,10)Y N(4,2,10))Y N(4,3,10))Y N(4,4,10))Y N(4,5,10)))O ((((N(5,1,10)Y N(5,2,10))Y N(5,3,10))Y N(5,4,10))Y N(5,5,10)))O ((((((((B(1,1,10)Y B(1,2,10))Y B(1,3,10))Y B(1,4,10))Y B(1,5,10))O ((((B(2,1,10)Y B(2,2,10))Y B(2,3,10))Y B(2,4,10))Y B(2,5,10)))O ((((B(3,1,10)Y B(3,2,10))Y B(3,3,10))Y B(3,4,10))Y B(3,5,10)))O ((((B(4,1,10)Y B(4,2,10))Y B(4,3,10))Y B(4,4,10))Y B(4,5,10)))O ((((B(5,1,10)Y B(5,2,10))Y B(5,3,10))Y B(5,4,10))Y B(5,5,10))))

# %% [markdown]
# ### Regla 3:
#
# La **regla 3** es la union de todas las posibles victorias con una 'O':
#
# \begin{align*}
#     R3\_D1 \vee R3\_D2 \vee R3 \_ V \vee R3 \_ H
# \end{align*}
#
# Se gana con cinco piedras del mismo color seguidas en línea vertical, horizontal o diagonal.

# %%
def regla3():
    diagonal_1 = victoria_diagonal_1()
    diagonal_2 = victoria_diagonal_2()
    vertical = victoria_vertical()
    horizontal = victoria_horizontal()
    victoria = horizontal + vertical + 'O' + diagonal_2 + 'O' + diagonal_1 + 'O'
    return victoria

# %%
formula = regla3()
A = String2Tree(formula)
print(Inorderp(A))
# Out:
# ((((((N(1,1,10)Y N(2,2,10))Y N(3,3,10))Y N(4,4,10))Y N(5,5,10))O ((((B(1,1,10)Y B(2,2,10))Y B(3,3,10))Y B(4,4,10))Y B(5,5,10)))O ((((((N(1,5,10)Y N(2,4,10))Y N(3,3,10))Y N(4,2,10))Y N(5,1,10))O ((((B(1,5,10)Y B(2,4,10))Y B(3,3,10))Y B(4,2,10))Y B(5,1,10)))O ((((((((((N(1,1,10)Y N(2,1,10))Y N(3,1,10))Y N(4,1,10))Y N(5,1,10))O ((((N(1,2,10)Y N(2,2,10))Y N(3,2,10))Y N(4,2,10))Y N(5,2,10)))O ((((N(1,3,10)Y N(2,3,10))Y N(3,3,10))Y N(4,3,10))Y N(5,3,10)))O ((((N(1,4,10)Y N(2,4,10))Y N(3,4,10))Y N(4,4,10))Y N(5,4,10)))O ((((N(1,5,10)Y N(2,5,10))Y N(3,5,10))Y N(4,5,10))Y N(5,5,10)))O ((((((((B(1,1,10)Y B(2,1,10))Y B(3,1,10))Y B(4,1,10))Y B(5,1,10))O ((((B(1,2,10)Y B(2,2,10))Y B(3,2,10))Y B(4,2,10))Y B(5,2,10)))O ((((B(1,3,10)Y B(2,3,10))Y B(3,3,10))Y B(4,3,10))Y B(5,3,10)))O ((((B(1,4,10)Y B(2,4,10))Y B(3,4,10))Y B(4,4,10))Y B(5,4,10)))O ((((B(1,5,10)Y B(2,5,10))Y B(3,5,10))Y B(4,5,10))Y B(5,5,10))))O (((((((((N(1,1,10)Y N(1,2,10))Y N(1,3,10))Y N(1,4,10))Y N(1,5,10))O ((((N(2,1,10)Y N(2,2,10))Y N(2,3,10))Y N(2,4,10))Y N(2,5,10)))O ((((N(3,1,10)Y N(3,2,10))Y N(3,3,10))Y N(3,4,10))Y N(3,5,10)))O ((((N(4,1,10)Y N(4,2,10))Y N(4,3,10))Y N(4,4,10))Y N(4,5,10)))O ((((N(5,1,10)Y N(5,2,10))Y N(5,3,10))Y N(5,4,10))Y N(5,5,10)))O ((((((((B(1,1,10)Y B(1,2,10))Y B(1,3,10))Y B(1,4,10))Y B(1,5,10))O ((((B(2,1,10)Y B(2,2,10))Y B(2,3,10))Y B(2,4,10))Y B(2,5,10)))O ((((B(3,1,10)Y B(3,2,10))Y B(3,3,10))Y B(3,4,10))Y B(3,5,10)))O ((((B(4,1,10)Y B(4,2,10))Y B(4,3,10))Y B(4,4,10))Y B(4,5,10)))O ((((B(5,1,10)Y B(5,2,10))Y B(5,3,10))Y B(5,4,10))Y B(5,5,10)))))))

# %% [markdown]
# ### Pasos para la regla 4:
#
# 4.1. La piedra que se coloque, sea negra o blanca, se debe quedar ahí para los siguientes turnos.
#
# \begin{align*}
#      \left( N(x,y,t) \rightarrow N(x,y,t')\right) \vee \left(B(x,y,t) \rightarrow B(x,y,t')\right)
# \end{align*}

# %%
def piedas_se_quedan(x,y,t1,t2):
    formula1 = cods1.N(x,y,t2) + cods1.N(x,y,t1) + ">"
    formula2 = cods2.B(x,y,t2) + cods2.B(x,y,t1) + ">"
    formula = formula2 + formula1 + "O"
    return formula

formula = piedas_se_quedan(1,1,1,2)
A = String2Tree(formula)
print(Inorderp(A))
# Out:
# ((N(1,1,1)> N(1,1,2))O (B(1,1,1)> B(1,1,2)))

# %% [markdown]
# 4.2 La **regla 4** se conforma para todas las posibilidades del paso 4.1
#
# \begin{align*}
#      \bigwedge_{t' = t+1}^{10} \bigwedge_{t = 1}^{10} \bigwedge_{x = b}^{f} \bigwedge_{y = 2}^{6} \left( N(x,y,t) \rightarrow N(x,y,t')\right) \vee \left(B(x,y,t) \rightarrow B(x,y,t')\right)
# \end{align*}
#
# Si hay una piedra en una posición del tablero, esta se queda ahí para todos los turnos siguientes.

# %%
def regla4():
    inicial = True
    Nf = 6
    Nc = 6
    Nt = 10
    for f in range(1, Nf):
        for c in range(1, Nc): 
            for t1 in range(1, Nt):
                for t2 in range(t1+1, Nt):
                    if inicial:
                        formula = piedas_se_quedan(f,c,t1,t2)
                        inicial = False
                    else:
                        formula = piedas_se_quedan(f,c,t1,t2) + formula + 'O'
    return formula

# %%
formula = regla4()
A = String2Tree(formula)
print(Inorderp(A))
# Out:
# (((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((N(1,1,1)> N(1,1,2))O (B(1,1,1)> B(1,1,2)))O ((N(1,1,1)> N(1,1,3))O (B(1,1,1)> B(1,1,3))))O ((N(1,1,1)> N(1,1,4))O (B(1,1,1)> B(1,1,4))))O ((N(1,1,1)> N(1,1,5))O (B(1,1,1)> B(1,1,5))))O ((N(1,1,1)> N(1,1,6))O (B(1,1,1)> B(1,1,6))))O ((N(1,1,1)> N(1,1,7))O (B(1,1,1)> B(1,1,7))))O ((N(1,1,1)> N(1,1,8))O (B(1,1,1)> B(1,1,8))))O ((N(1,1,1)> N(1,1,9))O (B(1,1,1)> B(1,1,9))))O ((N(1,1,2)> N(1,1,3))O (B(1,1,2)> B(1,1,3))))O ((N(1,1,2)> N(1,1,4))O (B(1,1,2)> B(1,1,4))))O ((N(1,1,2)> N(1,1,5))O (B(1,1,2)> B(1,1,5))))O ((N(1,1,2)> N(1,1,6))O (B(1,1,2)> B(1,1,6))))O ((N(1,1,2)> N(1,1,7))O (B(1,1,2)> B(1,1,7))))O ((N(1,1,2)> N(1,1,8))O (B(1,1,2)> B(1,1,8))))O ((N(1,1,2)> N(1,1,9))O (B(1,1,2)> B(1,1,9))))O ((N(1,1,3)> N(1,1,4))O (B(1,1,3)> B(1,1,4))))O ((N(1,1,3)> N(1,1,5))O (B(1,1,3)> B(1,1,5))))O ((N(1,1,3)> N(1,1,6))O (B(1,1,3)> B(1,1,6))))O ((N(1,1,3)> N(1,1,7))O (B(1,1,3)> B(1,1,7))))O ((N(1,1,3)> N(1,1,8))O (B(1,1,3)> B(1,1,8))))O ((N(1,1,3)> N(1,1,9))O (B(1,1,3)> B(1,1,9))))O ((N(1,1,4)> N(1,1,5))O (B(1,1,4)> B(1,1,5))))O ((N(1,1,4)> N(1,1,6))O (B(1,1,4)> B(1,1,6))))O ((N(1,1,4)> N(1,1,7))O (B(1,1,4)> B(1,1,7))))O ((N(1,1,4)> N(1,1,8))O (B(1,1,4)> B(1,1,8))))O ((N(1,1,4)> N(1,1,9))O (B(1,1,4)> B(1,1,9))))O ((N(1,1,5)> N(1,1,6))O (B(1,1,5)> B(1,1,6))))O ((N(1,1,5)> N(1,1,7))O (B(1,1,5)> B(1,1,7))))O ((N(1,1,5)> N(1,1,8))O (B(1,1,5)> B(1,1,8))))O ((N(1,1,5)> N(1,1,9))O (B(1,1,5)> B(1,1,9))))O ((N(1,1,6)> N(1,1,7))O (B(1,1,6)> B(1,1,7))))O ((N(1,1,6)> N(1,1,8))O (B(1,1,6)> B(1,1,8))))O ((N(1,1,6)> N(1,1,9))O (B(1,1,6)> B(1,1,9))))O ((N(1,1,7)> N(1,1,8))O (B(1,1,7)> B(1,1,8))))O ((N(1,1,7)> N(1,1,9))O (B(1,1,7)> B(1,1,9))))O ((N(1,1,8)> N(1,1,9))O (B(1,1,8)> B(1,1,9))))O ((N(1,2,1)> N(1,2,2))O (B(1,2,1)> B(1,2,2))))O ((N(1,2,1)> N(1,2,3))O (B(1,2,1)> B(1,2,3))))O ((N(1,2,1)> N(1,2,4))O (B(1,2,1)> B(1,2,4))))O ((N(1,2,1)> N(1,2,5))O (B(1,2,1)> B(1,2,5))))O ((N(1,2,1)> N(1,2,6))O (B(1,2,1)> B(1,2,6))))O ((N(1,2,1)> N(1,2,7))O (B(1,2,1)> B(1,2,7))))O ((N(1,2,1)> N(1,2,8))O (B(1,2,1)> B(1,2,8))))O ((N(1,2,1)> N(1,2,9))O (B(1,2,1)> B(1,2,9))))O ((N(1,2,2)> N(1,2,3))O (B(1,2,2)> B(1,2,3))))O ((N(1,2,2)> N(1,2,4))O (B(1,2,2)> B(1,2,4))))O ((N(1,2,2)> N(1,2,5))O (B(1,2,2)> B(1,2,5))))O ((N(1,2,2)> N(1,2,6))O (B(1,2,2)> B(1,2,6))))O ((N(1,2,2)> N(1,2,7))O (B(1,2,2)> B(1,2,7))))O ((N(1,2,2)> N(1,2,8))O (B(1,2,2)> B(1,2,8))))O ((N(1,2,2)> N(1,2,9))O (B(1,2,2)> B(1,2,9))))O ((N(1,2,3)> N(1,2,4))O (B(1,2,3)> B(1,2,4))))O ((N(1,2,3)> N(1,2,5))O (B(1,2,3)> B(1,2,5))))O ((N(1,2,3)> N(1,2,6))O (B(1,2,3)> B(1,2,6))))O ((N(1,2,3)> N(1,2,7))O (B(1,2,3)> B(1,2,7))))O ((N(1,2,3)> N(1,2,8))O (B(1,2,3)> B(1,2,8))))O ((N(1,2,3)> N(1,2,9))O (B(1,2,3)> B(1,2,9))))O ((N(1,2,4)> N(1,2,5))O (B(1,2,4)> B(1,2,5))))O ((N(1,2,4)> N(1,2,6))O (B(1,2,4)> B(1,2,6))))O ((N(1,2,4)> N(1,2,7))O (B(1,2,4)> B(1,2,7))))O ((N(1,2,4)> N(1,2,8))O (B(1,2,4)> B(1,2,8))))O ((N(1,2,4)> N(1,2,9))O (B(1,2,4)> B(1,2,9))))O ((N(1,2,5)> N(1,2,6))O (B(1,2,5)> B(1,2,6))))O ((N(1,2,5)> N(1,2,7))O (B(1,2,5)> B(1,2,7))))O ((N(1,2,5)> N(1,2,8))O (B(1,2,5)> B(1,2,8))))O ((N(1,2,5)> N(1,2,9))O (B(1,2,5)> B(1,2,9))))O  ...

# %% [markdown]
# ### (Por evaluar) regla 5:
#
# \begin{align*}
#     \bigwedge_{t = 2}^{25} \bigwedge_{x = b}^{f} \bigwedge_{y = 2}^{6} ( \left( \neg(N(x,y,t-1) \vee B(x,y,t-1)) \wedge (N(x,y,t) \vee B(x,y,t)) \right) \rightarrow \bigwedge_{(u,v) \neq (x,y)} \neg (N(u,v,t-1) \vee B(u,v,t-1)) \rightarrow  \neg (N(u,v,t) \vee B(u,v,t)))
# \end{align*}

# %% [markdown]
# Se coloca una piedra a la vez en cada ronda.

# %% [markdown]
# ## Visualización de una solución
#
# Para representar el problema del go-moku descrito anteriormente, es necesario construir la función que dibuje las posibilidades de juego.
#
#
# <img src="img/gomoku.jpg" alt="drawing" width="350"/>

# %%
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.offsetbox import AnnotationBbox, OffsetImage
# %matplotlib inline

# %%
def tablero(f):

    #Dibuja las cuadriculas coordenadas dada una formula f
    #Input: 
        # - f : es un diccionario con literales y sus valores de verdad.
    #Output:
        # tablero.
    
    # Dibujo el tablero
    fig, axes= plt.subplots()
    plt.xticks(np.arange(0, 1, 0.165), ["a","b","c","d","e","f","g"])
    plt.yticks(np.arange(0, 1, 0.165), range(1,8))
    
    axes.get_xaxis().set_visible(True)
    axes.get_yaxis().set_visible(True)
    
    axes.set_facecolor('peachpuff') # color del fondo
    
    step = 1./6
    cuadrados = []
    

    # Creo las líneas del tablero
    for j in range(14): #Determina que sea un tablero 6x6, con lineas 7x7
        locacion = j * step
        # Crea linea horizontal en el rectangulo
        cuadrados.append(patches.Rectangle(*[(0, step + locacion), 1, 0.005],\
                facecolor='black'))
        # Crea linea vertical en el rectangulo
        cuadrados.append(patches.Rectangle(*[(step + locacion, 0), 0.005, 1],\
                facecolor='black'))
    
    # crea el tablero
    for t in cuadrados:
        axes.add_patch(t)
    
    for i in f.keys():
        
        if f[i] != 0: #el valor de verdad es diferente de 0.
            fila, columna, turno = cods1.Ninv(i)
            fila2, columna2, turno2 = cods2.Binv(i)
            
        if turno%2 != 0: #si es el turno de las negras, ubicar en una respetiva coordenada.
            p_negra = plt.imread("img/p_negra.png", format='png')
            imagebox = OffsetImage(p_negra, zoom=0.1)
            imagebox.image.axes = axes
            ab = AnnotationBbox(imagebox, [fila*1./6, columna*1./6], frameon=False)
            axes.add_artist(ab)
 
        if turno2%2 == 0: #si es el turno de las blancas, ubicar en una respetiva coordenada.
            p_blanca = plt.imread("img/p_blanca.png", format= "png")
            image2box = OffsetImage(p_blanca, zoom = 0.1)
            image2box.image.axes = axes
            ab = AnnotationBbox(image2box, [fila2*1./6, columna2*1./6], frameon=False)
            axes.add_artist(ab)
    
    plt.show()

# %%
I = {}
I[cods1.N(1,1,1)] = 1 
I[cods2.B(1,2,2)] = 1 
I[cods1.N(2,3,3)] = 1 
I[cods2.B(5,5,4)] = 1
I[cods1.N(5,1,5)] = 1
I[cods2.B(5,2,6)] = 1
I
# Out:
# {'Ȅ': 1, 'ࣻ': 1, '̮': 1, '\u0ce4': 1, 'ր': 1, '౷': 1}

# %%
tablero(I)

# %%
ABC = {}
ABC[cods1.N(1,1,1)] = 1 
ABC[cods2.B(1,2,2)] = 1 
ABC[cods1.N(2,2,3)] = 1 
ABC[cods2.B(4,5,4)] = 1
ABC[cods1.N(3,3,5)] = 1
ABC[cods2.B(5,2,6)] = 1
ABC[cods1.N(4,4,7)] = 1
ABC[cods2.B(5,2,8)] = 1
ABC[cods1.N(5,5,9)] = 1
ABC
# Out:
# {'Ȅ': 1, 'ࣻ': 1, '̉': 1, 'ఆ': 1, 'Ў': 1, '౷': 1, 'ԓ': 1, '౹': 1, 'ؘ': 1}

# %%
tablero(ABC) # Victoria Diagonal 1 con negras
